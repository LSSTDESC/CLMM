# %%
import numpy as np
import matplotlib.pyplot as plt
#from astropy.table import Table

# %%
import clmm

# %%
import pyccl
pyccl.__version__
# Out:
# '2.1.1.dev78+g46692a38'

# %%
gamma_T = np.load("gamma_T.npy")
gamma_X = np.load("gamma_X.npy")
gamma1 = np.load("gamma1.npy")
gamma2 = np.load("gamma2.npy")

kappa = np.load("kappa.npy")
x_arcsec = np.load("x_arcsec.npy")
y_arcsec = np.load("y_arcsec.npy")

# %%
print(gamma_T)
# Out:
# [[0.00152502 0.00155102 0.00157752 ... 0.00157752 0.00155102 0.00152502]
#  [0.0015462  0.00157299 0.00160032 ... 0.00160032 0.00157299 0.0015462 ]
#  [0.00156761 0.00159521 0.00162339 ... 0.00162339 0.00159521 0.00156761]
#  ...
#  [0.00156761 0.00159521 0.00162339 ... 0.00162339 0.00159521 0.00156761]
#  [0.0015462  0.00157299 0.00160032 ... 0.00160032 0.00157299 0.0015462 ]
#  [0.00152502 0.00155102 0.00157752 ... 0.00157752 0.00155102 0.00152502]]

# %%
print(gamma1)
# Out:
# [[-1.23874244e-04 -9.48537609e-05 -6.40612184e-05 ... -6.40612184e-05
#   -9.48537609e-05 -1.23874244e-04]
#  [-1.57087129e-04 -1.28347423e-04 -9.77845814e-05 ... -9.77845814e-05
#   -1.28347423e-04 -1.57087129e-04]
#  [-1.91714603e-04 -1.63327296e-04 -1.33067412e-04 ... -1.33067412e-04
#   -1.63327296e-04 -1.91714603e-04]
#  ...
#  [-1.91714603e-04 -1.63327296e-04 -1.33067412e-04 ... -1.33067412e-04
#   -1.63327296e-04 -1.91714603e-04]
#  [-1.57087129e-04 -1.28347423e-04 -9.77845814e-05 ... -9.77845814e-05
#   -1.28347423e-04 -1.57087129e-04]
#  [-1.23874244e-04 -9.48537609e-05 -6.40612184e-05 ... -6.40612184e-05
#   -9.48537609e-05 -1.23874244e-04]]

# %%
print(gamma2)
# Out:
# [[ 0.00152502  0.00155328  0.00158151 ... -0.00158151 -0.00155328
#   -0.00152502]
#  [ 0.00154332  0.00157299  0.0016027  ... -0.0016027  -0.00157299
#   -0.00154332]
#  [ 0.00156103  0.00159216  0.00162339 ... -0.00162339 -0.00159216
#   -0.00156103]
#  ...
#  [-0.00156103 -0.00159216 -0.00162339 ...  0.00162339  0.00159216
#    0.00156103]
#  [-0.00154332 -0.00157299 -0.0016027  ...  0.0016027   0.00157299
#    0.00154332]
#  [-0.00152502 -0.00155328 -0.00158151 ...  0.00158151  0.00155328
#    0.00152502]]

# %%
print(kappa)
# Out:
# [[0.0003567  0.00036647 0.00037658 ... 0.00037658 0.00036647 0.0003567 ]
#  [0.00036098 0.00037099 0.00038135 ... 0.00038135 0.00037099 0.00036098]
#  [0.00036527 0.00037552 0.00038615 ... 0.00038615 0.00037552 0.00036527]
#  ...
#  [0.00036527 0.00037552 0.00038615 ... 0.00038615 0.00037552 0.00036527]
#  [0.00036098 0.00037099 0.00038135 ... 0.00038135 0.00037099 0.00036098]
#  [0.0003567  0.00036647 0.00037658 ... 0.00037658 0.00036647 0.0003567 ]]

# %%
print(x_arcsec)
# Out:
# [[-495. -485. -475. ...  475.  485.  495.]
#  [-495. -485. -475. ...  475.  485.  495.]
#  [-495. -485. -475. ...  475.  485.  495.]
#  ...
#  [-495. -485. -475. ...  475.  485.  495.]
#  [-495. -485. -475. ...  475.  485.  495.]
#  [-495. -485. -475. ...  475.  485.  495.]]

# %%
print(y_arcsec)
# Out:
# [[ 495.  495.  495. ...  495.  495.  495.]
#  [ 485.  485.  485. ...  485.  485.  485.]
#  [ 475.  475.  475. ...  475.  475.  475.]
#  ...
#  [-475. -475. -475. ... -475. -475. -475.]
#  [-485. -485. -485. ... -485. -485. -485.]
#  [-495. -495. -495. ... -495. -495. -495.]]

# %%
plt.figure()
plt.imshow(gamma_T)
plt.colorbar()

# %%
plt.figure()
plt.imshow(gamma_X, cmap='bwr')
plt.colorbar()

# %%
plt.figure()
plt.imshow(gamma1, cmap='bwr')
plt.colorbar()

# %%
plt.figure()
plt.imshow(gamma2, cmap='bwr')
plt.colorbar()
