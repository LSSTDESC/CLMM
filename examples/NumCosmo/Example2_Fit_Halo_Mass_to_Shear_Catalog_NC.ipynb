# %% [markdown]
# # Fit halo mass to shear profile using Numcosmo statistical framework
#
# _the LSST-DESC CLMM team_
#
# This notebook demonstrates how to use `clmm` to estimate a WL halo mass from observations of a galaxy cluster. It uses several functionalities of the support `mock_data` module to produce datasets of increasing complexity. It relies on Numcosmo tools for the statistical analysis and shows how to fit for both cluster mass and concentration.
#
# 1. The first part of notebook is equivalent to `Example2_Fit_Halo_Mass_to_Shear_Catalog.ipynb` and demonstrates the bias introduced on the reconstructed mass by a naive fit, when the redshift distribution of the background galaxies is not properly accounted for in the model.
#
# - Setting things up, with the proper imports.
# - Generating 3 datasets: an ideal dataset (dataset1) similar to that of Example1 (single source plane); an ideal dataset but with source galaxies following the Chang et al. (2013) redshift distribution (dataset2); a noisy dataset where photoz errors and shape noise are also included (dataset3).
# - Computing the binned reduced tangential shear profile, for the 3 datasets, using logarithmic binning.
# - Setting up the "single source plane" model to be fitted to the 3 datasets. Only dataset1 has a single source plane, so we expect to see a bias in the reconstructed mass when using this model on datasets 2 and 3.
# - Perform a simple fit using NumCosmo tools to compute the best-fit and the Fisher Matrix, and visualize the results.
# - Perform a MCMC analysis using NumCosmo tools and visualize the results.
#
# 2. In a second part, an unbinned likelihood is build to properly account for the redshift distribution, in a manner differing from that presented in `Example3_Fit_Halo_Mass_to_Shear_Catalog.ipynb`. Both the best-fit+Fisher matrix and MCMC analyses are used.
#
#
# NB: to display the corner plot output of the MCMC analysis, you will need the `corner` package installed in your python environment.

# %% [markdown]
# ## Setup

# %% [markdown]
# First, we import some standard packages.

# %%
# For NumCosmo
import os
import sys
import gi

gi.require_version('NumCosmo', '1.0')
gi.require_version('NumCosmoMath', '1.0')
from gi.repository import GObject
from gi.repository import NumCosmo as Nc
from gi.repository import NumCosmoMath as Ncm

from scipy.stats import chi2

import math
# The corner package is needed to view the results of the MCMC analysis
import corner


os.environ['CLMM_MODELING_BACKEND'] = 'nc'

__name__ = "NcContext"

Ncm.cfg_init ()
Ncm.cfg_set_log_handler (lambda msg: sys.stdout.write (msg) and sys.stdout.flush ())

# %%
try: import clmm
except:
    import notebook_install
    notebook_install.install_clmm_pipeline(upgrade=False)
    import clmm
import matplotlib.pyplot as plt
import numpy as np
from numpy import random
from clmm.support.sampler import fitters

clmm.__version__
# Out:
# '1.0.0'

# %% [markdown]
# Next, we import `clmm`'s core modules.

# %%
import clmm.dataops as da
import clmm.galaxycluster as gc
import clmm.theory as theory
from clmm import Cosmology

# %% [markdown]
# We then import a support modules for a specific data sets.
# `clmm` includes support modules that enable the user to generate mock data in a format compatible with `clmm`.

# %%
from clmm.support import mock_data as mock

# %% [markdown]
# ## Making mock data

# %% [markdown]
# For reproducibility:

# %%
np.random.seed(11)

# %% [markdown]
# To create mock data, we need to define a true cosmology.

# %%
mock_cosmo = Cosmology(H0 = 70.0, Omega_dm0 = 0.27 - 0.045, Omega_b0 = 0.045, Omega_k0 = 0.0)

# %% [markdown]
# We now set some parameters for a mock galaxy cluster.

# %%
cosmo = mock_cosmo
cluster_m = 1.e15 # M200,m [Msun]
cluster_z = 0.3   # Cluster's redshift
concentration = 4
ngals = 10000     # Number of galaxies
Delta = 200
cluster_ra = 0.0
cluster_dec = 0.0

# %% [markdown]
# Then we use the `mock_data` support module to generate 3 galaxy catalogs:
# - `ideal_data`: all background galaxies at the same redshift.
# - `ideal_data_z`: galaxies distributed according to the Chang et al. (2013) redshift distribution.
# - `noisy_data_z`: `ideal_data_z` + photoz errors + shape noise

# %%
ideal_data = mock.generate_galaxy_catalog(cluster_m, cluster_z, concentration, cosmo, 0.8, ngals=ngals)
ideal_data_z = mock.generate_galaxy_catalog(cluster_m, cluster_z, concentration, cosmo,'chang13', ngals=ngals)
noisy_data_z = mock.generate_galaxy_catalog(cluster_m, cluster_z, concentration, cosmo, 'chang13', 
                                            shapenoise=0.05, 
                                            photoz_sigma_unscaled=0.05, ngals=ngals)

# %% [markdown]
# The galaxy catalogs are converted to a `clmm.GalaxyCluster` object and may be saved for later use.

# %%
cluster_id = "CL_ideal"
gc_object = clmm.GalaxyCluster(cluster_id, cluster_ra, cluster_dec,
                               cluster_z, ideal_data)
gc_object.save('ideal_GC.pkl')

cluster_id = "CL_ideal_z"
gc_object = clmm.GalaxyCluster(cluster_id, cluster_ra, cluster_dec,
                               cluster_z, ideal_data_z)
gc_object.save('ideal_GC_z.pkl')

cluster_id = "CL_noisy_z"
gc_object = clmm.GalaxyCluster(cluster_id, cluster_ra, cluster_dec,
                               cluster_z, noisy_data_z)
gc_object.save('noisy_GC_z.pkl')

# %% [markdown]
# Any saved `clmm.GalaxyCluster` object may be read in for analysis.

# %%
cl1 = clmm.GalaxyCluster.load('ideal_GC.pkl') # all background galaxies at the same redshift
cl2 = clmm.GalaxyCluster.load('ideal_GC_z.pkl') # background galaxies distributed according to Chang et al. (2013)
cl3 = clmm.GalaxyCluster.load('noisy_GC_z.pkl') # same as cl2 but with photoz error and shape noise

print("Cluster info = ID:", cl2.unique_id, "; ra:", cl2.ra, "; dec:", cl2.dec, "; z_l :", cl2.z)
print("The number of source galaxies is :", len(cl2.galcat))
# Out:
# Cluster info = ID: CL_ideal_z ; ra: 0.0 ; dec: 0.0 ; z_l : 0.3
# The number of source galaxies is : 10000

# %%
h = plt.hist(cl2.galcat['z'], bins=50)

# %% [markdown]
# ## Deriving observables

# %% [markdown]
# ### Computing shear

# %% [markdown]
# `clmm.dataops.compute_tangential_and_cross_components` calculates the tangential and cross shears for each source galaxy in the cluster.

# %%
theta1, g_t1, g_x1 = cl1.compute_tangential_and_cross_components(geometry="flat")
theta2, g_t2, g_x2 = cl2.compute_tangential_and_cross_components(geometry="flat")
theta3, g_t3, g_x3 = cl3.compute_tangential_and_cross_components(geometry="flat")

# %% [markdown]
# ### Radially binning the data

# %%
bin_edges = da.make_bins(0.7, 4, 15, method='evenlog10width')

# %% [markdown]
# `clmm.dataops.make_radial_profile` evaluates the average shear of the galaxy catalog in bins of radius.

# %%
profile1 = cl1.make_radial_profile("Mpc", bins=bin_edges,cosmo=cosmo)
profile2 = cl2.make_radial_profile("Mpc", bins=bin_edges,cosmo=cosmo)
profile3 = cl3.make_radial_profile("Mpc", bins=bin_edges,cosmo=cosmo)

# %% [markdown]
# After running `clmm.dataops.make_radial_profile` on a `clmm.GalaxyCluster` object, the object acquires the `clmm.GalaxyCluster.profile` attribute.

# %%
for n in cl1.profile.colnames: cl1.profile[n].format = "%6.3e"
cl1.profile.pprint(max_width=-1)
# Out:
# radius_min   radius  radius_max     gt      gt_err      gx       gx_err      z       z_err     n_src
# ---------- --------- ---------- --------- --------- ---------- --------- --------- --------- ---------
#  7.000e-01 7.446e-01  7.863e-01 4.359e-02 1.313e-04  2.281e-18 1.091e-18 8.000e-01 2.916e-17 5.800e+01
#  7.863e-01 8.403e-01  8.831e-01 3.990e-02 1.101e-04 -8.510e-19 5.223e-19 8.000e-01 2.394e-17 8.600e+01
#  8.831e-01 9.395e-01  9.920e-01 3.659e-02 1.003e-04 -4.548e-19 4.929e-19 8.000e-01 3.417e-17 9.500e+01
#  9.920e-01 1.052e+00  1.114e+00 3.337e-02 8.507e-05 -1.080e-18 6.037e-19 8.000e-01 1.933e-17 1.320e+02
#  1.114e+00 1.187e+00  1.251e+00 3.007e-02 7.161e-05  1.735e-19 3.541e-19 8.000e-01 1.807e-17 1.510e+02
#  1.251e+00 1.331e+00  1.406e+00 2.711e-02 6.612e-05  9.795e-20 3.436e-19 8.000e-01 1.718e-17 1.670e+02
#  1.406e+00 1.495e+00  1.579e+00 2.428e-02 5.252e-05 -3.614e-19 2.682e-19 8.000e-01 0.000e+00 2.350e+02
#  1.579e+00 1.677e+00  1.773e+00 2.167e-02 3.915e-05 -8.007e-20 1.474e-19 8.000e-01 5.995e-18 3.430e+02
#  1.773e+00 1.887e+00  1.992e+00 1.918e-02 3.437e-05  8.858e-20 1.648e-19 8.000e-01 0.000e+00 4.010e+02
#  1.992e+00 2.119e+00  2.237e+00 1.694e-02 2.755e-05 -6.722e-21 1.131e-19 8.000e-01 0.000e+00 4.990e+02
#  2.237e+00 2.377e+00  2.513e+00 1.490e-02 2.161e-05  4.755e-20 1.037e-19 8.000e-01 8.623e-18 6.630e+02
#  2.513e+00 2.672e+00  2.823e+00 1.302e-02 1.846e-05  1.571e-20 7.415e-20 8.000e-01 0.000e+00 7.800e+02
#  2.823e+00 2.999e+00  3.171e+00 1.136e-02 1.422e-05  5.710e-21 4.879e-20 8.000e-01 0.000e+00 1.042e+03
#  3.171e+00 3.369e+00  3.561e+00 9.847e-03 1.131e-05 -9.008e-21 4.729e-20 8.000e-01 3.078e-18 1.301e+03
#  3.561e+00 3.781e+00  4.000e+00 8.514e-03 8.968e-06  4.905e-20 3.279e-20 8.000e-01 2.738e-18 1.644e+03

# %% [markdown]
# We visualize the radially binned shear for the 3 configurations

# %%
fig = plt.figure(figsize=(10, 6))


fsize = 14
fig.gca().errorbar(profile1['radius'], profile1['gt'], yerr=profile1['gt_err'], marker='o', label='z_src = 0.8')
fig.gca().errorbar(profile2['radius'], profile2['gt'], yerr=profile2['gt_err'], marker='o', 
                   label='z_src = Chang et al. (2013)')
fig.gca().errorbar(profile3['radius'], profile3['gt'], yerr=profile3['gt_err'], marker='o', 
                   label='z_src = Chang et al. (2013) + photoz err  + shape noise')

plt.gca().set_title(r'Binned shear of source galaxies', fontsize=fsize)
plt.gca().set_xlabel(r'$r\;[Mpc]$', fontsize=fsize)
plt.gca().set_ylabel(r'$g_t$', fontsize=fsize)
plt.legend()

# %% [markdown]
# ### Fitting a halo mass - highlighting bias when not accounting for the source redshift distribution in the model

# %% [markdown]
# We estimate the best-fit mass using a simple implementation of the likelihood using a NcmDataGaussDiag object.
#
# Here, to build the model we make the WRONG assumption that the average shear in bin $i$ equals the shear at the average redshift in the bin; i.e. we assume that $\langle g_t\rangle_i = g_t(\langle z\rangle_i)$. This should not impact `cluster 1` as all sources are located at the same redshift. However, this yields a bias in the constructed mass for `cluster 2` and `cluster 3`, where the sources followed the Chang et al. (2013) distribution.

# %% [markdown]
# As expected, the reconstructed mass is biased whenever the sources are not located at a single redshift as this was not accounted for in the model.

# %% [markdown]
# ## Create the halo model
#
# Here we model using the OO inteface, we also use NumCosmo statistical framework to perform the analysis. Below we create an object based on NumCosmo NcmDataGaussDiag (Gaussian likelihood with a diagonal covariance matrix) object. To connect with the C interface the object must implement the methods: `do_get_length`, `do_get_dof`, `do_begin`, `do_prepare` and `do_mean_func`. The last method is responsible to compute the theoretical predictions. In the param_set_ftype calls below one can change between FREE/FIXED to include/exclude the parameter from the analysis.
#
# Remember that here we are building the wrong model.

# %%
class GaussGammaTErr (Ncm.DataGaussDiag):
    z_cluster = GObject.Property (type = float, flags = GObject.PARAM_READWRITE)
    z_source  = GObject.Property (type = Ncm.Vector, flags = GObject.PARAM_READWRITE)
    r_source  = GObject.Property (type = Ncm.Vector, flags = GObject.PARAM_READWRITE)
    z_err     = GObject.Property (type = Ncm.Vector, flags = GObject.PARAM_READWRITE)

    def __init__ (self):
        Ncm.DataGaussDiag.__init__ (self, n_points = 0)        
        self.moo = clmm.Modeling ()
    
    def init_from_data (self, z_cluster, r_source, z_source, gt_profile, gt_err, z_err = None, moo = None):
        
        if moo:
            self.moo = moo
        
        assert len (gt_profile) == len (z_source)
        assert len (gt_profile) == len (r_source)
        assert len (gt_profile) == len (gt_err)
        
        self.set_size (len (gt_profile))
        
        self.props.z_cluster = z_cluster
        self.props.z_source  = Ncm.Vector.new_array (z_source)
        self.props.r_source  = Ncm.Vector.new_array (r_source)
        if z_err:
            self.props.r_source  = Ncm.Vector.new_array (z_err)
                
        self.y.set_array (gt_profile)
        
        self.sigma.set_array (gt_err) # Diagonal covariance matrix: standard deviation values in gt_err.

        
        self.set_init (True)        
    
    # Once the NcmDataGaussDiag is initialized, its parent class variable np is set with the n_points value.
    def do_get_length (self):
        return self.np

    def do_get_dof (self):
        return self.np

    def do_begin (self):
        pass

    def do_prepare (self, mset):
        self.moo.set_mset (mset)
        
    def do_mean_func (self, mset, vp):
        vp.set_array (self.moo.eval_reduced_tangential_shear (self.props.r_source.dup_array (), self.props.z_cluster, self.props.z_source.dup_array ()))
        return

GObject.type_register (GaussGammaTErr)
# Out:
# NcContext.GaussGammaTErr

# %% [markdown]
# Defining the model set (NcmMset), data set (NcmDataset) and NcmLikelihood objects to carry out a statistical analysis.
#
# The method `param_set_ftype` defines the parameters that can be fitted: `mid` - to which model set the parameter belongs to, `pid` - parameters' id, NcmParamType (FREE or FIXED) to say if the parameter will be fitted or not.

# %%
moo1 = clmm.Modeling (massdef = 'mean', delta_mdef = 200, halo_profile_model = 'nfw')
moo1.set_cosmo (cosmo)

moo2 = clmm.Modeling (massdef = 'mean', delta_mdef = 200, halo_profile_model = 'nfw')
moo2.set_cosmo (cosmo)

moo3 = clmm.Modeling (massdef = 'mean', delta_mdef = 200, halo_profile_model = 'nfw')
moo3.set_cosmo (cosmo)

ggt1 = GaussGammaTErr ()
ggt2 = GaussGammaTErr ()
ggt3 = GaussGammaTErr ()

ggt1.init_from_data (z_cluster = cluster_z, r_source = profile1['radius'], z_source = profile1['z'], gt_profile = profile1['gt'], gt_err = profile1['gt_err'], moo = moo1)
ggt2.init_from_data (z_cluster = cluster_z, r_source = profile2['radius'], z_source = profile2['z'], gt_profile = profile2['gt'], gt_err = profile2['gt_err'], moo = moo2)
ggt3.init_from_data (z_cluster = cluster_z, r_source = profile3['radius'], z_source = profile3['z'], gt_profile = profile3['gt'], gt_err = profile3['gt_err'], moo = moo3)

mset1 = ggt1.moo.get_mset ()
mset2 = ggt2.moo.get_mset ()
mset3 = ggt3.moo.get_mset ()

#Parameters: cluster mass (log base 10) and concentration
MDelta_pi = mset1.param_get_by_full_name ("NcHaloDensityProfile:log10MDelta")
cDelta_pi = mset1.param_get_by_full_name ("NcHaloDensityProfile:cDelta")

mset1.param_set_ftype (MDelta_pi.mid, MDelta_pi.pid, Ncm.ParamType.FREE)
mset1.param_set_ftype (cDelta_pi.mid, cDelta_pi.pid, Ncm.ParamType.FREE)
mset1.prepare_fparam_map ()

mset2.param_set_ftype (MDelta_pi.mid, MDelta_pi.pid, Ncm.ParamType.FREE)
mset2.param_set_ftype (cDelta_pi.mid, cDelta_pi.pid, Ncm.ParamType.FREE)
mset2.prepare_fparam_map ()

mset3.param_set_ftype (MDelta_pi.mid, MDelta_pi.pid, Ncm.ParamType.FREE)
mset3.param_set_ftype (cDelta_pi.mid, cDelta_pi.pid, Ncm.ParamType.FREE)
mset3.prepare_fparam_map ()

dset1 = Ncm.Dataset.new ()
dset1.append_data (ggt1)
lh1 = Ncm.Likelihood.new (dset1)

dset2 = Ncm.Dataset.new ()
dset2.append_data (ggt2)
lh2 = Ncm.Likelihood.new (dset2)

dset3 = Ncm.Dataset.new ()
dset3.append_data (ggt3)
lh3 = Ncm.Likelihood.new (dset3)

# %% [markdown]
# ### Fitting parameters: Fisher Matrix
#
# The NcmFit object receives the NcmLikelihood and NcmMset objects. The user also indicates the fitting algorithm and the numerical differentiation method.
# Functions `run` and `fisher` computes the [best-fit](https://en.wikipedia.org/wiki/Maximum_likelihood_estimation) and the [fisher matrix](https://en.wikipedia.org/wiki/Fisher_information#Multivariate_normal_distribution), respectively. `log_info` prints the complete information about the data used, models and its parameters, and `log_covar` prints the best-fit along with the error-bar and the covariance matrix.

# %%
fit1 = Ncm.Fit.new (Ncm.FitType.NLOPT, "ln-neldermead", lh1, mset1, Ncm.FitGradType.NUMDIFF_FORWARD)
fit2 = Ncm.Fit.new (Ncm.FitType.NLOPT, "ln-neldermead", lh2, mset2, Ncm.FitGradType.NUMDIFF_FORWARD)
fit3 = Ncm.Fit.new (Ncm.FitType.NLOPT, "ln-neldermead", lh3, mset3, Ncm.FitGradType.NUMDIFF_FORWARD)

fit1.run (Ncm.FitRunMsgs.SIMPLE)
fit1.fisher ()
fit1.log_info ()
fit1.log_covar ()

fit2.run (Ncm.FitRunMsgs.SIMPLE)
fit2.fisher ()
fit2.log_info ()
fit2.log_covar ()

fit3.run (Ncm.FitRunMsgs.SIMPLE)
fit3.fisher ()
fit3.log_info ()
fit3.log_covar ()
# Out:
# #----------------------------------------------------------------------------------
# # Model fitting. Interating using:
# #  - solver:            NLOpt:ln-neldermead
# #  - differentiation:   Numerical differentiantion (forward)
# #..............
# #  Minimum found with precision: |df|/f =  1.00000e-08 and |dx| =  1.00000e-05
# #  Elapsed time: 00 days, 00:00:00.0181810
# #  iteration            [000056]
# #  function evaluations [000058]
# #  gradient evaluations [000000]
# #  degrees of freedom   [000013]
# #  m2lnL     =   0.0050078633459665 (  0.0050078633 )
# #  Fit parameters:
# #     3.9953235476808      15.0007832361652
# #----------------------------------------------------------------------------------
# # Data used:
# #   - NcContext+GaussGammaTErr
# #----------------------------------------------------------------------------------
# # Model[03000]:
# #   - NcHICosmo : Chevalier-Polarski-Linder parametrization
# #----------------------------------------------------------------------------------
# # Model parameters
# #   -          H0[00]:  70                  [FIXED]
# #   -      Omegac[01]:  0.225               [FIXED]
# #   -      Omegak[02]:  0                   [FIXED]
# #   -     Tgamma0[03]:  2.7255              [FIXED]
# #   -          Yp[04]:  0.24                [FIXED]
# #   -        ENnu[05]:  2.03279837503097    [FIXED]
# #   -      Omegab[06]:  0.045               [FIXED]
# #   -          w0[07]: -1                   [FIXED]
# #   -          w1[08]:  0                   [FIXED]
# #   -    massnu_0[09]:  0.06                [FIXED]
# #   -       Tnu_0[10]:  0.71611             [FIXED]
# #   -      munu_0[11]:  0                   [FIXED]
# #   -       gnu_0[12]:  1                   [FIXED]
# #----------------------------------------------------------------------------------
# # Model[06000]:
# #   - NcHaloDensityProfile : NFW Density Profile
# #----------------------------------------------------------------------------------
# # Model parameters
# #   -      cDelta[00]:  3.9953235476808     [FREE]
# #   - log10MDelta[01]:  15.0007832361652    [FREE]
# #----------------------------------------------------------------------------------
# # Model[10000]:
# #   - NcWLSurfaceMassDensity : WL Surface Mass Density
# #----------------------------------------------------------------------------------
# # Model parameters
# #   -         pcc[00]:  0.8                 [FIXED]
# #   -        Roff[01]:  1                   [FIXED]
# #----------------------------------------------------------------------------------
# # NcmMSet parameters covariance matrix
# #                                                       -------------------------------
# #      cDelta[06000:00] =  3.995       +/-  0.009986    |  1           | -0.4857      |
# # log10MDelta[06000:01] =  15          +/-  0.0003024   | -0.4857      |  1           |
# #                                                       -------------------------------
# #----------------------------------------------------------------------------------
# # Model fitting. Interating using:
# #  - solver:            NLOpt:ln-neldermead
# #  - differentiation:   Numerical differentiantion (forward)
# #...............
# #  Minimum found with precision: |df|/f =  1.00000e-08 and |dx| =  1.00000e-05
# #  Elapsed time: 00 days, 00:00:00.0281210
# #  iteration            [000067]
# #  function evaluations [000069]
# #  gradient evaluations [000000]
# #  degrees of freedom   [000013]
# #  m2lnL     =     2.73659904338731 (      2.736599 )
# #  Fit parameters:
# #     3.81186275355844     14.9400261506675
# #----------------------------------------------------------------------------------
# # Data used:
# #   - NcContext+GaussGammaTErr
# #----------------------------------------------------------------------------------
# # Model[03000]:
# #   - NcHICosmo : Chevalier-Polarski-Linder parametrization
# #----------------------------------------------------------------------------------
# # Model parameters
# #   -          H0[00]:  70                  [FIXED]
# #   -      Omegac[01]:  0.225               [FIXED]
# #   -      Omegak[02]:  0                   [FIXED]
# #   -     Tgamma0[03]:  2.7255              [FIXED]
# #   -          Yp[04]:  0.24                [FIXED]
# #   -        ENnu[05]:  2.03279837503097    [FIXED]
# #   -      Omegab[06]:  0.045               [FIXED]
# #   -          w0[07]: -1                   [FIXED]
# #   -          w1[08]:  0                   [FIXED]
# #   -    massnu_0[09]:  0.06                [FIXED]
# #   -       Tnu_0[10]:  0.71611             [FIXED]
# #   -      munu_0[11]:  0                   [FIXED]
# #   -       gnu_0[12]:  1                   [FIXED]
# #----------------------------------------------------------------------------------
# # Model[06000]:
# #   - NcHaloDensityProfile : NFW Density Profile
# #----------------------------------------------------------------------------------
# # Model parameters
# #   -      cDelta[00]:  3.81186275355844    [FREE]
# #   - log10MDelta[01]:  14.9400261506675    [FREE]
# #----------------------------------------------------------------------------------
# # Model[10000]:
# #   - NcWLSurfaceMassDensity : WL Surface Mass Density
# #----------------------------------------------------------------------------------
# # Model parameters
# #   -         pcc[00]:  0.8                 [FIXED]
# #   -        Roff[01]:  1                   [FIXED]
# #----------------------------------------------------------------------------------
# # NcmMSet parameters covariance matrix
# #                                                       -------------------------------
# #      cDelta[06000:00] =  3.812       +/-  0.07122     |  1           | -0.2998      |
# # log10MDelta[06000:01] =  14.94       +/-  0.001694    | -0.2998      |  1           |
# #                                                       -------------------------------
# #----------------------------------------------------------------------------------
# # Model fitting. Interating using:
# #  - solver:            NLOpt:ln-neldermead
# #  - differentiation:   Numerical differentiantion (forward)
# #..................
# #  Minimum found with precision: |df|/f =  1.00000e-08 and |dx| =  1.00000e-05
# #  Elapsed time: 00 days, 00:00:00.0497140
# #  iteration            [000094]
# #  function evaluations [000096]
# #  gradient evaluations [000000]
# #  degrees of freedom   [000013]
# #  m2lnL     =     13.0788414638129 (     13.078841 )
# #  Fit parameters:
# #     5.01279804519566     14.9200745554864
# #----------------------------------------------------------------------------------
# # Data used:
# #   - NcContext+GaussGammaTErr
# #----------------------------------------------------------------------------------
# # Model[03000]:
# #   - NcHICosmo : Chevalier-Polarski-Linder parametrization
# #----------------------------------------------------------------------------------
# # Model parameters
# #   -          H0[00]:  70                  [FIXED]
# #   -      Omegac[01]:  0.225               [FIXED]
# #   -      Omegak[02]:  0                   [FIXED]
# #   -     Tgamma0[03]:  2.7255              [FIXED]
# #   -          Yp[04]:  0.24                [FIXED]
# #   -        ENnu[05]:  2.03279837503097    [FIXED]
# #   -      Omegab[06]:  0.045               [FIXED]
# #   -          w0[07]: -1                   [FIXED]
# #   -          w1[08]:  0                   [FIXED]
# #   -    massnu_0[09]:  0.06                [FIXED]
# #   -       Tnu_0[10]:  0.71611             [FIXED]
# #   -      munu_0[11]:  0                   [FIXED]
# #   -       gnu_0[12]:  1                   [FIXED]
# #----------------------------------------------------------------------------------
# # Model[06000]:
# #   - NcHaloDensityProfile : NFW Density Profile
# #----------------------------------------------------------------------------------
# # Model parameters
# #   -      cDelta[00]:  5.01279804519566    [FREE]
# #   - log10MDelta[01]:  14.9200745554864    [FREE]
# #----------------------------------------------------------------------------------
# # Model[10000]:
# #   - NcWLSurfaceMassDensity : WL Surface Mass Density
# #----------------------------------------------------------------------------------
# # Model parameters
# #   -         pcc[00]:  0.8                 [FIXED]
# #   -        Roff[01]:  1                   [FIXED]
# #----------------------------------------------------------------------------------
# # NcmMSet parameters covariance matrix
# #                                                       -------------------------------
# #      cDelta[06000:00] =  5.013       +/-  0.8138      |  1           | -0.7302      |
# # log10MDelta[06000:01] =  14.92       +/-  0.02721     | -0.7302      |  1           |
# #                                                       -------------------------------

# %% [markdown]
# ## Visualization of the results
#
# For visualization purpose, we calculate the reduced tangential shear predicted by the model when using the average redshift of the catalog.

# %%
rr = np.logspace(-0.5, np.log10(5), 100)

gt_model1 = moo1.eval_reduced_tangential_shear (rr, cluster_z, np.mean(cl1.galcat['z']))
gt_model2 = moo2.eval_reduced_tangential_shear (rr, cluster_z, np.mean(cl2.galcat['z']))
gt_model3 = moo3.eval_reduced_tangential_shear (rr, cluster_z, np.mean(cl3.galcat['z']))

m_est1 = 10**mset1.param_get (MDelta_pi.mid, MDelta_pi.pid)
m_est2 = 10**mset2.param_get (MDelta_pi.mid, MDelta_pi.pid)
m_est3 = 10**mset3.param_get (MDelta_pi.mid, MDelta_pi.pid)

# Standard deviation
m_est_err1 = fit1.covar_sd (MDelta_pi.mid, MDelta_pi.pid) * m_est1 * math.log (10.0)
m_est_err2 = fit2.covar_sd (MDelta_pi.mid, MDelta_pi.pid) * m_est2 * math.log (10.0)
m_est_err3 = fit3.covar_sd (MDelta_pi.mid, MDelta_pi.pid) * m_est3 * math.log (10.0)

print ("% 22.15e +/- %.0e % 22.15e +/- %.0e % 22.15e +/- %.0e" % (m_est1, m_est_err1, m_est2, m_est_err2, m_est3, m_est_err3))
# Out:
#  1.001805095144565e+15 +/- 7e+11  8.710160358560778e+14 +/- 3e+12  8.319065725386354e+14 +/- 5e+13

# %% [markdown]
# We visualize that prediction of reduced tangential shears along with the data

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(16, 6))

axes[0].errorbar(profile1['radius'], profile1['gt'],profile1['gt_err'], color='red',
                 label='ideal_data, M_input = %.3e Msun' % cluster_m, fmt='.')
axes[0].plot(rr, gt_model1,color='red',
             label='best fit model 1, M_fit = %.2e +/- %.2e' % (m_est1, m_est_err1))


axes[0].errorbar(profile2['radius'], profile2['gt'],profile2['gt_err'], color='green',
                  label='ideal_data_z, M_input = %.3e Msun' % cluster_m, fmt='.')
axes[0].plot(rr, gt_model2, color='green',
               label='best fit model 2, M_fit = %.2e +/- %.2e' % (m_est2, m_est_err2))
axes[0].set_title('Ideal data w/wo src redshift distribution',fontsize=fsize)
axes[0].semilogx()
axes[0].semilogy()
axes[0].legend(fontsize=fsize)
axes[0].set_xlabel('R [Mpc]', fontsize=fsize)
axes[0].set_ylabel('reduced tangential shear', fontsize=fsize)

axes[1].errorbar(profile3['radius'], profile3['gt'],profile3['gt_err'], color='red',
                label='noisy_data_z, M_input = %.3e Msun' % cluster_m, fmt='.')
axes[1].plot(rr, gt_model3,color='red',
             label='best fit model 3, M_fit = %.2e +/- %.2e' % (m_est3, m_est_err3))
axes[1].set_title('Noisy data with src redshift distribution',fontsize=fsize)
axes[1].semilogx()
axes[1].semilogy()
axes[1].legend(fontsize=fsize)
axes[1].set_xlabel('R [Mpc]', fontsize=fsize)
axes[1].set_ylabel('reduced tangential shear', fontsize=fsize)

fig.tight_layout()

# %% [markdown]
# ### To investigate further the results we make a MCMC analysis below.
#
# We begin by specifying if the run is single- or multi-thread: `func_eval_set_max_threads` sets the maximum number of threads, and `func_eval_log_pool_stats` prints the information about the thread pool.
#
# Then, we initialize the transition kernel object (NcmMSetTransKern) which defines the distribution of the initial points of the parameter space to be used by the ensemble sampler. In this example we use the Gaussian transition kernel (NcmMSetTransKernGauss), with priors provided by the NcmMset (`set_prior_from_mset`). `set_cov_from_rescale` sets the covariance matrix with zero correlation and the diagonal terms defined by the scale of each parameter times the argument of `set_cov_from_rescale`.
#
# Here we use the Ensemble Sampler MCMC (ESMCMC) method. `nwalkers` and `walker` define the number of walkers and the algorithm used to move the points in the ensemble.
# Running: `start_run`, `run_lre` and `end_run`. `run_lre` runs the ESMCMC until the relative error of the mean of each parameter is smaller than $10^{-3}$. Its first argument (integer) indicates how many ensembles are computed before applying any convergence test.
#
# In the end we save the catalog to mcat_wrong to compare with a correct analysis.

# %%
Ncm.func_eval_set_max_threads (0)
Ncm.func_eval_log_pool_stats ()

init_sampler = Ncm.MSetTransKernGauss.new (0)
init_sampler.set_mset (mset3)
init_sampler.set_prior_from_mset ()
init_sampler.set_cov_from_rescale (1.0e-1)

nwalkers = 800 # Number of walkers
walker = Ncm.FitESMCMCWalkerAPES.new (nwalkers, mset3.fparams_len ())

# Ensemble Sampler MCMC
esmcmc  = Ncm.FitESMCMC.new (fit3, nwalkers, init_sampler, walker, Ncm.FitRunMsgs.SIMPLE)
esmcmc.set_data_file ("example2_fit3_wrong_esmcmc_out_aps.fits")
esmcmc.set_auto_trim (True)            # Detect and discard the burn-in points.
esmcmc.set_auto_trim_div (100)
esmcmc.set_max_runs_time (2.0 * 60.0)  # Maximum time between tests.

esmcmc.start_run ()
esmcmc.run_lre (20, 1.0e-3)
esmcmc.end_run ()

mcat_wrong = esmcmc.peek_catalog ()
# Out:
# # NcmThreadPool:Unused:      0
# # NcmThreadPool:Max Unused:  2
# # NcmThreadPool:Running:     0
# # NcmThreadPool:Unprocessed: 0
# # NcmThreadPool:Unused:      0
# #----------------------------------------------------------------------------------
# # NcmFitESMCMC: Starting Ensamble Sampler Markov Chain Monte Carlo.
# #   Number of walkers: 0800.
# #   Number of threads: 0000.
# # NcmFitESMCMC: No RNG was defined, using algorithm: `mt19937' and seed: 1123225249.
# # NcmMSetCatalog: Current mean:   20.746       5.0129       14.923
# # NcmMSetCatalog: Current msd:    0.42201      0.00034719   0.0018021
# # NcmMSetCatalog: Current sd:     11.936       0.0098201    0.050971
# # NcmMSetCatalog: Current var:    142.47       9.6435e-05   0.0025981
# # NcmMSetCatalog: Current tau:    1            1            1
# # NcmMSetCatalog: Current skfac: -nan         -nan         -nan
# # NcmMSetCatalog: Maximal Shrink factor = 1e+10
# #----------------------------------------------------------------------------------
# # NcmMSetCatalog: Computing the constant break point for parameter `0', sample size `1':
# # NcmMSetCatalog: Constant break point at `0':
# # NcmFitESMCMC:last ensemble variance of -2ln(L):       142.610422462308 (2n = 4), min(-2ln(L)) =       13.0788921934974.
# # Task:NcmFitESMCMC, completed: 800 of 800, elapsed time: 00:00:00.3098
# # Task:NcmFitESMCMC, mean time: 00:00:00.0003 +/- 00:00:00.0003
# # Task:NcmFitESMCMC, time left: 00:00:00.0000 +/- 00:00:00.0000
# # Task:NcmFitESMCMC, current time:        Mon Sep 13 2021, 14:01:21
# # Task:NcmFitESMCMC, estimated to end at: Mon Sep 13 2021, 14:01:21 +/- 00:00:00.0000
# # NcmFitESMCMC: Running first 99 pre-runs...
# #----------------------------------------------------------------------------------
# # NcmFitESMCMC: Calculating [000099] Ensemble Sampler Markov Chain Monte Carlo runs [APES-Move:VKDE:Cauchy]
# # Task:NcmFitESMCMC, started at: Mon Sep 13 2021, 14:01:21
# # NcmMSetCatalog: Current mean:   15.514       5.1996       14.917
# # NcmMSetCatalog: Current msd:    0.032803     0.0064492    0.00023789
# # NcmMSetCatalog: Current sd:     4.0443       0.79511      0.029329
# # NcmMSetCatalog: Current var:    16.356       0.63219      0.00086018
# # NcmMSetCatalog: Current tau:    1            1            1
# # NcmMSetCatalog: Current skfac:  1.0189       1.0214       1.0203
# # NcmMSetCatalog: Maximal Shrink factor = 1.02171
# #----------------------------------------------------------------------------------
# # NcmMSetCatalog: Computing the constant break point for parameter `0', sample size `19':
# # NcmMSetCatalog: Constant break point at `3':
# # NcmFitESMCMC:acceptance ratio 69.7083% (last update 70.8750%), offboard ratio  0.0000% (last update  0.0000%).
# # NcmFitESMCMC:last ensemble variance of -2ln(L):       5.24697091169199 (2n = 4), min(-2ln(L)) =       13.0788440418054.
# # Task:NcmFitESMCMC, completed: 15200 of 80000, elapsed time: 00:00:02.8736
# # Task:NcmFitESMCMC, mean time: 00:00:00.0002 +/- 00:00:00.0000
# # Task:NcmFitESMCMC, time left: 00:00:12.0105 +/- 00:00:02.8171
# # Task:NcmFitESMCMC, current time:        Mon Sep 13 2021, 14:01:24
# # Task:NcmFitESMCMC, estimated to end at: Mon Sep 13 2021, 14:01:36 +/- 00:00:02.8171
# # NcmMSetCatalog: Current mean:   15.327       5.2304       14.916
# # NcmMSetCatalog: Current msd:    0.018451     0.0048101    0.00016225
# # NcmMSetCatalog: Current sd:     3.2171       0.83867      0.028289
# # NcmMSetCatalog: Current var:    10.35        0.70337      0.00080025
# # NcmMSetCatalog: Current tau:    1            1            1
# # NcmMSetCatalog: Current skfac:  1.009        1.0094       1.0089
# # NcmMSetCatalog: Maximal Shrink factor = 1.00972
# #----------------------------------------------------------------------------------
# # NcmMSetCatalog: Computing the constant break point for parameter `0', sample size `38':
# # NcmMSetCatalog: Constant break point at `3':
# # NcmFitESMCMC:acceptance ratio 70.7128% (last update 71.3750%), offboard ratio  0.0000% (last update  0.0000%).
# # NcmFitESMCMC:last ensemble variance of -2ln(L):       3.65589403220732 (2n = 4), min(-2ln(L)) =       13.0788440418054.
# # Task:NcmFitESMCMC, completed: 30400 of 80000, elapsed time: 00:00:05.5496
# # Task:NcmFitESMCMC, mean time: 00:00:00.0002 +/- 00:00:00.0000
# # Task:NcmFitESMCMC, time left: 00:00:08.9811 +/- 00:00:01.4765
# # Task:NcmFitESMCMC, current time:        Mon Sep 13 2021, 14:01:27
# # Task:NcmFitESMCMC, estimated to end at: Mon Sep 13 2021, 14:01:36 +/- 00:00:01.4765
# # NcmMSetCatalog: Current mean:   15.269       5.2452       14.916
# # NcmMSetCatalog: Current msd:    0.013562     0.0040033    0.00013096
# # NcmMSetCatalog: Current sd:     2.8961       0.85486      0.027966
# # NcmMSetCatalog: Current var:    8.3875       0.73079      0.00078209
# # NcmMSetCatalog: Current tau:    1            1            1
# # NcmMSetCatalog: Current skfac:  1.0068       1.0055       1.0052
# # NcmMSetCatalog: Maximal Shrink factor = 1.00627
# #----------------------------------------------------------------------------------
# # NcmMSetCatalog: Computing the constant break point for parameter `0', sample size `57':
# # NcmMSetCatalog: Constant break point at `3':
# # NcmFitESMCMC:acceptance ratio 71.1696% (last update 69.1250%), offboard ratio  0.0000% (last update  0.0000%).
# # NcmFitESMCMC:last ensemble variance of -2ln(L):       3.76996750494484 (2n = 4), min(-2ln(L)) =       13.0788440418054.
# # Task:NcmFitESMCMC, completed: 45600 of 80000, elapsed time: 00:00:08.1982
# # Task:NcmFitESMCMC, mean time: 00:00:00.0002 +/- 00:00:00.0000
# # Task:NcmFitESMCMC, time left: 00:00:06.1499 +/- 00:00:00.8229
# # Task:NcmFitESMCMC, current time:        Mon Sep 13 2021, 14:01:29
# # Task:NcmFitESMCMC, estimated to end at: Mon Sep 13 2021, 14:01:35 +/- 00:00:00.8229
# # NcmMSetCatalog: Current mean:   15.239       5.2531       14.915
# # NcmMSetCatalog: Current msd:    0.010977     0.003497     0.00011248
# # NcmMSetCatalog: Current sd:     2.7066       0.86227      0.027735
# # NcmMSetCatalog: Current var:    7.3254       0.7435       0.00076924
# # NcmMSetCatalog: Current tau:    1            1            1
# # NcmMSetCatalog: Current skfac:  1.0055       1.0042       1.0042
# # NcmMSetCatalog: Maximal Shrink factor = 1.0042
# #----------------------------------------------------------------------------------
# # NcmMSetCatalog: Computing the constant break point for parameter `0', sample size `76':
# # NcmMSetCatalog: Constant break point at `3':
# # NcmFitESMCMC:acceptance ratio 71.2383% (last update 70.6250%), offboard ratio  0.0000% (last update  0.0000%).
# # NcmFitESMCMC:last ensemble variance of -2ln(L):         4.468194796596 (2n = 4), min(-2ln(L)) =       13.0788440418054.
# # Task:NcmFitESMCMC, completed: 60800 of 80000, elapsed time: 00:00:10.8486
# # Task:NcmFitESMCMC, mean time: 00:00:00.0002 +/- 00:00:00.0000
# # Task:NcmFitESMCMC, time left: 00:00:03.4165 +/- 00:00:00.3953
# # Task:NcmFitESMCMC, current time:        Mon Sep 13 2021, 14:01:32
# # Task:NcmFitESMCMC, estimated to end at: Mon Sep 13 2021, 14:01:35 +/- 00:00:00.3953
# # NcmMSetCatalog: Current mean:   15.224       5.2587       14.915
# # NcmMSetCatalog: Current msd:    0.0093856    0.0031539    0.00010029
# # NcmMSetCatalog: Current sd:     2.5874       0.86946      0.027647
# # NcmMSetCatalog: Current var:    6.6947       0.75596      0.00076438
# # NcmMSetCatalog: Current tau:    1            1            1
# # NcmMSetCatalog: Current skfac:  1.0044       1.0037       1.0031
# # NcmMSetCatalog: Maximal Shrink factor = 1.00373
# #----------------------------------------------------------------------------------
# # NcmMSetCatalog: Computing the constant break point for parameter `0', sample size `95':
# # NcmMSetCatalog: Constant break point at `3':
# # NcmFitESMCMC:acceptance ratio 71.2261% (last update 72.2500%), offboard ratio  0.0000% (last update  0.0000%).
# # NcmFitESMCMC:last ensemble variance of -2ln(L):       4.14454648473848 (2n = 4), min(-2ln(L)) =       13.0788440418054.
# # Task:NcmFitESMCMC, completed: 76000 of 80000, elapsed time: 00:00:13.5022
# # Task:NcmFitESMCMC, mean time: 00:00:00.0002 +/- 00:00:00.0000
# # Task:NcmFitESMCMC, time left: 00:00:00.7083 +/- 00:00:00.0732
# # Task:NcmFitESMCMC, current time:        Mon Sep 13 2021, 14:01:35
# # Task:NcmFitESMCMC, estimated to end at: Mon Sep 13 2021, 14:01:35 +/- 00:00:00.0732
# # NcmMSetCatalog: Current mean:   15.22        5.2589       14.915
# # NcmMSetCatalog: Current msd:    0.0090651    0.0030754    9.7664e-05
# # NcmMSetCatalog: Current sd:     2.564        0.86986      0.027624
# # NcmMSetCatalog: Current var:    6.5741       0.75665      0.00076307
# # NcmMSetCatalog: Current tau:    1            1            1
# # NcmMSetCatalog: Current skfac:  1.0042       1.0035       1.003
# # NcmMSetCatalog: Maximal Shrink factor = 1.00353
# #----------------------------------------------------------------------------------
# # NcmMSetCatalog: Computing the constant break point for parameter `0', sample size `100':
# # NcmMSetCatalog: Constant break point at `3':
# # NcmFitESMCMC:acceptance ratio 71.3093% (last update 72.1250%), offboard ratio  0.0000% (last update  0.0000%).
# # NcmFitESMCMC:last ensemble variance of -2ln(L):       4.64989172513497 (2n = 4), min(-2ln(L)) =       13.0788440418054.
# # Task:NcmFitESMCMC, completed: 80000 of 80000, elapsed time: 00:00:14.2430
# # Task:NcmFitESMCMC, mean time: 00:00:00.0002 +/- 00:00:00.0000
# # Task:NcmFitESMCMC, time left: 00:00:00.0000 +/- 00:00:00.0000
# # Task:NcmFitESMCMC, current time:        Mon Sep 13 2021, 14:01:35
# # Task:NcmFitESMCMC, estimated to end at: Mon Sep 13 2021, 14:01:35 +/- 00:00:00.0000
# #----------------------------------------------------------------------------------
# # NcmMSetCatalog: Calculating catalog effective sample size from chain 100 => 0 using 100 blocks:
# # NcmMSetCatalog: - best cutoff time:         0
# # NcmMSetCatalog: - total number of points:   100  (80000)
# # NcmMSetCatalog: - number of points left:    100  (80000)
# # NcmMSetCatalog: - worst parameter:          NcHaloDensityProfile:cDelta[01]
# # NcmMSetCatalog: - worst parameter ess:      14.01
# # NcmMSetCatalog: - worst parameter ar order: 1
# # NcmMSetCatalog: - ess's:                    56.20 14.01 23.59
# # NcmFitESMCMC: Largest relative error 1.000000e-03 not attained: 1.562517e-03
# # NcmFitESMCMC: ln (eVol) =      -2.17887637599315; ln (gVol) =      -2.08364973982762; lnNorm =      -8.87442877509967
# # NcmFitESMCMC: Running more 15 runs...
# #----------------------------------------------------------------------------------
# # NcmFitESMCMC: Calculating [000015] Ensemble Sampler Markov Chain Monte Carlo runs [APES-Move:VKDE:Cauchy]
# # Task:NcmFitESMCMC, started at: Mon Sep 13 2021, 14:01:21
# # NcmMSetCatalog: Current mean:   15.219       5.2582       14.915
# # NcmMSetCatalog: Current msd:    0.011934     0.0081342    0.00019914
# # NcmMSetCatalog: Current sd:     2.5556       0.86965      0.02763
# # NcmMSetCatalog: Current var:    6.5311       0.7563       0.00076344
# # NcmMSetCatalog: Current tau:    1.7794       7.1388       4.2388
# # NcmMSetCatalog: Current skfac:  1.004        1.0033       1.0029
# # NcmMSetCatalog: Maximal Shrink factor = 1.00337
# #----------------------------------------------------------------------------------
# # NcmMSetCatalog: Computing the constant break point for parameter `0', sample size `102':
# # NcmMSetCatalog: Constant break point at `3':
# # NcmFitESMCMC:acceptance ratio 71.3131% (last update 70.2500%), offboard ratio  0.0000% (last update  0.0000%).
# # NcmFitESMCMC:last ensemble variance of -2ln(L):       4.05128502554751 (2n = 4), min(-2ln(L)) =       13.0788440418054.
# # Task:NcmFitESMCMC, completed: 81600 of 92000, elapsed time: 00:00:14.5755
# # Task:NcmFitESMCMC, mean time: 00:00:00.0002 +/- 00:00:00.0000
# # Task:NcmFitESMCMC, time left: 00:00:01.8522 +/- 00:00:00.1848
# # Task:NcmFitESMCMC, current time:        Mon Sep 13 2021, 14:01:36
# # Task:NcmFitESMCMC, estimated to end at: Mon Sep 13 2021, 14:01:38 +/- 00:00:00.1848
# # NcmMSetCatalog: Current mean:   15.219       5.2582       14.915
# # NcmMSetCatalog: Current msd:    0.011713     0.0080234    0.00019624
# # NcmMSetCatalog: Current sd:     2.5448       0.87033      0.027625
# # NcmMSetCatalog: Current var:    6.476        0.75748      0.00076312
# # NcmMSetCatalog: Current tau:    1.7794       7.1388       4.2388
# # NcmMSetCatalog: Current skfac:  1.004        1.0034       1.0029
# # NcmMSetCatalog: Maximal Shrink factor = 1.00341
# #----------------------------------------------------------------------------------
# # NcmMSetCatalog: Computing the constant break point for parameter `0', sample size `105':
# # NcmMSetCatalog: Constant break point at `3':
# # NcmFitESMCMC:acceptance ratio 71.3269% (last update 71.8750%), offboard ratio  0.0000% (last update  0.0000%).
# # NcmFitESMCMC:last ensemble variance of -2ln(L):       3.99803328275948 (2n = 4), min(-2ln(L)) =       13.0788440418054.
# # Task:NcmFitESMCMC, completed: 84000 of 92000, elapsed time: 00:00:15.0582
# # Task:NcmFitESMCMC, mean time: 00:00:00.0002 +/- 00:00:00.0000
# # Task:NcmFitESMCMC, time left: 00:00:01.4302 +/- 00:00:00.1408
# # Task:NcmFitESMCMC, current time:        Mon Sep 13 2021, 14:01:36
# # Task:NcmFitESMCMC, estimated to end at: Mon Sep 13 2021, 14:01:38 +/- 00:00:00.1408
# # NcmMSetCatalog: Current mean:   15.217       5.2578       14.915
# # NcmMSetCatalog: Current msd:    0.0115       0.0079121    0.00019345
# # NcmMSetCatalog: Current sd:     2.5341       0.87043      0.027619
# # NcmMSetCatalog: Current var:    6.4218       0.75765      0.00076283
# # NcmMSetCatalog: Current tau:    1.7794       7.1388       4.2388
# # NcmMSetCatalog: Current skfac:  1.0041       1.0033       1.0027
# # NcmMSetCatalog: Maximal Shrink factor = 1.00338
# #----------------------------------------------------------------------------------
# # NcmMSetCatalog: Computing the constant break point for parameter `0', sample size `108':
# # NcmMSetCatalog: Constant break point at `3':
# # NcmFitESMCMC:acceptance ratio 71.3329% (last update 70.8750%), offboard ratio  0.0000% (last update  0.0000%).
# # NcmFitESMCMC:last ensemble variance of -2ln(L):       5.12454912285937 (2n = 4), min(-2ln(L)) =       13.0788440418054.
# # Task:NcmFitESMCMC, completed: 86400 of 92000, elapsed time: 00:00:15.5254
# # Task:NcmFitESMCMC, mean time: 00:00:00.0002 +/- 00:00:00.0000
# # Task:NcmFitESMCMC, time left: 00:00:01.0037 +/- 00:00:00.0974
# # Task:NcmFitESMCMC, current time:        Mon Sep 13 2021, 14:01:37
# # Task:NcmFitESMCMC, estimated to end at: Mon Sep 13 2021, 14:01:38 +/- 00:00:00.0974
# # NcmMSetCatalog: Current mean:   15.216       5.2582       14.915
# # NcmMSetCatalog: Current msd:    0.011296     0.0078091    0.00019072
# # NcmMSetCatalog: Current sd:     2.5234       0.87096      0.027605
# # NcmMSetCatalog: Current var:    6.3673       0.75857      0.00076203
# # NcmMSetCatalog: Current tau:    1.7794       7.1388       4.2388
# # NcmMSetCatalog: Current skfac:  1.004        1.0031       1.0026
# # NcmMSetCatalog: Maximal Shrink factor = 1.00325
# #----------------------------------------------------------------------------------
# # NcmMSetCatalog: Computing the constant break point for parameter `0', sample size `111':
# # NcmMSetCatalog: Constant break point at `3':
# # NcmFitESMCMC:acceptance ratio 71.3500% (last update 71.2500%), offboard ratio  0.0000% (last update  0.0000%).
# # NcmFitESMCMC:last ensemble variance of -2ln(L):       3.65112622694923 (2n = 4), min(-2ln(L)) =       13.0788440418054.
# # Task:NcmFitESMCMC, completed: 88800 of 92000, elapsed time: 00:00:15.9865
# # Task:NcmFitESMCMC, mean time: 00:00:00.0002 +/- 00:00:00.0000
# # Task:NcmFitESMCMC, time left: 00:00:00.5750 +/- 00:00:00.0551
# # Task:NcmFitESMCMC, current time:        Mon Sep 13 2021, 14:01:37
# # Task:NcmFitESMCMC, estimated to end at: Mon Sep 13 2021, 14:01:38 +/- 00:00:00.0551
# # NcmMSetCatalog: Current mean:   15.214       5.2582       14.915
# # NcmMSetCatalog: Current msd:    0.0111       0.0077068    0.00018811
# # NcmMSetCatalog: Current sd:     2.5128       0.87108      0.027592
# # NcmMSetCatalog: Current var:    6.3143       0.75878      0.0007613
# # NcmMSetCatalog: Current tau:    1.7794       7.1388       4.2388
# # NcmMSetCatalog: Current skfac:  1.0039       1.003        1.0026
# # NcmMSetCatalog: Maximal Shrink factor = 1.00307
# #----------------------------------------------------------------------------------
# # NcmMSetCatalog: Computing the constant break point for parameter `0', sample size `114':
# # NcmMSetCatalog: Constant break point at `3':
# # NcmFitESMCMC:acceptance ratio 71.3783% (last update 73.0000%), offboard ratio  0.0000% (last update  0.0000%).
# # NcmFitESMCMC:last ensemble variance of -2ln(L):       4.96485292463968 (2n = 4), min(-2ln(L)) =       13.0788440418054.
# # Task:NcmFitESMCMC, completed: 91200 of 92000, elapsed time: 00:00:16.4538
# # Task:NcmFitESMCMC, mean time: 00:00:00.0002 +/- 00:00:00.0000
# # Task:NcmFitESMCMC, time left: 00:00:00.1441 +/- 00:00:00.0136
# # Task:NcmFitESMCMC, current time:        Mon Sep 13 2021, 14:01:38
# # Task:NcmFitESMCMC, estimated to end at: Mon Sep 13 2021, 14:01:38 +/- 00:00:00.0136
# # NcmMSetCatalog: Current mean:   15.214       5.258        14.915
# # NcmMSetCatalog: Current msd:    0.011034     0.0076756    0.00018731
# # NcmMSetCatalog: Current sd:     2.5089       0.87135      0.027595
# # NcmMSetCatalog: Current var:    6.2947       0.75924      0.00076146
# # NcmMSetCatalog: Current tau:    1.7794       7.1388       4.2388
# # NcmMSetCatalog: Current skfac:  1.0039       1.003        1.0026
# # NcmMSetCatalog: Maximal Shrink factor = 1.00307
# #----------------------------------------------------------------------------------
# # NcmMSetCatalog: Computing the constant break point for parameter `0', sample size `115':
# # NcmMSetCatalog: Constant break point at `3':
# # NcmFitESMCMC:acceptance ratio 71.3947% (last update 73.2500%), offboard ratio  0.0000% (last update  0.0000%).
# # NcmFitESMCMC:last ensemble variance of -2ln(L):       4.06882682602185 (2n = 4), min(-2ln(L)) =       13.0788440418054.
# # Task:NcmFitESMCMC, completed: 92000 of 92000, elapsed time: 00:00:16.6588
# # Task:NcmFitESMCMC, mean time: 00:00:00.0002 +/- 00:00:00.0000
# # Task:NcmFitESMCMC, time left: 00:00:00.0000 +/- 00:00:00.0000
# # Task:NcmFitESMCMC, current time:        Mon Sep 13 2021, 14:01:38
# # Task:NcmFitESMCMC, estimated to end at: Mon Sep 13 2021, 14:01:38 +/- 00:00:00.0000
# #----------------------------------------------------------------------------------
# # NcmMSetCatalog: Calculating catalog effective sample size from chain 115 => 0 using 100 blocks:
# # NcmMSetCatalog: - best cutoff time:         12
# # NcmMSetCatalog: - total number of points:   115  (92000)
# # NcmMSetCatalog: - number of points left:    103  (82400)
# # NcmMSetCatalog: - worst parameter:          NcmFit:m2lnL[00]
# # NcmMSetCatalog: - worst parameter ess:      54.77
# # NcmMSetCatalog: - worst parameter ar order: 1
# # NcmMSetCatalog: - ess's:                    54.77 82.03 63.59
# # NcmMSetCatalog: Trimming the catalog at: 12.
# #----------------------------------------------------------------------------------
# # NcmFitESMCMC: Largest relative error 1.000000e-03 attained: 6.573205e-04
# # NcmMSetCatalog: Current mean:   15.155       5.2707       14.915
# # NcmMSetCatalog: Current msd:    0.0099037    0.0034645    0.00012078
# # NcmMSetCatalog: Current sd:     2.0727       0.88711      0.027228
# # NcmMSetCatalog: Current var:    4.2962       0.78696      0.00074137
# # NcmMSetCatalog: Current tau:    1.8812       1.2568       1.6215

# %% [markdown]
# ## Correct non- projected model
#
# Here, instead of building an object directly on top of NcmDataGauss*, we use NumCosmo's framework to build non-binned likelihood for weak-lensing cluster analysis.
#
# For that we need two objects: a NcGalaxyWLReducedShearGauss that model a Gaussian distributed reduced shear likelihood, here the observables matrix is simply $(r, \gamma_t, \sigma_{\gamma_t})$ for each galaxy. If the data has spectroscopic redshifts then we use NcGalaxyRedshiftSpec with an array of real redshifts. When photometric errors are included we use the NcGalaxyRedshiftGauss object that receives $(z, \sigma_z)$ for each galaxy.
#
# Once we have the data objects ready we can proceed as in the previous examples.

# %%
def create_nc_data_cluster_wl (theta, g_t, z_source, z_cluster, cosmo, dist, sigma_z = None, sigma_g = None):
    r  = clmm.convert_units (theta, "radians", "Mpc", redshift = z_cluster, cosmo = cosmo)
    ga = Ncm.ObjArray.new ()
    
    sigma_g = 1.0e-4 if not sigma_g else sigma_g
    m_obs = np.column_stack ((r, g_t, np.repeat (sigma_g, len (r))))
    
    grsg = Nc.GalaxyWLReducedShearGauss (pos = Nc.GalaxyWLReducedShearGaussPos.R)
    grsg.set_obs (Ncm.Matrix.new_array (m_obs.flatten (), 3))
    
    if sigma_z:
        gzgs = Nc.GalaxyRedshiftGauss ()
        z_obs = np.column_stack ((z_source, (1.0 + z_source) * sigma_z))
        gzgs.set_obs (Ncm.Matrix.new_array (z_obs.flatten (), 2))
    else:
        gzgs = Nc.GalaxyRedshiftSpec ()
        gzgs.set_z (Ncm.Vector.new_array (z_source))

    gwl  = Nc.GalaxyWL (wl_dist = grsg, gz_dist = gzgs)
    ga.add (gwl)

    nc_dcwl = Nc.DataClusterWL (galaxy_array = ga, z_cluster = z_cluster)
    nc_dcwl.set_init (True)
    
    return nc_dcwl

def create_fit_obj (data_array, mset):
    dset = Ncm.Dataset.new ()
    for data in data_array:
        dset.append_data (data)
    lh = Ncm.Likelihood.new (dset)
    fit = Ncm.Fit.new (Ncm.FitType.NLOPT, "ln-neldermead", lh, mset, Ncm.FitGradType.NUMDIFF_FORWARD)
    #fit.set_params_reltol (1.0e-8)
    #fit.set_m2lnL_reltol (1.0e-11)
    
    return fit

ggt1 = create_nc_data_cluster_wl (theta1, g_t1, cl1.galcat['z'], cluster_z, cosmo, cosmo.dist, sigma_z = None, sigma_g = None)
ggt2 = create_nc_data_cluster_wl (theta2, g_t2, cl2.galcat['z'], cluster_z, cosmo, cosmo.dist, sigma_z = None, sigma_g = None)
ggt3 = create_nc_data_cluster_wl (theta3, g_t3, cl3.galcat['z'], cluster_z, cosmo, cosmo.dist, sigma_z = 0.05, sigma_g = 0.05)

# %% [markdown]
# As the likelihood is not Gaussian, here we compute the [Observed Fisher Matrix](https://en.wikipedia.org/wiki/Observed_information) (`obs_fisher`).

# %%
fit1 = create_fit_obj ([ggt1], mset1)
fit2 = create_fit_obj ([ggt2], mset2)
fit3 = create_fit_obj ([ggt3], mset3)

fit1.run (Ncm.FitRunMsgs.SIMPLE)
fit1.obs_fisher ()
fit1.log_covar ()

fit2.run (Ncm.FitRunMsgs.SIMPLE)
fit2.obs_fisher ()
fit2.log_covar ()

fit3.run (Ncm.FitRunMsgs.SIMPLE)
fit3.obs_fisher ()
fit3.log_covar ()

mest1 = 10**mset1.param_get (MDelta_pi.mid, MDelta_pi.pid)
mest2 = 10**mset2.param_get (MDelta_pi.mid, MDelta_pi.pid)
mest3 = 10**mset3.param_get (MDelta_pi.mid, MDelta_pi.pid)

print ("% 22.15e % 22.15e % 22.15e" % (mest1, mest2, mest3))
# Out:
# #----------------------------------------------------------------------------------
# # Model fitting. Interating using:
# #  - solver:            NLOpt:ln-neldermead
# #  - differentiation:   Numerical differentiantion (forward)
# #..............
# #  Minimum found with precision: |df|/f =  1.00000e-08 and |dx| =  1.00000e-05
# #  Elapsed time: 00 days, 00:00:00.1921670
# #  iteration            [000057]
# #  function evaluations [000059]
# #  gradient evaluations [000000]
# #  degrees of freedom   [009998]
# #  m2lnL     =   0.0248087366543645 (   0.024808737 )
# #  Fit parameters:
# #     3.9999835855765      15.0000069687639
# #----------------------------------------------------------------------------------
# # NcmMSet parameters covariance matrix
# #                                                       -------------------------------
# #      cDelta[06000:00] =  4           +/-  0.0004521   |  1           | -0.6531      |
# # log10MDelta[06000:01] =  15          +/-  4.986e-05   | -0.6531      |  1           |
# #                                                       -------------------------------
# #----------------------------------------------------------------------------------
# # Model fitting. Interating using:
# #  - solver:            NLOpt:ln-neldermead
# #  - differentiation:   Numerical differentiantion (forward)
# #...............
# #  Minimum found with precision: |df|/f =  1.00000e-08 and |dx| =  1.00000e-05
# #  Elapsed time: 00 days, 00:00:00.2650860
# #  iteration            [000063]
# #  function evaluations [000065]
# #  gradient evaluations [000000]
# #  degrees of freedom   [009998]
# #  m2lnL     =      0.1962177894175 (    0.19621779 )
# #  Fit parameters:
# #     4.00012734917092     14.9999838971033
# #----------------------------------------------------------------------------------
# # NcmMSet parameters covariance matrix
# #                                                       -------------------------------
# #      cDelta[06000:00] =  4           +/-  0.0002957   |  1           | -0.7061      |
# # log10MDelta[06000:01] =  15          +/-  4.267e-05   | -0.7061      |  1           |
# #                                                       -------------------------------
# #----------------------------------------------------------------------------------
# # Model fitting. Interating using:
# #  - solver:            NLOpt:ln-neldermead
# #  - differentiation:   Numerical differentiantion (forward)
# #..............
# #  Minimum found with precision: |df|/f =  1.00000e-08 and |dx| =  1.00000e-05
# #  Elapsed time: 00 days, 00:00:05.8184500
# #  iteration            [000054]
# #  function evaluations [000056]
# #  gradient evaluations [000000]
# #  degrees of freedom   [009998]
# #  m2lnL     =     9707.50525625965 (     9707.5053 )
# #  Fit parameters:
# #     3.96709240474766     15.0226282124308
# #----------------------------------------------------------------------------------
# # NcmMSet parameters covariance matrix
# #                                                       -------------------------------
# #      cDelta[06000:00] =  3.967       +/-  0.2084      |  1           | -0.6808      |
# # log10MDelta[06000:01] =  15.02       +/-  0.02188     | -0.6808      |  1           |
# #                                                       -------------------------------
#  1.000016046300544e+15  9.999629223975090e+14  1.053484650998323e+15

# %% [markdown]
# ## Visualizing the results
#
# Note below that we no longer have biased results, all results are well within the error bars. Note also that the error bars are substantially smaller than in the binned case.

# %%
rr = np.logspace(-0.5, np.log10(5), 100)

gt_model1 = moo1.eval_reduced_tangential_shear (rr, cluster_z, np.mean(cl1.galcat['z']))
gt_model2 = moo2.eval_reduced_tangential_shear (rr, cluster_z, np.mean(cl2.galcat['z']))
gt_model3 = moo3.eval_reduced_tangential_shear (rr, cluster_z, np.mean(cl3.galcat['z']))

m_est1 = 10**mset1.param_get (MDelta_pi.mid, MDelta_pi.pid)
m_est2 = 10**mset2.param_get (MDelta_pi.mid, MDelta_pi.pid)
m_est3 = 10**mset3.param_get (MDelta_pi.mid, MDelta_pi.pid)

m_est_err1 = fit1.covar_sd (MDelta_pi.mid, MDelta_pi.pid) * m_est1 * math.log (10.0)
m_est_err2 = fit2.covar_sd (MDelta_pi.mid, MDelta_pi.pid) * m_est2 * math.log (10.0)
m_est_err3 = fit3.covar_sd (MDelta_pi.mid, MDelta_pi.pid) * m_est3 * math.log (10.0)

print ("% 22.15e +/- %.0e % 22.15e +/- %.0e % 22.15e +/- %.0e" % (m_est1, m_est_err1, m_est2, m_est_err2, m_est3, m_est_err3))
# Out:
#  1.000016046300544e+15 +/- 1e+11  9.999629223975090e+14 +/- 1e+11  1.053484650998323e+15 +/- 5e+13

# %% [markdown]
# ### To investigate further the results we make a MCMC analysis below.

# %%
Ncm.func_eval_set_max_threads (0)
Ncm.func_eval_log_pool_stats ()

init_sampler = Ncm.MSetTransKernGauss.new (0)
init_sampler.set_mset (mset3)
init_sampler.set_prior_from_mset ()
init_sampler.set_cov_from_rescale (1.0e-1)

nwalkers = 100
stretch = Ncm.FitESMCMCWalkerAPES.new (nwalkers, mset3.fparams_len ())

esmcmc  = Ncm.FitESMCMC.new (fit3, nwalkers, init_sampler, stretch, Ncm.FitRunMsgs.SIMPLE)
esmcmc.set_data_file ("example2_fit3_esmcmc_out_aps.fits")
esmcmc.set_auto_trim (True)
esmcmc.set_auto_trim_div (100)
esmcmc.set_max_runs_time (2.0 * 60.0)

esmcmc.start_run ()
esmcmc.run_lre (20, 1.0e-3)
esmcmc.end_run ()
# Out:
# # NcmThreadPool:Unused:      0
# # NcmThreadPool:Max Unused:  2
# # NcmThreadPool:Running:     0
# # NcmThreadPool:Unprocessed: 0
# # NcmThreadPool:Unused:      0
# #----------------------------------------------------------------------------------
# # NcmFitESMCMC: Starting Ensamble Sampler Markov Chain Monte Carlo.
# #   Number of walkers: 0100.
# #   Number of threads: 0000.
# # NcmFitESMCMC: No RNG was defined, using algorithm: `mt19937' and seed: 4119727130.
# # NcmMSetCatalog: Current mean:   9718.2       3.9668       15.027
# # NcmMSetCatalog: Current msd:    1.5091       0.00090854   0.0051666
# # NcmMSetCatalog: Current sd:     15.091       0.0090854    0.051666
# # NcmMSetCatalog: Current var:    227.74       8.2545e-05   0.0026694
# # NcmMSetCatalog: Current tau:    1            1            1
# # NcmMSetCatalog: Current skfac: -nan         -nan         -nan
# # NcmMSetCatalog: Maximal Shrink factor = 1e+10
# #----------------------------------------------------------------------------------
# # NcmMSetCatalog: Computing the constant break point for parameter `0', sample size `1':
# # NcmMSetCatalog: Constant break point at `0':
# # NcmFitESMCMC:last ensemble variance of -2ln(L):       229.576232848735 (2n = 4), min(-2ln(L)) =        9707.5068680762.
# # Task:NcmFitESMCMC, completed: 100 of 100, elapsed time: 00:00:14.0938
# # Task:NcmFitESMCMC, mean time: 00:00:00.1406 +/- 00:00:00.1406
# # Task:NcmFitESMCMC, time left: 00:00:00.0000 +/- 00:00:00.0000
# # Task:NcmFitESMCMC, current time:        Mon Sep 13 2021, 14:02:09
# # Task:NcmFitESMCMC, estimated to end at: Mon Sep 13 2021, 14:02:09 +/- 00:00:00.0000
# # NcmFitESMCMC: Running first 99 pre-runs...
# #----------------------------------------------------------------------------------
# # NcmFitESMCMC: Calculating [000099] Ensemble Sampler Markov Chain Monte Carlo runs [APES-Move:VKDE:Cauchy]
# # Task:NcmFitESMCMC, started at: Mon Sep 13 2021, 14:01:55
# # NcmMSetCatalog: Current mean:   9711.2       3.9732       15.022
# # NcmMSetCatalog: Current msd:    0.27246      0.0032682    0.0011454
# # NcmMSetCatalog: Current sd:     7.2085       0.086468     0.030305
# # NcmMSetCatalog: Current var:    51.962       0.0074768    0.00091842
# # NcmMSetCatalog: Current tau:    1            1            1
# # NcmMSetCatalog: Current skfac:  1.0478       1.2125       1.2546
# # NcmMSetCatalog: Maximal Shrink factor = 1.25515
# #----------------------------------------------------------------------------------
# # NcmMSetCatalog: Computing the constant break point for parameter `0', sample size `7':
# # NcmMSetCatalog: Constant break point at `2':
# # NcmFitESMCMC:acceptance ratio 23.0000% (last update 20.0000%), offboard ratio  0.0000% (last update  0.0000%).
# # NcmFitESMCMC:last ensemble variance of -2ln(L):       7.53774826117702 (2n = 4), min(-2ln(L)) =       9707.50529998411.
# # Task:NcmFitESMCMC, completed: 700 of 10000, elapsed time: 00:01:17.1630
# # Task:NcmFitESMCMC, mean time: 00:00:00.1102 +/- 00:00:00.0417
# # Task:NcmFitESMCMC, time left: 00:17:04.7680 +/- 00:06:28.1952
# # Task:NcmFitESMCMC, current time:        Mon Sep 13 2021, 14:03:12
# # Task:NcmFitESMCMC, estimated to end at: Mon Sep 13 2021, 14:20:17 +/- 00:06:28.1952
# # NcmMSetCatalog: Current mean:   9710.5       3.977        15.021
# # NcmMSetCatalog: Current msd:    0.15407      0.0040299    0.00074346
# # NcmMSetCatalog: Current sd:     5.5549       0.1453       0.026806
# # NcmMSetCatalog: Current var:    30.857       0.021112     0.00071856
# # NcmMSetCatalog: Current tau:    1            1            1
# # NcmMSetCatalog: Current skfac:  1.0401       1.2524       1.2039
# # NcmMSetCatalog: Maximal Shrink factor = 1.25575
# #----------------------------------------------------------------------------------
# # NcmMSetCatalog: Computing the constant break point for parameter `0', sample size `13':
# # NcmMSetCatalog: Constant break point at `3':
# # NcmFitESMCMC:acceptance ratio 19.7500% (last update  4.0000%), offboard ratio  0.0000% (last update  0.0000%).
# # NcmFitESMCMC:last ensemble variance of -2ln(L):       5.92866800406312 (2n = 4), min(-2ln(L)) =       9707.50529998411.
# # Task:NcmFitESMCMC, completed: 1300 of 10000, elapsed time: 00:02:19.8660
# # Task:NcmFitESMCMC, mean time: 00:00:00.1076 +/- 00:00:00.0298
# # Task:NcmFitESMCMC, time left: 00:15:35.7734 +/- 00:04:19.3966
# # Task:NcmFitESMCMC, current time:        Mon Sep 13 2021, 14:04:15
# # Task:NcmFitESMCMC, estimated to end at: Mon Sep 13 2021, 14:19:51 +/- 00:04:19.3966
# # NcmMSetCatalog: Current mean:   9710.3       3.9798       15.022
# # NcmMSetCatalog: Current msd:    0.11043      0.0036502    0.00058593
# # NcmMSetCatalog: Current sd:     4.8134       0.15911      0.02554
# # NcmMSetCatalog: Current var:    23.169       0.025315     0.00065229
# # NcmMSetCatalog: Current tau:    1            1            1
# # NcmMSetCatalog: Current skfac:  1.0362       1.2415       1.2037
# # NcmMSetCatalog: Maximal Shrink factor = 1.2445
# #----------------------------------------------------------------------------------
# # NcmMSetCatalog: Computing the constant break point for parameter `0', sample size `19':
# # NcmMSetCatalog: Constant break point at `3':
# # NcmFitESMCMC:acceptance ratio 17.2222% (last update  0.0000%), offboard ratio  0.0000% (last update  0.0000%).
# # NcmFitESMCMC:last ensemble variance of -2ln(L):       5.79416031379205 (2n = 4), min(-2ln(L)) =       9707.50529998411.
# # Task:NcmFitESMCMC, completed: 1900 of 10000, elapsed time: 00:03:24.7147
# # Task:NcmFitESMCMC, mean time: 00:00:00.1077 +/- 00:00:00.0247
# # Task:NcmFitESMCMC, time left: 00:14:32.6366 +/- 00:03:19.9117
# # Task:NcmFitESMCMC, current time:        Mon Sep 13 2021, 14:05:20
# # Task:NcmFitESMCMC, estimated to end at: Mon Sep 13 2021, 14:19:52 +/- 00:03:19.9117
# # NcmMSetCatalog: Current mean:   9710.2       3.9811       15.022
# # NcmMSetCatalog: Current msd:    0.090301     0.0034189    0.00050837
# # NcmMSetCatalog: Current sd:     4.4238       0.16749      0.024905
# # NcmMSetCatalog: Current var:    19.57        0.028053     0.00062026
# # NcmMSetCatalog: Current tau:    1            1            1
# # NcmMSetCatalog: Current skfac:  1.0458       1.2538       1.2376
# # NcmMSetCatalog: Maximal Shrink factor = 1.26634
# #----------------------------------------------------------------------------------
# # NcmMSetCatalog: Computing the constant break point for parameter `0', sample size `24':
# # NcmMSetCatalog: Constant break point at `3':
# # NcmFitESMCMC:acceptance ratio 13.4783% (last update  0.0000%), offboard ratio  0.0000% (last update  0.0000%).
# # NcmFitESMCMC:last ensemble variance of -2ln(L):       5.79416031379205 (2n = 4), min(-2ln(L)) =       9707.50529998411.
# # Task:NcmFitESMCMC, completed: 2400 of 10000, elapsed time: 00:04:25.5416
# # Task:NcmFitESMCMC, mean time: 00:00:00.1106 +/- 00:00:00.0226
# # Task:NcmFitESMCMC, time left: 00:14:00.7874 +/- 00:02:51.5243
# # Task:NcmFitESMCMC, current time:        Mon Sep 13 2021, 14:06:21
# # Task:NcmFitESMCMC, estimated to end at: Mon Sep 13 2021, 14:20:21 +/- 00:02:51.5243
# # NcmMSetCatalog: Current mean:   9710.1       3.9822       15.023
# # NcmMSetCatalog: Current msd:    0.074885     0.0031692    0.00044558
# # NcmMSetCatalog: Current sd:     4.1016       0.17358      0.024405
# # NcmMSetCatalog: Current var:    16.823       0.030131     0.00059561
# # NcmMSetCatalog: Current tau:    1            1            1
# # NcmMSetCatalog: Current skfac:  1.0664       1.3258       1.2996
# # NcmMSetCatalog: Maximal Shrink factor = 1.34148
# #----------------------------------------------------------------------------------
# # NcmMSetCatalog: Computing the constant break point for parameter `0', sample size `30':
# # NcmMSetCatalog: Constant break point at `3':
# # NcmFitESMCMC:acceptance ratio 10.6897% (last update  0.0000%), offboard ratio  0.0000% (last update  0.0000%).
# # NcmFitESMCMC:last ensemble variance of -2ln(L):       5.79416031379205 (2n = 4), min(-2ln(L)) =       9707.50529998411.
# # Task:NcmFitESMCMC, completed: 3000 of 10000, elapsed time: 00:05:32.4214
# # Task:NcmFitESMCMC, mean time: 00:00:00.1108 +/- 00:00:00.0202
# # Task:NcmFitESMCMC, time left: 00:12:55.6045 +/- 00:02:21.4512
# # Task:NcmFitESMCMC, current time:        Mon Sep 13 2021, 14:07:27
# # Task:NcmFitESMCMC, estimated to end at: Mon Sep 13 2021, 14:20:23 +/- 00:02:21.4512
# # NcmMSetCatalog: Current mean:   9710.1       3.9829       15.023
# # NcmMSetCatalog: Current msd:    0.064521     0.0029587    0.00040106
# # NcmMSetCatalog: Current sd:     3.8713       0.17752      0.024063
# # NcmMSetCatalog: Current var:    14.987       0.031514     0.00057904
# # NcmMSetCatalog: Current tau:    1            1            1
# # NcmMSetCatalog: Current skfac:  1.0912       1.4103       1.3679
# # NcmMSetCatalog: Maximal Shrink factor = 1.42683
# #----------------------------------------------------------------------------------
# # NcmMSetCatalog: Computing the constant break point for parameter `0', sample size `36':
# # NcmMSetCatalog: Constant break point at `18':
# # NcmFitESMCMC:acceptance ratio  8.8571% (last update  0.0000%), offboard ratio  0.0000% (last update  0.0000%).
# # NcmFitESMCMC:last ensemble variance of -2ln(L):       5.79416031379205 (2n = 4), min(-2ln(L)) =       9707.50529998411.
# # Task:NcmFitESMCMC, completed: 3600 of 10000, elapsed time: 00:06:42.7171
# # Task:NcmFitESMCMC, mean time: 00:00:00.1119 +/- 00:00:00.0186
# # Task:NcmFitESMCMC, time left: 00:11:55.8567 +/- 00:01:59.2384
# # Task:NcmFitESMCMC, current time:        Mon Sep 13 2021, 14:08:38
# # Task:NcmFitESMCMC, estimated to end at: Mon Sep 13 2021, 14:20:34 +/- 00:01:59.2384
# # NcmMSetCatalog: Current mean:   9710         3.9831       15.023
# # NcmMSetCatalog: Current msd:    0.061778     0.0028964    0.00038888
# # NcmMSetCatalog: Current sd:     3.8082       0.17854      0.023972
# # NcmMSetCatalog: Current var:    14.503       0.031878     0.00057466
# # NcmMSetCatalog: Current tau:    1            1            1
# # NcmMSetCatalog: Current skfac:  1.1          1.439        1.391
# # NcmMSetCatalog: Maximal Shrink factor = 1.45568
# #----------------------------------------------------------------------------------
# # NcmMSetCatalog: Computing the constant break point for parameter `0', sample size `38':
# # NcmMSetCatalog: Constant break point at `37':
# # NcmFitESMCMC:acceptance ratio  8.3784% (last update  0.0000%), offboard ratio  0.0000% (last update  0.0000%).
# # NcmFitESMCMC:last ensemble variance of -2ln(L):       5.79416031379205 (2n = 4), min(-2ln(L)) =       9707.50529998411.
# # Task:NcmFitESMCMC, completed: 3800 of 10000, elapsed time: 00:07:08.6259
# # Task:NcmFitESMCMC, mean time: 00:00:00.1128 +/- 00:00:00.0183
# # Task:NcmFitESMCMC, time left: 00:11:39.2968 +/- 00:01:53.4101
# # Task:NcmFitESMCMC, current time:        Mon Sep 13 2021, 14:09:04
# # Task:NcmFitESMCMC, estimated to end at: Mon Sep 13 2021, 14:20:43 +/- 00:01:53.4101
# # NcmMSetCatalog: Current mean:   9710         3.9835       15.023
# # NcmMSetCatalog: Current msd:    0.055006     0.0027291    0.00035799
# # NcmMSetCatalog: Current sd:     3.6487       0.18103      0.023746
# # NcmMSetCatalog: Current var:    13.313       0.032771     0.00056388
# # NcmMSetCatalog: Current tau:    1            1            1
# # NcmMSetCatalog: Current skfac:  1.1269       1.5243       1.46
# # NcmMSetCatalog: Maximal Shrink factor = 1.54145
# #----------------------------------------------------------------------------------
# # NcmMSetCatalog: Computing the constant break point for parameter `0', sample size `44':
# # NcmMSetCatalog: Constant break point at `43':
# # NcmFitESMCMC:acceptance ratio  7.2093% (last update  0.0000%), offboard ratio  0.0000% (last update  0.0000%).
# # NcmFitESMCMC:last ensemble variance of -2ln(L):       5.79416031379205 (2n = 4), min(-2ln(L)) =       9707.50529998411.
# # Task:NcmFitESMCMC, completed: 4400 of 10000, elapsed time: 00:08:12.0839
# # Task:NcmFitESMCMC, mean time: 00:00:00.1118 +/- 00:00:00.0168
# # Task:NcmFitESMCMC, time left: 00:10:26.2567 +/- 00:01:34.3554
# # Task:NcmFitESMCMC, current time:        Mon Sep 13 2021, 14:10:07
# # Task:NcmFitESMCMC, estimated to end at: Mon Sep 13 2021, 14:20:33 +/- 00:01:34.3554
# # NcmMSetCatalog: Current mean:   9710         3.9838       15.023
# # NcmMSetCatalog: Current msd:    0.049815     0.0025865    0.00033336
# # NcmMSetCatalog: Current sd:     3.5225       0.18289      0.023572
# # NcmMSetCatalog: Current var:    12.408       0.033449     0.00055565
# # NcmMSetCatalog: Current tau:    1            1            1
# # NcmMSetCatalog: Current skfac:  1.1544       1.6074       1.5276
# # NcmMSetCatalog: Maximal Shrink factor = 1.62496
# #----------------------------------------------------------------------------------
# # NcmMSetCatalog: Computing the constant break point for parameter `0', sample size `50':
# # NcmMSetCatalog: Constant break point at `18':
# # NcmFitESMCMC:acceptance ratio  6.3265% (last update  0.0000%), offboard ratio  0.0000% (last update  0.0000%).
# # NcmFitESMCMC:last ensemble variance of -2ln(L):       5.79416031379205 (2n = 4), min(-2ln(L)) =       9707.50529998411.
# # Task:NcmFitESMCMC, completed: 5000 of 10000, elapsed time: 00:09:18.7629
# # Task:NcmFitESMCMC, mean time: 00:00:00.1117 +/- 00:00:00.0158
# # Task:NcmFitESMCMC, time left: 00:09:18.7397 +/- 00:01:18.9747
# # Task:NcmFitESMCMC, current time:        Mon Sep 13 2021, 14:11:14
# # Task:NcmFitESMCMC, estimated to end at: Mon Sep 13 2021, 14:20:33 +/- 00:01:18.9747
# # NcmMSetCatalog: Current mean:   9710         3.9841       15.023
# # NcmMSetCatalog: Current msd:    0.0457       0.0024634    0.00031316
# # NcmMSetCatalog: Current sd:     3.4199       0.18434      0.023434
# # NcmMSetCatalog: Current var:    11.696       0.033982     0.00054917
# # NcmMSetCatalog: Current tau:    1            1            1
# # NcmMSetCatalog: Current skfac:  1.182        1.6876       1.5934
# # NcmMSetCatalog: Maximal Shrink factor = 1.70566
# #----------------------------------------------------------------------------------
# # NcmMSetCatalog: Computing the constant break point for parameter `0', sample size `56':
# # NcmMSetCatalog: Constant break point at `55':
# # NcmFitESMCMC:acceptance ratio  5.6364% (last update  0.0000%), offboard ratio  0.0000% (last update  0.0000%).
# # NcmFitESMCMC:last ensemble variance of -2ln(L):       5.79416031379205 (2n = 4), min(-2ln(L)) =       9707.50529998411.
# # Task:NcmFitESMCMC, completed: 5600 of 10000, elapsed time: 00:10:24.8501
# # Task:NcmFitESMCMC, mean time: 00:00:00.1116 +/- 00:00:00.0149
# # Task:NcmFitESMCMC, time left: 00:08:10.9330 +/- 00:01:05.5864
# # Task:NcmFitESMCMC, current time:        Mon Sep 13 2021, 14:12:20
# # Task:NcmFitESMCMC, estimated to end at: Mon Sep 13 2021, 14:20:31 +/- 00:01:05.5864
# # NcmMSetCatalog: Current mean:   9710         3.9841       15.023
# # NcmMSetCatalog: Current msd:    0.045096     0.0024445    0.00031013
# # NcmMSetCatalog: Current sd:     3.4046       0.18455      0.023414
# # NcmMSetCatalog: Current var:    11.592       0.03406      0.00054822
# # NcmMSetCatalog: Current tau:    1            1            1
# # NcmMSetCatalog: Current skfac:  1.1865       1.7007       1.6042
# # NcmMSetCatalog: Maximal Shrink factor = 1.71883
# #----------------------------------------------------------------------------------
# # NcmMSetCatalog: Computing the constant break point for parameter `0', sample size `57':
# # NcmMSetCatalog: Constant break point at `56':
# # NcmFitESMCMC:acceptance ratio  5.5357% (last update  0.0000%), offboard ratio  0.0000% (last update  0.0000%).
# # NcmFitESMCMC:last ensemble variance of -2ln(L):       5.79416031379205 (2n = 4), min(-2ln(L)) =       9707.50529998411.
# # Task:NcmFitESMCMC, completed: 5700 of 10000, elapsed time: 00:10:35.7062
# # Task:NcmFitESMCMC, mean time: 00:00:00.1115 +/- 00:00:00.0148
# # Task:NcmFitESMCMC, time left: 00:07:59.5507 +/- 00:01:03.4967
# # Task:NcmFitESMCMC, current time:        Mon Sep 13 2021, 14:12:31
# # Task:NcmFitESMCMC, estimated to end at: Mon Sep 13 2021, 14:20:30 +/- 00:01:03.4967
# # NcmMSetCatalog: Current mean:   9710         3.9843       15.023
# # NcmMSetCatalog: Current msd:    0.042352     0.0023559    0.00029619
# # NcmMSetCatalog: Current sd:     3.3348       0.1855       0.023322
# # NcmMSetCatalog: Current var:    11.121       0.034412     0.00054393
# # NcmMSetCatalog: Current tau:    1            1            1
# # NcmMSetCatalog: Current skfac:  1.2094       1.765        1.6573
# # NcmMSetCatalog: Maximal Shrink factor = 1.7835
# #----------------------------------------------------------------------------------
# # NcmMSetCatalog: Computing the constant break point for parameter `0', sample size `62':
# # NcmMSetCatalog: Constant break point at `61':
# # NcmFitESMCMC:acceptance ratio  5.0820% (last update  0.0000%), offboard ratio  0.0000% (last update  0.0000%).
# # NcmFitESMCMC:last ensemble variance of -2ln(L):       5.79416031379205 (2n = 4), min(-2ln(L)) =       9707.50529998411.
# # Task:NcmFitESMCMC, completed: 6200 of 10000, elapsed time: 00:11:36.6917
# # Task:NcmFitESMCMC, mean time: 00:00:00.1124 +/- 00:00:00.0143
# # Task:NcmFitESMCMC, time left: 00:07:06.9882 +/- 00:00:54.2527
# # Task:NcmFitESMCMC, current time:        Mon Sep 13 2021, 14:13:32
# # Task:NcmFitESMCMC, estimated to end at: Mon Sep 13 2021, 14:20:39 +/- 00:00:54.2527
# # NcmMSetCatalog: Current mean:   9709.9       3.9845       15.023
# # NcmMSetCatalog: Current msd:    0.03957      0.0022611    0.0002817
# # NcmMSetCatalog: Current sd:     3.263        0.18646      0.023229
# # NcmMSetCatalog: Current var:    10.647       0.034765     0.0005396
# # NcmMSetCatalog: Current tau:    1            1            1
# # NcmMSetCatalog: Current skfac:  1.2365       1.8396       1.7193
# # NcmMSetCatalog: Maximal Shrink factor = 1.8586
# #----------------------------------------------------------------------------------
# # NcmMSetCatalog: Computing the constant break point for parameter `0', sample size `68':
# # NcmMSetCatalog: Constant break point at `18':
# # NcmFitESMCMC:acceptance ratio  4.6269% (last update  0.0000%), offboard ratio  0.0000% (last update  0.0000%).
# # NcmFitESMCMC:last ensemble variance of -2ln(L):       5.79416031379205 (2n = 4), min(-2ln(L)) =       9707.50529998411.
# # Task:NcmFitESMCMC, completed: 6800 of 10000, elapsed time: 00:12:39.6210
# # Task:NcmFitESMCMC, mean time: 00:00:00.1117 +/- 00:00:00.0135
# # Task:NcmFitESMCMC, time left: 00:05:57.4579 +/- 00:00:43.3577
# # Task:NcmFitESMCMC, current time:        Mon Sep 13 2021, 14:14:35
# # Task:NcmFitESMCMC, estimated to end at: Mon Sep 13 2021, 14:20:32 +/- 00:00:43.3577
# # NcmMSetCatalog: Current mean:   9709.9       3.9847       15.023
# # NcmMSetCatalog: Current msd:    0.037218     0.0021767    0.00026913
# # NcmMSetCatalog: Current sd:     3.2016       0.18725      0.023151
# # NcmMSetCatalog: Current var:    10.25        0.035062     0.00053598
# # NcmMSetCatalog: Current tau:    1            1            1
# # NcmMSetCatalog: Current skfac:  1.2634       1.9116       1.7795
# # NcmMSetCatalog: Maximal Shrink factor = 1.93113
# #----------------------------------------------------------------------------------
# # NcmMSetCatalog: Computing the constant break point for parameter `0', sample size `74':
# # NcmMSetCatalog: Constant break point at `73':
# # NcmFitESMCMC:acceptance ratio  4.2466% (last update  0.0000%), offboard ratio  0.0000% (last update  0.0000%).
# # NcmFitESMCMC:last ensemble variance of -2ln(L):       5.79416031379205 (2n = 4), min(-2ln(L)) =       9707.50529998411.
# # Task:NcmFitESMCMC, completed: 7400 of 10000, elapsed time: 00:13:43.2645
# # Task:NcmFitESMCMC, mean time: 00:00:00.1112 +/- 00:00:00.0129
# # Task:NcmFitESMCMC, time left: 00:04:49.2429 +/- 00:00:33.6234
# # Task:NcmFitESMCMC, current time:        Mon Sep 13 2021, 14:15:38
# # Task:NcmFitESMCMC, estimated to end at: Mon Sep 13 2021, 14:20:28 +/- 00:00:33.6234
# # NcmMSetCatalog: Current mean:   9709.9       3.9847       15.023
# # NcmMSetCatalog: Current msd:    0.036512     0.0021506    0.00026529
# # NcmMSetCatalog: Current sd:     3.1831       0.18748      0.023128
# # NcmMSetCatalog: Current var:    10.132       0.03515      0.00053489
# # NcmMSetCatalog: Current tau:    1            1            1
# # NcmMSetCatalog: Current skfac:  1.2722       1.9351       1.7991
# # NcmMSetCatalog: Maximal Shrink factor = 1.95477
# #----------------------------------------------------------------------------------
# # NcmMSetCatalog: Computing the constant break point for parameter `0', sample size `76':
# # NcmMSetCatalog: Constant break point at `75':
# # NcmFitESMCMC:acceptance ratio  4.1333% (last update  0.0000%), offboard ratio  0.0000% (last update  0.0000%).
# # NcmFitESMCMC:last ensemble variance of -2ln(L):       5.79416031379205 (2n = 4), min(-2ln(L)) =       9707.50529998411.
# # Task:NcmFitESMCMC, completed: 7600 of 10000, elapsed time: 00:14:04.2401
# # Task:NcmFitESMCMC, mean time: 00:00:00.1111 +/- 00:00:00.0127
# # Task:NcmFitESMCMC, time left: 00:04:26.5939 +/- 00:00:30.5779
# # Task:NcmFitESMCMC, current time:        Mon Sep 13 2021, 14:15:59
# # Task:NcmFitESMCMC, estimated to end at: Mon Sep 13 2021, 14:20:26 +/- 00:00:30.5779
# # NcmMSetCatalog: Current mean:   9709.9       3.9848       15.023
# # NcmMSetCatalog: Current msd:    0.03459      0.0020774    0.0002547
# # NcmMSetCatalog: Current sd:     3.1323       0.18812      0.023064
# # NcmMSetCatalog: Current var:    9.8112       0.035389     0.00053196
# # NcmMSetCatalog: Current tau:    1            1            1
# # NcmMSetCatalog: Current skfac:  1.2985       2.004        1.857
# # NcmMSetCatalog: Maximal Shrink factor = 2.02418
# #----------------------------------------------------------------------------------
# # NcmMSetCatalog: Computing the constant break point for parameter `0', sample size `82':
# # NcmMSetCatalog: Constant break point at `18':
# # NcmFitESMCMC:acceptance ratio  3.8272% (last update  0.0000%), offboard ratio  0.0000% (last update  0.0000%).
# # NcmFitESMCMC:last ensemble variance of -2ln(L):       5.79416031379205 (2n = 4), min(-2ln(L)) =       9707.50529998411.
# # Task:NcmFitESMCMC, completed: 8200 of 10000, elapsed time: 00:15:05.9516
# # Task:NcmFitESMCMC, mean time: 00:00:00.1105 +/- 00:00:00.0122
# # Task:NcmFitESMCMC, time left: 00:03:18.8560 +/- 00:00:21.9555
# # Task:NcmFitESMCMC, current time:        Mon Sep 13 2021, 14:17:01
# # Task:NcmFitESMCMC, estimated to end at: Mon Sep 13 2021, 14:20:20 +/- 00:00:21.9555
# # NcmMSetCatalog: Current mean:   9709.9       3.9849       15.023
# # NcmMSetCatalog: Current msd:    0.032915     0.0020112    0.00024528
# # NcmMSetCatalog: Current sd:     3.0877       0.18867      0.023009
# # NcmMSetCatalog: Current var:    9.534        0.035596     0.00052942
# # NcmMSetCatalog: Current tau:    1            1            1
# # NcmMSetCatalog: Current skfac:  1.3245       2.0708       1.9133
# # NcmMSetCatalog: Maximal Shrink factor = 2.09145
# #----------------------------------------------------------------------------------
# # NcmMSetCatalog: Computing the constant break point for parameter `0', sample size `88':
# # NcmMSetCatalog: Constant break point at `87':
# # NcmFitESMCMC:acceptance ratio  3.5632% (last update  0.0000%), offboard ratio  0.0000% (last update  0.0000%).
# # NcmFitESMCMC:last ensemble variance of -2ln(L):       5.79416031379205 (2n = 4), min(-2ln(L)) =       9707.50529998411.
# # Task:NcmFitESMCMC, completed: 8800 of 10000, elapsed time: 00:16:08.7042
# # Task:NcmFitESMCMC, mean time: 00:00:00.1101 +/- 00:00:00.0117
# # Task:NcmFitESMCMC, time left: 00:02:12.0915 +/- 00:00:14.0759
# # Task:NcmFitESMCMC, current time:        Mon Sep 13 2021, 14:18:04
# # Task:NcmFitESMCMC, estimated to end at: Mon Sep 13 2021, 14:20:16 +/- 00:00:14.0759
# # NcmMSetCatalog: Current mean:   9709.9       3.985        15.024
# # NcmMSetCatalog: Current msd:    0.031441     0.0019509    0.00023682
# # NcmMSetCatalog: Current sd:     3.0483       0.18915      0.022961
# # NcmMSetCatalog: Current var:    9.2922       0.035776     0.0005272
# # NcmMSetCatalog: Current tau:    1            1            1
# # NcmMSetCatalog: Current skfac:  1.35         2.1356       1.9681
# # NcmMSetCatalog: Maximal Shrink factor = 2.15675
# #----------------------------------------------------------------------------------
# # NcmMSetCatalog: Computing the constant break point for parameter `0', sample size `94':
# # NcmMSetCatalog: Constant break point at `18':
# # NcmFitESMCMC:acceptance ratio  3.3333% (last update  0.0000%), offboard ratio  0.0000% (last update  0.0000%).
# # NcmFitESMCMC:last ensemble variance of -2ln(L):       5.79416031379205 (2n = 4), min(-2ln(L)) =       9707.50529998411.
# # Task:NcmFitESMCMC, completed: 9400 of 10000, elapsed time: 00:17:11.4243
# # Task:NcmFitESMCMC, mean time: 00:00:00.1097 +/- 00:00:00.0113
# # Task:NcmFitESMCMC, time left: 00:01:05.8339 +/- 00:00:06.7865
# # Task:NcmFitESMCMC, current time:        Mon Sep 13 2021, 14:19:06
# # Task:NcmFitESMCMC, estimated to end at: Mon Sep 13 2021, 14:20:12 +/- 00:00:06.7865
# # NcmMSetCatalog: Current mean:   9709.9       3.985        15.024
# # NcmMSetCatalog: Current msd:    0.031212     0.0019413    0.0002355
# # NcmMSetCatalog: Current sd:     3.0422       0.18922      0.022953
# # NcmMSetCatalog: Current var:    9.2548       0.035804     0.00052686
# # NcmMSetCatalog: Current tau:    1            1            1
# # NcmMSetCatalog: Current skfac:  1.3542       2.1462       1.9771
# # NcmMSetCatalog: Maximal Shrink factor = 2.16745
# #----------------------------------------------------------------------------------
# # NcmMSetCatalog: Computing the constant break point for parameter `0', sample size `95':
# # NcmMSetCatalog: Constant break point at `18':
# # NcmFitESMCMC:acceptance ratio  3.2979% (last update  0.0000%), offboard ratio  0.0000% (last update  0.0000%).
# # NcmFitESMCMC:last ensemble variance of -2ln(L):       5.79416031379205 (2n = 4), min(-2ln(L)) =       9707.50529998411.
# # Task:NcmFitESMCMC, completed: 9500 of 10000, elapsed time: 00:17:22.0856
# # Task:NcmFitESMCMC, mean time: 00:00:00.1097 +/- 00:00:00.0112
# # Task:NcmFitESMCMC, time left: 00:00:54.8452 +/- 00:00:05.6237
# # Task:NcmFitESMCMC, current time:        Mon Sep 13 2021, 14:19:17
# # Task:NcmFitESMCMC, estimated to end at: Mon Sep 13 2021, 14:20:12 +/- 00:00:05.6237
# # NcmMSetCatalog: Current mean:   9709.9       3.9851       15.024
# # NcmMSetCatalog: Current msd:    0.030132     0.0018956    0.00022918
# # NcmMSetCatalog: Current sd:     3.0132       0.18956      0.022918
# # NcmMSetCatalog: Current var:    9.0793       0.035934     0.00052525
# # NcmMSetCatalog: Current tau:    1            1            1
# # NcmMSetCatalog: Current skfac:  1.3751       2.1986       2.0215
# # NcmMSetCatalog: Maximal Shrink factor = 2.22023
# #----------------------------------------------------------------------------------
# # NcmMSetCatalog: Computing the constant break point for parameter `0', sample size `100':
# # NcmMSetCatalog: Constant break point at `18':
# # NcmFitESMCMC:acceptance ratio  3.1313% (last update  0.0000%), offboard ratio  0.0000% (last update  0.0000%).
# # NcmFitESMCMC:last ensemble variance of -2ln(L):       5.79416031379205 (2n = 4), min(-2ln(L)) =       9707.50529998411.
# # Task:NcmFitESMCMC, completed: 10000 of 10000, elapsed time: 00:18:15.3990
# # Task:NcmFitESMCMC, mean time: 00:00:00.1095 +/- 00:00:00.0109
# # Task:NcmFitESMCMC, time left: 00:00:00.0000 +/- 00:00:00.0000
# # Task:NcmFitESMCMC, current time:        Mon Sep 13 2021, 14:20:10
# # Task:NcmFitESMCMC, estimated to end at: Mon Sep 13 2021, 14:20:10 +/- 00:00:00.0000
# #----------------------------------------------------------------------------------
# # NcmMSetCatalog: Calculating catalog effective sample size from chain 100 => 0 using 100 blocks:
# # NcmMSetCatalog: - best cutoff time:         0
# # NcmMSetCatalog: - total number of points:   100  (10000)
# # NcmMSetCatalog: - number of points left:    100  (10000)
# # NcmMSetCatalog: - worst parameter:          NcHaloDensityProfile:log10MDelta[02]
# # NcmMSetCatalog: - worst parameter ess:      11.92
# # NcmMSetCatalog: - worst parameter ar order: 7
# # NcmMSetCatalog: - ess's:                    70.56 36.93 11.92
# #----------------------------------------------------------------------------------
# # NcmFitESMCMC: Largest relative error 1.000000e-03 attained: 7.827224e-04
# # NcmMSetCatalog: Current mean:   9709.9       3.9851       15.024
# # NcmMSetCatalog: Current msd:    0.035871     0.0031192    0.00066388
# # NcmMSetCatalog: Current sd:     3.0132       0.18956      0.022918
# # NcmMSetCatalog: Current var:    9.0793       0.035934     0.00052525
# # NcmMSetCatalog: Current tau:    1.4173       2.7076       8.3909

# %% [markdown]
# ### Below we plot both MCMC results
#
# The wrong analysis has a strong bias in $\log_{10}(M_\Delta)$ (the peak of the wrong model is more than $3\sigma$ away from the correct model best-fit) and much larger variance.

# %%
s1d1 = chi2.cdf (1.0, df = 1)
s1d2 = chi2.cdf (4.0, df = 1)
s2d1 = chi2.cdf (1.0, df = 2)
s2d2 = chi2.cdf (4.0, df = 2)
s2d3 = chi2.cdf (9.0, df = 2)
qts = [0.5 - s1d2 / 2.0, 0.5 - s1d1 / 2.0, 0.5, 0.5 + s1d1 / 2.0, 0.5 + s1d2 / 2.0]

mcat = esmcmc.peek_catalog ()
rows = np.array ([mcat.peek_row (i).dup_array () for i in range (nwalkers * 10, mcat.len ())])
params = ["$" + mcat.col_symb (i) + "$" for i in range (mcat.ncols ())]
figure = corner.corner (rows[:,1:], labels = params[1:], reverse = False,
                        quantiles=qts, levels = (s2d1, s2d2, s2d3), 
                        bins = 40, smooth = 0.8, smooth1d = 0.8, color = (0.5, 0.2, 0.5, 1.0))

rows = np.array ([mcat_wrong.peek_row (i).dup_array () for i in range (nwalkers * 10, mcat_wrong.len ())])
params = ["$" + mcat_wrong.col_symb (i) + "$" for i in range (mcat_wrong.ncols ())]
figure = corner.corner (rows[:,1:], labels = params[1:], range=[(2.9, 9.5), (14.8, 15.12)], reverse = False,
                        levels = (s2d1, s2d2, s2d3), color = (0.1, 0.2, 0.5, 0.5),
                        bins = 40, smooth = 0.8, smooth1d = 0.8, fig = figure)


figure.set_size_inches(12, 6)

# %%
ser = Ncm.Serialize.new (0)
data = fit3.lh.dset.get_data (0)
ser.to_file (data, "example2_fit3_data.obj")
