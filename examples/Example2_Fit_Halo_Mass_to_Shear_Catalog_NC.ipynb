# %% [markdown]
# # Fit halo mass to shear profile: 2. realistic data
#
# _the LSST-DESC CLMM team_
#
#
# This notebook demonstrates how to use `clmm` to estimate a WL halo mass from observations of a galaxy cluster. It uses several functionalities of the support `mock_data` module to produce datasets of increasing complexity. This notebook also demonstrates the bias introduced on the reconstructed mass by a naive fit, when the redshift distribution of the background galaxies is not properly accounted for in the model. Organization of this notebook goes as follows:
#
# - Setting things up, with the proper imports.
# - Generating 3 datasets: an ideal dataset (dataset1) similar to that of Example1 (single source plane); an ideal dataset but with source galaxies following the Chang et al. (2013) redshift distribution (dataset2); a noisy dataset where photoz errors and shape noise are also included (dataset3).
# - Computing the binned reduced tangential shear profile, for the 3 datasets, using logarithmic binning.
# - Setting up the "single source plane" model to be fitted to the 3 datasets. Only dataset1 has a single source plane, so we expect to see a bias in the reconstructed mass when using this model on datasets 2 and 3.
# - Perform a simple fit using `scipy.optimize.curve_fit` and visualize the results.

# %% [markdown]
# ## Setup

# %% [markdown]
# First, we import some standard packages.

# %%
# For NumCosmo
import os
import sys
import gi

gi.require_version('NumCosmo', '1.0')
gi.require_version('NumCosmoMath', '1.0')
from gi.repository import GObject
from gi.repository import NumCosmo as Nc
from gi.repository import NumCosmoMath as Ncm

from scipy.stats import chi2
import corner

os.environ['CLMM_MODELING_BACKEND'] = 'nc'

__name__ = "NcContext"

Ncm.cfg_init ()
Ncm.cfg_set_log_handler (lambda msg: sys.stdout.write (msg) and sys.stdout.flush ())

# %%
try: import clmm
except:
    import notebook_install
    notebook_install.install_clmm_pipeline(upgrade=False)
    import clmm
import matplotlib.pyplot as plt
import numpy as np
from numpy import random
from clmm.support.sampler import fitters

clmm.__version__
# Out:
# '0.8.0'

# %% [markdown]
# Next, we import `clmm`'s core modules.

# %%
import clmm.dataops as da
import clmm.galaxycluster as gc
import clmm.theory as theory
from clmm import Cosmology

# %% [markdown]
# We then import a support modules for a specific data sets.
# `clmm` includes support modules that enable the user to generate mock data in a format compatible with `clmm`.

# %%
from clmm.support import mock_data as mock

# %% [markdown]
# ## Making mock data

# %% [markdown]
# For reproducibility:

# %%
np.random.seed(11)

# %% [markdown]
# To create mock data, we need to define a true cosmology.

# %%
mock_cosmo = Cosmology(H0 = 70.0, Omega_dm0 = 0.27 - 0.045, Omega_b0 = 0.045, Omega_k0 = 0.0)

# %% [markdown]
# We now set some parameters for a mock galaxy cluster.

# %%
cosmo = mock_cosmo
cluster_m = 1.e15 # M200,m [Msun]
cluster_z = 0.3   # Cluster's redshift
concentration = 4
ngals = 10000     # Number of galaxies
Delta = 200
cluster_ra = 0.0
cluster_dec = 0.0

# %% [markdown]
# Then we use the `mock_data` support module to generate 3 galaxy catalogs:
# - `ideal_data`: all background galaxies at the same redshift.
# - `ideal_data_z`: galaxies distributed according to the Chang et al. (2013) redshift distribution.
# - `noisy_data_z`: `ideal_data_z` + photoz errors + shape noise

# %%
ideal_data = mock.generate_galaxy_catalog(cluster_m, cluster_z, concentration, cosmo, 0.8, ngals=ngals)
ideal_data_z = mock.generate_galaxy_catalog(cluster_m, cluster_z, concentration, cosmo,'chang13', ngals=ngals)
noisy_data_z = mock.generate_galaxy_catalog(cluster_m, cluster_z, concentration, cosmo, 'chang13', 
                                            shapenoise=0.05, 
                                            photoz_sigma_unscaled=0.05, ngals=ngals)
# Out:
# /home/mariana/Projects/CLMM/build/lib/clmm/theory/func_layer.py:354: UserWarning: Some source redshifts are lower than the cluster redshift. kappa = 0 for those galaxies.
#   warnings.warn(f'Some source redshifts are lower than the cluster redshift. kappa = 0 for those galaxies.')

# %% [markdown]
# The galaxy catalogs are converted to a `clmm.GalaxyCluster` object and may be saved for later use.

# %%
cluster_id = "CL_ideal"
gc_object = clmm.GalaxyCluster(cluster_id, cluster_ra, cluster_dec,
                               cluster_z, ideal_data)
gc_object.save('ideal_GC.pkl')

cluster_id = "CL_ideal_z"
gc_object = clmm.GalaxyCluster(cluster_id, cluster_ra, cluster_dec,
                               cluster_z, ideal_data_z)
gc_object.save('ideal_GC_z.pkl')

cluster_id = "CL_noisy_z"
gc_object = clmm.GalaxyCluster(cluster_id, cluster_ra, cluster_dec,
                               cluster_z, noisy_data_z)
gc_object.save('noisy_GC_z.pkl')

# %% [markdown]
# Any saved `clmm.GalaxyCluster` object may be read in for analysis.

# %%
cl1 = clmm.GalaxyCluster.load('ideal_GC.pkl') # all background galaxies at the same redshift
cl2 = clmm.GalaxyCluster.load('ideal_GC_z.pkl') # background galaxies distributed according to Chang et al. (2013)
cl3 = clmm.GalaxyCluster.load('noisy_GC_z.pkl') # same as cl2 but with photoz error and shape noise

print("Cluster info = ID:", cl2.unique_id, "; ra:", cl2.ra, "; dec:", cl2.dec, "; z_l :", cl2.z)
print("The number of source galaxies is :", len(cl2.galcat))
# Out:
# Cluster info = ID: CL_ideal_z ; ra: 0.0 ; dec: 0.0 ; z_l : 0.3
# The number of source galaxies is : 10000

# %%
h = plt.hist(cl2.galcat['z'], bins=50)

# %% [markdown]
# ## Deriving observables

# %% [markdown]
# ### Computing shear

# %% [markdown]
# `clmm.dataops.compute_tangential_and_cross_components` calculates the tangential and cross shears for each source galaxy in the cluster.

# %%
theta1, g_t1, g_x1 = cl1.compute_tangential_and_cross_components(geometry="flat")
theta2, g_t2, g_x2 = cl2.compute_tangential_and_cross_components(geometry="flat")
theta3, g_t3, g_x3 = cl3.compute_tangential_and_cross_components(geometry="flat")

# %% [markdown]
# ### Radially binning the data

# %%
bin_edges = da.make_bins(0.7, 4, 15, method='evenlog10width')

# %% [markdown]
# `clmm.dataops.make_radial_profile` evaluates the average shear of the galaxy catalog in bins of radius.

# %%
profile1 = cl1.make_radial_profile("Mpc", bins=bin_edges,cosmo=cosmo)
profile2 = cl2.make_radial_profile("Mpc", bins=bin_edges,cosmo=cosmo)
profile3 = cl3.make_radial_profile("Mpc", bins=bin_edges,cosmo=cosmo)

# %% [markdown]
# After running `clmm.dataops.make_radial_profile` on a `clmm.GalaxyCluster` object, the object acquires the `clmm.GalaxyCluster.profile` attribute.

# %%
for n in cl1.profile.colnames: cl1.profile[n].format = "%6.3e"
cl1.profile.pprint(max_width=-1)
# Out:
# radius_min   radius  radius_max     gt      gt_err      gx       gx_err      z       z_err     n_src
# ---------- --------- ---------- --------- --------- ---------- --------- --------- --------- ---------
#  7.000e-01 7.446e-01  7.863e-01 4.353e-02 1.310e-04  1.122e-18 8.188e-19 8.000e-01 2.916e-17 5.800e+01
#  7.863e-01 8.403e-01  8.831e-01 3.984e-02 1.099e-04  5.055e-19 4.608e-19 8.000e-01 2.394e-17 8.600e+01
#  8.831e-01 9.395e-01  9.920e-01 3.654e-02 1.001e-04 -8.674e-20 3.030e-19 8.000e-01 3.417e-17 9.500e+01
#  9.920e-01 1.052e+00  1.114e+00 3.332e-02 8.489e-05 -1.651e-19 4.658e-19 8.000e-01 1.933e-17 1.320e+02
#  1.114e+00 1.187e+00  1.251e+00 3.003e-02 7.147e-05 -5.078e-19 5.545e-19 8.000e-01 1.807e-17 1.510e+02
#  1.251e+00 1.331e+00  1.406e+00 2.708e-02 6.600e-05 -4.658e-20 3.316e-19 8.000e-01 1.718e-17 1.670e+02
#  1.406e+00 1.495e+00  1.579e+00 2.426e-02 5.243e-05  5.056e-19 3.138e-19 8.000e-01 0.000e+00 2.350e+02
#  1.579e+00 1.677e+00  1.773e+00 2.165e-02 3.908e-05  3.655e-21 2.141e-19 8.000e-01 5.995e-18 3.430e+02
#  1.773e+00 1.887e+00  1.992e+00 1.917e-02 3.431e-05  2.922e-19 1.562e-19 8.000e-01 0.000e+00 4.010e+02
#  1.992e+00 2.119e+00  2.237e+00 1.692e-02 2.751e-05 -1.892e-19 1.166e-19 8.000e-01 0.000e+00 4.990e+02
#  2.237e+00 2.377e+00  2.513e+00 1.489e-02 2.158e-05  2.277e-20 1.005e-19 8.000e-01 8.623e-18 6.630e+02
#  2.513e+00 2.672e+00  2.823e+00 1.301e-02 1.844e-05  5.799e-20 7.480e-20 8.000e-01 0.000e+00 7.800e+02
#  2.823e+00 2.999e+00  3.171e+00 1.135e-02 1.421e-05  1.188e-19 5.225e-20 8.000e-01 0.000e+00 1.042e+03
#  3.171e+00 3.369e+00  3.561e+00 9.842e-03 1.130e-05 -3.104e-20 4.638e-20 8.000e-01 3.078e-18 1.301e+03
#  3.561e+00 3.781e+00  4.000e+00 8.509e-03 8.960e-06  7.327e-21 3.498e-20 8.000e-01 2.738e-18 1.644e+03

# %% [markdown]
# We visualize the radially binned shear for the 3 configurations

# %%
fig = plt.figure(figsize=(10, 6))


fsize = 14
fig.gca().errorbar(profile1['radius'], profile1['gt'], yerr=profile1['gt_err'], marker='o', label='z_src = 0.8')
fig.gca().errorbar(profile2['radius'], profile2['gt'], yerr=profile2['gt_err'], marker='o', 
                   label='z_src = Chang et al. (2013)')
fig.gca().errorbar(profile3['radius'], profile3['gt'], yerr=profile3['gt_err'], marker='o', 
                   label='z_src = Chang et al. (2013) + photoz err  + shape noise')

plt.gca().set_title(r'Binned shear of source galaxies', fontsize=fsize)
plt.gca().set_xlabel(r'$r\;[Mpc]$', fontsize=fsize)
plt.gca().set_ylabel(r'$g_t$', fontsize=fsize)
plt.legend()

# %% [markdown]
# ### Fitting a halo mass - highlighting bias when not accounting for the source redshift distribution in the model

# %% [markdown]
# We estimate the best-fit mass using a simple implementation of the likelihood using a NcmDataGaussDiag object.
#
# Here, to build the model we make the WRONG assumption that the average shear in bin $i$ equals the shear at the average redshift in the bin; i.e. we assume that $\langle g_t\rangle_i = g_t(\langle z\rangle_i)$. This should not impact `cluster 1` as all sources are located at the same redshift. However, this yields a bias in the constructed mass for `cluster 2` and `cluster 3`, where the sources followed the Chang et al. (2013) distribution.

# %% [markdown]
# As expected, the reconstructed mass is biased whenever the sources are not located at a single redshift as this was not accounted for in the model.

# %% [markdown]
# ## Create the halo model
#
# Here we model using the OO inteface, we also use NumCosmo statistical framework to perform the analysis. Below we create an object based on NumCosmo NcmDataGaussDiag (Gaussian likelihood with a diagonal covariance matrix) object. To connect with the C interface the object must implement the methods: `do_get_length`, `do_get_dof`, `do_begin`, `do_prepare` and `do_mean_func`. The last method is responsible to compute the theoretical predictions. In the param_set_ftype calls below one can change between FREE/FIXED to include/exclude the parameter from the analysis.
#
# Remember that here we are building the wrong model.

# %%
class GaussGammaTErr (Ncm.DataGaussDiag):
    z_cluster = GObject.Property (type = float, flags = GObject.PARAM_READWRITE)
    z_source  = GObject.Property (type = Ncm.Vector, flags = GObject.PARAM_READWRITE)
    r_source  = GObject.Property (type = Ncm.Vector, flags = GObject.PARAM_READWRITE)
    z_err     = GObject.Property (type = Ncm.Vector, flags = GObject.PARAM_READWRITE)

    def __init__ (self):
        Ncm.DataGaussDiag.__init__ (self, n_points = 0)        
        self.moo = clmm.Modeling ()
    
    def init_from_data (self, z_cluster, r_source, z_source, gt_profile, gt_err, z_err = None, moo = None):
        
        if moo:
            self.moo = moo
        
        assert len (gt_profile) == len (z_source)
        assert len (gt_profile) == len (r_source)
        assert len (gt_profile) == len (gt_err)
        
        self.set_size (len (gt_profile))
        
        self.props.z_cluster = z_cluster
        self.props.z_source  = Ncm.Vector.new_array (z_source)
        self.props.r_source  = Ncm.Vector.new_array (r_source)
        if z_err:
            self.props.r_source  = Ncm.Vector.new_array (z_err)
                
        self.y.set_array (gt_profile)
        
        self.sigma.set_array (gt_err) # Diagonal covariance matrix: standard deviation values in gt_err.

        
        self.set_init (True)        
    
    # Once the NcmDataGaussDiag is initialized, its parent class variable np is set with the n_points value.
    def do_get_length (self):
        return self.np

    def do_get_dof (self):
        return self.np

    def do_begin (self):
        pass

    def do_prepare (self, mset):
        self.moo.set_mset (mset)
        
    def do_mean_func (self, mset, vp):
        vp.set_array (self.moo.eval_reduced_shear (self.props.r_source.dup_array (), self.props.z_cluster, self.props.z_source.dup_array ()))
        return

GObject.type_register (GaussGammaTErr)
# Out:
# NcContext.GaussGammaTErr

# %% [markdown]
# Defining the model set (NcmMset), data set (NcmDataset) and NcmLikelihood objects to carry out a statistical analysis.
#
# The method `param_set_ftype` defines the parameters that can be fitted: `mid` - to which model set the parameter belongs to, `pid` - parameters' id, NcmParamType (FREE or FIXED) to say if the parameter will be fitted or not.

# %%
moo1 = clmm.Modeling (massdef = 'mean', delta_mdef = 200, halo_profile_model = 'nfw')
moo1.set_cosmo (cosmo)
moo1.set_concentration (4.0)

moo2 = clmm.Modeling (massdef = 'mean', delta_mdef = 200, halo_profile_model = 'nfw')
moo2.set_cosmo (cosmo)
moo2.set_concentration (4.0)

moo3 = clmm.Modeling (massdef = 'mean', delta_mdef = 200, halo_profile_model = 'nfw')
moo3.set_cosmo (cosmo)
moo3.set_concentration (4.0)

ggt1 = GaussGammaTErr ()
ggt2 = GaussGammaTErr ()
ggt3 = GaussGammaTErr ()

ggt1.init_from_data (z_cluster = cluster_z, r_source = profile1['radius'], z_source = profile1['z'], gt_profile = profile1['gt'], gt_err = profile1['gt_err'], moo = moo1)
ggt2.init_from_data (z_cluster = cluster_z, r_source = profile2['radius'], z_source = profile2['z'], gt_profile = profile2['gt'], gt_err = profile2['gt_err'], moo = moo2)
ggt3.init_from_data (z_cluster = cluster_z, r_source = profile3['radius'], z_source = profile3['z'], gt_profile = profile3['gt'], gt_err = profile3['gt_err'], moo = moo3)

mset1 = ggt1.moo.get_mset ()
mset2 = ggt2.moo.get_mset ()
mset3 = ggt3.moo.get_mset ()

#Parameters: cluster mass (log base 10) and concentration
MDelta_pi = mset1.param_get_by_full_name ("NcHaloDensityProfile:log10MDelta")
cDelta_pi = mset1.param_get_by_full_name ("NcHaloDensityProfile:cDelta")

mset1.param_set_ftype (MDelta_pi.mid, MDelta_pi.pid, Ncm.ParamType.FREE)
mset1.param_set_ftype (cDelta_pi.mid, cDelta_pi.pid, Ncm.ParamType.FREE)
mset1.prepare_fparam_map ()

mset2.param_set_ftype (MDelta_pi.mid, MDelta_pi.pid, Ncm.ParamType.FREE)
mset2.param_set_ftype (cDelta_pi.mid, cDelta_pi.pid, Ncm.ParamType.FREE)
mset2.prepare_fparam_map ()

mset3.param_set_ftype (MDelta_pi.mid, MDelta_pi.pid, Ncm.ParamType.FREE)
mset3.param_set_ftype (cDelta_pi.mid, cDelta_pi.pid, Ncm.ParamType.FREE)
mset3.prepare_fparam_map ()

dset1 = Ncm.Dataset.new ()
dset1.append_data (ggt1)
lh1 = Ncm.Likelihood.new (dset1)

dset2 = Ncm.Dataset.new ()
dset2.append_data (ggt2)
lh2 = Ncm.Likelihood.new (dset2)

dset3 = Ncm.Dataset.new ()
dset3.append_data (ggt3)
lh3 = Ncm.Likelihood.new (dset3)

# %% [markdown]
# ### Fitting parameters: Fisher Matrix
#
# The NcmFit object receives the NcmLikelihood and NcmMset objects. The user also indicates the fitting algorithm and the numerical differentiation method.
# Functions `run` and `fisher` computes the [best-fit](https://en.wikipedia.org/wiki/Maximum_likelihood_estimation) and the [fisher matrix](https://en.wikipedia.org/wiki/Fisher_information#Multivariate_normal_distribution), respectively. `log_info` prints the complete information about the data used, models and its parameters, and `log_covar` prints the best-fit along with the error-bar and the covariance matrix.

# %%
fit1 = Ncm.Fit.new (Ncm.FitType.NLOPT, "ln-neldermead", lh1, mset1, Ncm.FitGradType.NUMDIFF_FORWARD)
fit2 = Ncm.Fit.new (Ncm.FitType.NLOPT, "ln-neldermead", lh2, mset2, Ncm.FitGradType.NUMDIFF_FORWARD)
fit3 = Ncm.Fit.new (Ncm.FitType.NLOPT, "ln-neldermead", lh3, mset3, Ncm.FitGradType.NUMDIFF_FORWARD)

fit1.run (Ncm.FitRunMsgs.SIMPLE)
fit1.fisher ()
fit1.log_info ()
fit1.log_covar ()

fit2.run (Ncm.FitRunMsgs.SIMPLE)
fit2.fisher ()
fit2.log_info ()
fit2.log_covar ()

fit3.run (Ncm.FitRunMsgs.SIMPLE)
fit3.fisher ()
fit3.log_info ()
fit3.log_covar ()
# Out:
# #----------------------------------------------------------------------------------
# # Model fitting. Interating using:
# #  - solver:            NLOpt:ln-neldermead
# #  - differentiation:   Numerical differentiantion (forward)
# #..............
# #  Minimum found with precision: |df|/f =  1.00000e-08 and |dx| =  1.00000e-05
# #  Elapsed time: 00 days, 00:00:00.0052210
# #  iteration            [000056]
# #  function evaluations [000058]
# #  gradient evaluations [000000]
# #  degrees of freedom   [000013]
# #  m2lnL     =  0.00502081162003553 (  0.0050208116 )
# #  Fit parameters:
# #     3.9953235476808      15.0007832361652
# #----------------------------------------------------------------------------------
# # Data used:
# #   - NcContext+GaussGammaTErr
# #----------------------------------------------------------------------------------
# # Model[01000]:
# #   - NcHICosmo : XCDM - Constant EOS
# #----------------------------------------------------------------------------------
# # Model parameters
# #   -          H0[00]:  70                  [FIXED]
# #   -      Omegac[01]:  0.225               [FIXED]
# #   -      Omegak[02]:  0                   [FIXED]
# #   -     Tgamma0[03]:  0                   [FIXED]
# #   -          Yp[04]:  0.24                [FIXED]
# #   -        ENnu[05]:  3.046               [FIXED]
# #   -      Omegab[06]:  0.045               [FIXED]
# #   -           w[07]: -1                   [FIXED]
# #----------------------------------------------------------------------------------
# # Model[04000]:
# #   - NcHaloDensityProfile : NFW Density Profile
# #----------------------------------------------------------------------------------
# # Model parameters
# #   -      cDelta[00]:  3.9953235476808     [FREE]
# #   - log10MDelta[01]:  15.0007832361652    [FREE]
# #----------------------------------------------------------------------------------
# # Model[08000]:
# #   - NcWLSurfaceMassDensity : WL Surface Mass Density
# #----------------------------------------------------------------------------------
# # Model parameters
# #   -         pcc[00]:  0.8                 [FIXED]
# #   -        Roff[01]:  1                   [FIXED]
# #----------------------------------------------------------------------------------
# # NcmMSet parameters covariance matrix
# #                                                       -------------------------------
# #      cDelta[04000:00] =  3.995       +/-  0.009972    |  1           | -0.4877      |
# # log10MDelta[04000:01] =  15          +/-  0.0003027   | -0.4877      |  1           |
# #                                                       -------------------------------
# #----------------------------------------------------------------------------------
# # Model fitting. Interating using:
# #  - solver:            NLOpt:ln-neldermead
# #  - differentiation:   Numerical differentiantion (forward)
# #...............
# #  Minimum found with precision: |df|/f =  1.00000e-08 and |dx| =  1.00000e-05
# #  Elapsed time: 00 days, 00:00:00.0032170
# #  iteration            [000066]
# #  function evaluations [000068]
# #  gradient evaluations [000000]
# #  degrees of freedom   [000013]
# #  m2lnL     =     2.73688687623507 (     2.7368869 )
# #  Fit parameters:
# #     3.81171853288838     14.9400250978337
# #----------------------------------------------------------------------------------
# # Data used:
# #   - NcContext+GaussGammaTErr
# #----------------------------------------------------------------------------------
# # Model[01000]:
# #   - NcHICosmo : XCDM - Constant EOS
# #----------------------------------------------------------------------------------
# # Model parameters
# #   -          H0[00]:  70                  [FIXED]
# #   -      Omegac[01]:  0.225               [FIXED]
# #   -      Omegak[02]:  0                   [FIXED]
# #   -     Tgamma0[03]:  0                   [FIXED]
# #   -          Yp[04]:  0.24                [FIXED]
# #   -        ENnu[05]:  3.046               [FIXED]
# #   -      Omegab[06]:  0.045               [FIXED]
# #   -           w[07]: -1                   [FIXED]
# #----------------------------------------------------------------------------------
# # Model[04000]:
# #   - NcHaloDensityProfile : NFW Density Profile
# #----------------------------------------------------------------------------------
# # Model parameters
# #   -      cDelta[00]:  3.81171853288838    [FREE]
# #   - log10MDelta[01]:  14.9400250978337    [FREE]
# #----------------------------------------------------------------------------------
# # Model[08000]:
# #   - NcWLSurfaceMassDensity : WL Surface Mass Density
# #----------------------------------------------------------------------------------
# # Model parameters
# #   -         pcc[00]:  0.8                 [FIXED]
# #   -        Roff[01]:  1                   [FIXED]
# #----------------------------------------------------------------------------------
# # NcmMSet parameters covariance matrix
# #                                                       -------------------------------
# #      cDelta[04000:00] =  3.812       +/-  0.07116     |  1           | -0.3029      |
# # log10MDelta[04000:01] =  14.94       +/-  0.001696    | -0.3029      |  1           |
# #                                                       -------------------------------
# #----------------------------------------------------------------------------------
# # Model fitting. Interating using:
# #  - solver:            NLOpt:ln-neldermead
# #  - differentiation:   Numerical differentiantion (forward)
# #..................
# #  Minimum found with precision: |df|/f =  1.00000e-08 and |dx| =  1.00000e-05
# #  Elapsed time: 00 days, 00:00:00.0088140
# #  iteration            [000093]
# #  function evaluations [000095]
# #  gradient evaluations [000000]
# #  degrees of freedom   [000013]
# #  m2lnL     =     13.0733570914813 (     13.073357 )
# #  Fit parameters:
# #     5.0129961761262      14.9199431139839
# #----------------------------------------------------------------------------------
# # Data used:
# #   - NcContext+GaussGammaTErr
# #----------------------------------------------------------------------------------
# # Model[01000]:
# #   - NcHICosmo : XCDM - Constant EOS
# #----------------------------------------------------------------------------------
# # Model parameters
# #   -          H0[00]:  70                  [FIXED]
# #   -      Omegac[01]:  0.225               [FIXED]
# #   -      Omegak[02]:  0                   [FIXED]
# #   -     Tgamma0[03]:  0                   [FIXED]
# #   -          Yp[04]:  0.24                [FIXED]
# #   -        ENnu[05]:  3.046               [FIXED]
# #   -      Omegab[06]:  0.045               [FIXED]
# #   -           w[07]: -1                   [FIXED]
# #----------------------------------------------------------------------------------
# # Model[04000]:
# #   - NcHaloDensityProfile : NFW Density Profile
# #----------------------------------------------------------------------------------
# # Model parameters
# #   -      cDelta[00]:  5.0129961761262     [FREE]
# #   - log10MDelta[01]:  14.9199431139839    [FREE]
# #----------------------------------------------------------------------------------
# # Model[08000]:
# #   - NcWLSurfaceMassDensity : WL Surface Mass Density
# #----------------------------------------------------------------------------------
# # Model parameters
# #   -         pcc[00]:  0.8                 [FIXED]
# #   -        Roff[01]:  1                   [FIXED]
# #----------------------------------------------------------------------------------
# # NcmMSet parameters covariance matrix
# #                                                       -------------------------------
# #      cDelta[04000:00] =  5.013       +/-  0.8142      |  1           | -0.7308      |
# # log10MDelta[04000:01] =  14.92       +/-  0.02727     | -0.7308      |  1           |
# #                                                       -------------------------------

# %% [markdown]
# ## Visualization of the results
#
# For visualization purpose, we calculate the reduced tangential shear predicted by the model when using the average redshift of the catalog.

# %%
rr = np.logspace(-0.5, np.log10(5), 100)

gt_model1 = moo1.eval_reduced_shear (rr, cluster_z, np.mean(cl1.galcat['z']))
gt_model2 = moo2.eval_reduced_shear (rr, cluster_z, np.mean(cl2.galcat['z']))
gt_model3 = moo3.eval_reduced_shear (rr, cluster_z, np.mean(cl3.galcat['z']))

m_est1 = 10**mset1.param_get (MDelta_pi.mid, MDelta_pi.pid)
m_est2 = 10**mset2.param_get (MDelta_pi.mid, MDelta_pi.pid)
m_est3 = 10**mset3.param_get (MDelta_pi.mid, MDelta_pi.pid)

# Standard deviation
m_est_err1 = fit1.covar_sd (MDelta_pi.mid, MDelta_pi.pid) * m_est1 * math.log (10.0)
m_est_err2 = fit2.covar_sd (MDelta_pi.mid, MDelta_pi.pid) * m_est2 * math.log (10.0)
m_est_err3 = fit3.covar_sd (MDelta_pi.mid, MDelta_pi.pid) * m_est3 * math.log (10.0)

print ("% 22.15e +/- %.0e % 22.15e +/- %.0e % 22.15e +/- %.0e" % (m_est1, m_est_err1, m_est2, m_est_err2, m_est3, m_est_err3))
# Out:
#  1.001805095144565e+15 +/- 7e+11  8.710139243072430e+14 +/- 3e+12  8.316548297494131e+14 +/- 5e+13

# %% [markdown]
# We visualize that prediction of reduced tangential shears along with the data

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(16, 6))

axes[0].errorbar(profile1['radius'], profile1['gt'],profile1['gt_err'], color='red',
                 label='ideal_data, M_input = %.3e Msun' % cluster_m, fmt='.')
axes[0].plot(rr, gt_model1,color='red',
             label='best fit model 1, M_fit = %.2e +/- %.2e' % (m_est1, m_est_err1))


axes[0].errorbar(profile2['radius'], profile2['gt'],profile2['gt_err'], color='green',
                  label='ideal_data_z, M_input = %.3e Msun' % cluster_m, fmt='.')
axes[0].plot(rr, gt_model2, color='green',
               label='best fit model 2, M_fit = %.2e +/- %.2e' % (m_est2, m_est_err2))
axes[0].set_title('Ideal data w/wo src redshift distribution',fontsize=fsize)
axes[0].semilogx()
axes[0].semilogy()
axes[0].legend(fontsize=fsize)
axes[0].set_xlabel('R [Mpc]', fontsize=fsize)
axes[0].set_ylabel('reduced tangential shear', fontsize=fsize)

axes[1].errorbar(profile3['radius'], profile3['gt'],profile3['gt_err'], color='red',
                label='noisy_data_z, M_input = %.3e Msun' % cluster_m, fmt='.')
axes[1].plot(rr, gt_model3,color='red',
             label='best fit model 3, M_fit = %.2e +/- %.2e' % (m_est3, m_est_err3))
axes[1].set_title('Noisy data with src redshift distribution',fontsize=fsize)
axes[1].semilogx()
axes[1].semilogy()
axes[1].legend(fontsize=fsize)
axes[1].set_xlabel('R [Mpc]', fontsize=fsize)
axes[1].set_ylabel('reduced tangential shear', fontsize=fsize)

fig.tight_layout()

# %% [markdown]
# ### To investigate further the results we make a MCMC analysis below.
#
# We begin by specifying if the run is single- or multi-thread: `func_eval_set_max_threads` sets the maximum number of threads, and `func_eval_log_pool_stats` prints the information about the thread pool.
#
# Then, we initialize the transition kernel object (NcmMSetTransKern) which defines the distribution of the initial points of the parameter space to be used by the ensemble sampler. In this example we use the Gaussian transition kernel (NcmMSetTransKernGauss), with priors provided by the NcmMset (`set_prior_from_mset`). `set_cov_from_rescale` sets the covariance matrix with zero correlation and the diagonal terms defined by the scale of each parameter times the argument of `set_cov_from_rescale`.
#
# Here we use the Ensemble Sampler MCMC (ESMCMC) method. `nwalkers` and `walker` define the number of walkers and the algorithm used to move the points in the ensemble.
# Running: `start_run`, `run_lre` and `end_run`. `run_lre` runs the ESMCMC until the relative error of the mean of each parameter is smaller than $10^{-3}$. Its first argument (integer) indicates how many ensembles are computed before applying any convergence test.
#
# In the end we save the catalog to mcat_wrong to compare with a correct analysis.

# %%
Ncm.func_eval_set_max_threads (0)
Ncm.func_eval_log_pool_stats ()

init_sampler = Ncm.MSetTransKernGauss.new (0)
init_sampler.set_mset (mset3)
init_sampler.set_prior_from_mset ()
init_sampler.set_cov_from_rescale (1.0e-1)

nwalkers = 100 # Number of walkers
walker = Ncm.FitESMCMCWalkerAPS.new (nwalkers, mset3.fparams_len ())

# Ensemble Sampler MCMC
esmcmc  = Ncm.FitESMCMC.new (fit3, nwalkers, init_sampler, walker, Ncm.FitRunMsgs.SIMPLE)
esmcmc.set_data_file ("example2_fit3_wrong_esmcmc_out_aps.fits")
esmcmc.set_auto_trim (True)            # Detect and discard the burn-in points.
esmcmc.set_auto_trim_div (100)
esmcmc.set_max_runs_time (2.0 * 60.0)  # Maximum time between tests.

esmcmc.start_run ()
esmcmc.run_lre (20, 1.0e-3)
esmcmc.end_run ()

mcat_wrong = esmcmc.peek_catalog ()
# Out:
# # NcmThreadPool:Unused:      0
# # NcmThreadPool:Max Unused:  2
# # NcmThreadPool:Running:     0
# # NcmThreadPool:Unprocessed: 0
# # NcmThreadPool:Unused:      0
# #----------------------------------------------------------------------------------
# # NcmFitESMCMC: Starting Ensamble Sampler Markov Chain Monte Carlo.
# #   Number of walkers: 0100.
# #   Number of threads: 0000.
# #----------------------------------------------------------------------------------
# # NcmFitESMCMC: Skipping 20400 points (204.000000 iterations), will start at 20401-th point.
# #----------------------------------------------------------------------------------
# # NcmFitESMCMC: validating catalog rows [19100, 19200)
# # NcmFitESMCMC: Catalog row 19100: m2lnL =     13.7562269395045, recalculated to     13.7562269395045, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row 19101: m2lnL =     13.5143924223005, recalculated to     13.5143924223005, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row 19102: m2lnL =     17.2124068548066, recalculated to     17.2124068548066, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row 19103: m2lnL =     14.3117055136772, recalculated to     14.3117055136772, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row 19104: m2lnL =     13.6115070491553, recalculated to     13.6115070491553, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row 19105: m2lnL =     15.1317865096113, recalculated to     15.1317865096113, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row 19106: m2lnL =     14.3334421621239, recalculated to     14.3334421621239, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row 19107: m2lnL =     15.5363958643687, recalculated to     15.5363958643687, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row 19108: m2lnL =     13.1386324485338, recalculated to     13.1386324485338, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row 19109: m2lnL =     15.0869624011886, recalculated to     15.0869624011886, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row 19110: m2lnL =     18.1574978154383, recalculated to     18.1574978154383, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row 19111: m2lnL =     13.3607432012708, recalculated to     13.3607432012708, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row 19112: m2lnL =     16.0846293523281, recalculated to     16.0846293523281, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row 19113: m2lnL =     14.0214553035488, recalculated to     14.0214553035488, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row 19114: m2lnL =      13.661688625693, recalculated to      13.661688625693, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row 19115: m2lnL =     13.5615515612091, recalculated to     13.5615515612091, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row 19116: m2lnL =     14.7879333310016, recalculated to     14.7879333310016, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row 19117: m2lnL =     17.3737383367353, recalculated to     17.3737383367353, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row 19118: m2lnL =     13.9219682633234, recalculated to     13.9219682633234, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row 19119: m2lnL =     14.4307625041174, recalculated to     14.4307625041174, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row 19120: m2lnL =     13.7454857197747, recalculated to     13.7454857197747, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row 19121: m2lnL =     14.4725647419997, recalculated to     14.4725647419997, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row 19122: m2lnL =     16.2744530710634, recalculated to     16.2744530710634, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row 19123: m2lnL =     14.1642120143627, recalculated to     14.1642120143627, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row 19124: m2lnL =     14.3810185978896, recalculated to     14.3810185978896, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row 19125: m2lnL =     13.9872764662589, recalculated to     13.9872764662589, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row 19126: m2lnL =     13.2212046405318, recalculated to     13.2212046405318, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row 19127: m2lnL =     13.4752607580226, recalculated to     13.4752607580226, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row 19128: m2lnL =     14.3045068453719, recalculated to     14.3045068453719, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row 19129: m2lnL =     15.0453728395244, recalculated to     15.0453728395244, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row 19130: m2lnL =     14.4303443027606, recalculated to     14.4303443027606, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row 19131: m2lnL =     17.9376819836551, recalculated to     17.9376819836551, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row 19132: m2lnL =     22.6506071794402, recalculated to     22.6506071794402, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row 19133: m2lnL =     14.5053603945522, recalculated to     14.5053603945522, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row 19134: m2lnL =     14.5444936101057, recalculated to     14.5444936101057, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row 19135: m2lnL =     15.7386531366587, recalculated to     15.7386531366587, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row 19136: m2lnL =      13.573438063095, recalculated to      13.573438063095, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row 19137: m2lnL =     13.9257372671737, recalculated to     13.9257372671737, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row 19138: m2lnL =     13.3357881873894, recalculated to     13.3357881873894, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row 19139: m2lnL =     15.0517356414625, recalculated to     15.0517356414625, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row 19140: m2lnL =     13.8280325839439, recalculated to     13.8280325839439, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row 19141: m2lnL =     14.7600187363515, recalculated to     14.7600187363515, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row 19142: m2lnL =     15.6138299034215, recalculated to     15.6138299034215, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row 19143: m2lnL =     13.1489686273552, recalculated to     13.1489686273552, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row 19144: m2lnL =     16.5585638341548, recalculated to     16.5585638341548, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row 19145: m2lnL =     13.0796992329577, recalculated to     13.0796992329577, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row 19146: m2lnL =     13.4491531471862, recalculated to     13.4491531471862, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row 19147: m2lnL =     18.5227488076609, recalculated to     18.5227488076609, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row 19148: m2lnL =     15.7625040446428, recalculated to     15.7625040446428, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row 19149: m2lnL =     13.1689989086502, recalculated to     13.1689989086502, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row 19150: m2lnL =     14.0712996994683, recalculated to     14.0712996994683, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row 19151: m2lnL =     13.4386166724159, recalculated to     13.4386166724159, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row 19152: m2lnL =     16.5749899771958, recalculated to     16.5749899771958, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row 19153: m2lnL =     13.4376457013347, recalculated to     13.4376457013347, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row 19154: m2lnL =     13.3814394897716, recalculated to     13.3814394897716, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row 19155: m2lnL =     13.4719332101075, recalculated to     13.4719332101075, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row 19156: m2lnL =     13.0832177807984, recalculated to     13.0832177807984, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row 19157: m2lnL =     16.4176865102801, recalculated to     16.4176865102801, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row 19158: m2lnL =     14.3043233360341, recalculated to     14.3043233360341, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row 19159: m2lnL =     14.0411836389849, recalculated to     14.0411836389849, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row 19160: m2lnL =     13.5031224392182, recalculated to     13.5031224392182, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row 19161: m2lnL =     18.5663256118481, recalculated to     18.5663256118481, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row 19162: m2lnL =     15.0633317187742, recalculated to     15.0633317187742, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row 19163: m2lnL =     14.9609813094793, recalculated to     14.9609813094793, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row 19164: m2lnL =      13.692721560396, recalculated to      13.692721560396, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row 19165: m2lnL =     13.9901703406717, recalculated to     13.9901703406717, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row 19166: m2lnL =     21.1273335020789, recalculated to     21.1273335020789, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row 19167: m2lnL =     14.1300967176864, recalculated to     14.1300967176864, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row 19168: m2lnL =     14.9415134524537, recalculated to     14.9415134524537, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row 19169: m2lnL =     15.6942478318705, recalculated to     15.6942478318705, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row 19170: m2lnL =     13.9772263477026, recalculated to     13.9772263477026, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row 19171: m2lnL =     13.1247999149826, recalculated to     13.1247999149826, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row 19172: m2lnL =     13.4051427064686, recalculated to     13.4051427064686, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row 19173: m2lnL =     15.4669714546173, recalculated to     15.4669714546173, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row 19174: m2lnL =     13.7651749598598, recalculated to     13.7651749598598, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row 19175: m2lnL =     14.2883345698245, recalculated to     14.2883345698245, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row 19176: m2lnL =     14.9175589305745, recalculated to     14.9175589305745, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row 19177: m2lnL =     15.8616386058672, recalculated to     15.8616386058672, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row 19178: m2lnL =     15.9389344312416, recalculated to     15.9389344312416, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row 19179: m2lnL =     13.1677025247122, recalculated to     13.1677025247122, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row 19180: m2lnL =     15.6394799134001, recalculated to     15.6394799134001, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row 19181: m2lnL =     13.4110987662924, recalculated to     13.4110987662924, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row 19182: m2lnL =     15.4997916651705, recalculated to     15.4997916651705, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row 19183: m2lnL =     14.9677894357361, recalculated to     14.9677894357361, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row 19184: m2lnL =      13.199090074967, recalculated to      13.199090074967, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row 19185: m2lnL =     15.6523331254426, recalculated to     15.6523331254426, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row 19186: m2lnL =      17.403736810098, recalculated to      17.403736810098, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row 19187: m2lnL =     18.0760688179094, recalculated to     18.0760688179094, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row 19188: m2lnL =     15.5160899092999, recalculated to     15.5160899092999, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row 19189: m2lnL =     13.3043743937334, recalculated to     13.3043743937334, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row 19190: m2lnL =     16.6567677447548, recalculated to     16.6567677447548, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row 19191: m2lnL =     23.3834796199944, recalculated to     23.3834796199944, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row 19192: m2lnL =     15.0848126349587, recalculated to     15.0848126349587, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row 19193: m2lnL =     13.1739193290253, recalculated to     13.1739193290253, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row 19194: m2lnL =     13.3139938549354, recalculated to     13.3139938549354, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row 19195: m2lnL =     13.3600880763456, recalculated to     13.3600880763456, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row 19196: m2lnL =     13.5779597810374, recalculated to     13.5779597810374, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row 19197: m2lnL =     19.9209310719454, recalculated to     19.9209310719454, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row 19198: m2lnL =     15.4128549592561, recalculated to     15.4128549592561, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row 19199: m2lnL =     13.7397120648721, recalculated to     13.7397120648721, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Largest relative error 1.000000e-03 not attained: 1.179657e-03
# # NcmFitESMCMC: ln (eVol) =      -2.20246008497063; ln (gVol) =      -2.15845751458402; lnNorm =      -8.88843200711249
# # NcmFitESMCMC: Running more 10 runs...
# #----------------------------------------------------------------------------------
# # NcmFitESMCMC: Calculating [000010] Ensemble Sampler Markov Chain Monte Carlo runs [APS-Move]
# # Task:NcmFitESMCMC, started at: Mon Jan 04 2021, 14:41:36
# # NcmMSetCatalog: Current mean:   15.09        5.2604       14.915
# # NcmMSetCatalog: Current msd:    0.014159     0.0061769    0.00019264
# # NcmMSetCatalog: Current sd:     1.9721       0.86034      0.026831
# # NcmMSetCatalog: Current var:    3.889        0.74019      0.00071991
# # NcmMSetCatalog: Current tau:    1            1            1
# # NcmMSetCatalog: Current skfac:  1.0021       1.0016       1.0017
# # NcmMSetCatalog: Maximal Shrink factor = 1.00176
# #----------------------------------------------------------------------------------
# # NcmMSetCatalog: Computing the constant break point for parameter `0', sample size `194':
# # NcmMSetCatalog: Constant break point at `0':
# # NcmFitESMCMC:acceptance ratio 96.5000% (last update 98.0000%), offboard ratio  0.0000% (last update  0.0000%).
# # NcmFitESMCMC:last ensemble variance of -2ln(L):       3.68253085374217 (2n = 4), min(-2ln(L)) =       13.0734285937316.
# # Task:NcmFitESMCMC, completed: 200 of 1000, elapsed time: 00:00:00.0117
# # Task:NcmFitESMCMC, mean time: 00:00:00.0000 +/- 00:00:00.0000
# # Task:NcmFitESMCMC, time left: 00:00:00.0360 +/- 00:00:00.0250
# # Task:NcmFitESMCMC, current time:        Mon Jan 04 2021, 14:41:36
# # Task:NcmFitESMCMC, estimated to end at: Mon Jan 04 2021, 14:41:36 +/- 00:00:00.0250
# # NcmMSetCatalog: Current mean:   15.09        5.2611       14.915
# # NcmMSetCatalog: Current msd:    0.014072     0.0061471    0.00019168
# # NcmMSetCatalog: Current sd:     1.97         0.8606       0.026835
# # NcmMSetCatalog: Current var:    3.881        0.74063      0.0007201
# # NcmMSetCatalog: Current tau:    1            1            1
# # NcmMSetCatalog: Current skfac:  1.0022       1.0016       1.0016
# # NcmMSetCatalog: Maximal Shrink factor = 1.00167
# #----------------------------------------------------------------------------------
# # NcmMSetCatalog: Computing the constant break point for parameter `0', sample size `196':
# # NcmMSetCatalog: Constant break point at `0':
# # NcmFitESMCMC:acceptance ratio 96.7500% (last update 96.0000%), offboard ratio  0.0000% (last update  0.0000%).
# # NcmFitESMCMC:last ensemble variance of -2ln(L):       3.76478728322165 (2n = 4), min(-2ln(L)) =       13.0734285937316.
# # Task:NcmFitESMCMC, completed: 400 of 1000, elapsed time: 00:00:00.0234
# # Task:NcmFitESMCMC, mean time: 00:00:00.0001 +/- 00:00:00.0000
# # Task:NcmFitESMCMC, time left: 00:00:00.0310 +/- 00:00:00.0158
# # Task:NcmFitESMCMC, current time:        Mon Jan 04 2021, 14:41:36
# # Task:NcmFitESMCMC, estimated to end at: Mon Jan 04 2021, 14:41:36 +/- 00:00:00.0158
# # NcmMSetCatalog: Current mean:   15.09        5.2617       14.915
# # NcmMSetCatalog: Current msd:    0.01401      0.0061161    0.00019057
# # NcmMSetCatalog: Current sd:     1.9714       0.86061      0.026816
# # NcmMSetCatalog: Current var:    3.8863       0.74064      0.00071911
# # NcmMSetCatalog: Current tau:    1            1            1
# # NcmMSetCatalog: Current skfac:  1.0022       1.0014       1.0015
# # NcmMSetCatalog: Maximal Shrink factor = 1.00151
# #----------------------------------------------------------------------------------
# # NcmMSetCatalog: Computing the constant break point for parameter `0', sample size `198':
# # NcmMSetCatalog: Constant break point at `0':
# # NcmFitESMCMC:acceptance ratio 96.3333% (last update 95.0000%), offboard ratio  0.0000% (last update  0.0000%).
# # NcmFitESMCMC:last ensemble variance of -2ln(L):       3.98524483909816 (2n = 4), min(-2ln(L)) =       13.0734285937316.
# # Task:NcmFitESMCMC, completed: 600 of 1000, elapsed time: 00:00:00.0345
# # Task:NcmFitESMCMC, mean time: 00:00:00.0001 +/- 00:00:00.0000
# # Task:NcmFitESMCMC, time left: 00:00:00.0218 +/- 00:00:00.0090
# # Task:NcmFitESMCMC, current time:        Mon Jan 04 2021, 14:41:36
# # Task:NcmFitESMCMC, estimated to end at: Mon Jan 04 2021, 14:41:36 +/- 00:00:00.0090
# # NcmMSetCatalog: Current mean:   15.089       5.2618       14.915
# # NcmMSetCatalog: Current msd:    0.01394      0.0060807    0.00018965
# # NcmMSetCatalog: Current sd:     1.9714       0.85994      0.026821
# # NcmMSetCatalog: Current var:    3.8865       0.7395       0.00071937
# # NcmMSetCatalog: Current tau:    1            1            1
# # NcmMSetCatalog: Current skfac:  1.0021       1.0014       1.0016
# # NcmMSetCatalog: Maximal Shrink factor = 1.0016
# #----------------------------------------------------------------------------------
# # NcmMSetCatalog: Computing the constant break point for parameter `0', sample size `200':
# # NcmMSetCatalog: Constant break point at `0':
# # NcmFitESMCMC:acceptance ratio 96.6250% (last update 97.0000%), offboard ratio  0.0000% (last update  0.0000%).
# # NcmFitESMCMC:last ensemble variance of -2ln(L):       2.76374077183384 (2n = 4), min(-2ln(L)) =       13.0734285937316.
# # Task:NcmFitESMCMC, completed: 800 of 1000, elapsed time: 00:00:00.0452
# # Task:NcmFitESMCMC, mean time: 00:00:00.0001 +/- 00:00:00.0000
# # Task:NcmFitESMCMC, time left: 00:00:00.0109 +/- 00:00:00.0039
# # Task:NcmFitESMCMC, current time:        Mon Jan 04 2021, 14:41:36
# # Task:NcmFitESMCMC, estimated to end at: Mon Jan 04 2021, 14:41:36 +/- 00:00:00.0039
# # NcmMSetCatalog: Current mean:   15.089       5.2613       14.915
# # NcmMSetCatalog: Current msd:    0.013865     0.0060458    0.00018868
# # NcmMSetCatalog: Current sd:     1.9706       0.85927      0.026816
# # NcmMSetCatalog: Current var:    3.8834       0.73834      0.00071911
# # NcmMSetCatalog: Current tau:    1            1            1
# # NcmMSetCatalog: Current skfac:  1.0022       1.0013       1.0017
# # NcmMSetCatalog: Maximal Shrink factor = 1.00167
# #----------------------------------------------------------------------------------
# # NcmMSetCatalog: Computing the constant break point for parameter `0', sample size `202':
# # NcmMSetCatalog: Constant break point at `0':
# # NcmFitESMCMC:acceptance ratio 96.8000% (last update 98.0000%), offboard ratio  0.0000% (last update  0.0000%).
# # NcmFitESMCMC:last ensemble variance of -2ln(L):        2.8838251346972 (2n = 4), min(-2ln(L)) =       13.0734285937316.
# # Task:NcmFitESMCMC, completed: 1000 of 1000, elapsed time: 00:00:00.0554
# # Task:NcmFitESMCMC, mean time: 00:00:00.0001 +/- 00:00:00.0000
# # Task:NcmFitESMCMC, time left: 00:00:00.0000 +/- 00:00:00.0000
# # Task:NcmFitESMCMC, current time:        Mon Jan 04 2021, 14:41:36
# # Task:NcmFitESMCMC, estimated to end at: Mon Jan 04 2021, 14:41:36 +/- 00:00:00.0000
# #----------------------------------------------------------------------------------
# # NcmMSetCatalog: Calculating catalog effective sample size from chain 202 => 0 using 100 blocks:
# # NcmMSetCatalog: - best cutoff time:         0
# # NcmMSetCatalog: - total number of points:   202  (20200)
# # NcmMSetCatalog: - number of points left:    202  (20200)
# # NcmMSetCatalog: - worst parameter:          NcmFit:m2lnL[00]
# # NcmMSetCatalog: - worst parameter ess:      202.00
# # NcmMSetCatalog: - worst parameter ar order: 0
# # NcmMSetCatalog: - ess's:                    202.00 202.00 202.00
# # NcmFitESMCMC: Largest relative error 1.000000e-03 not attained: 1.149100e-03
# # NcmFitESMCMC: ln (eVol) =      -2.20088004932751; ln (gVol) =      -2.15893672629003; lnNorm =      -8.88791752145329
# # NcmFitESMCMC: Running more 10 runs...
# #----------------------------------------------------------------------------------
# # NcmFitESMCMC: Calculating [000010] Ensemble Sampler Markov Chain Monte Carlo runs [APS-Move]
# # Task:NcmFitESMCMC, started at: Mon Jan 04 2021, 14:41:36
# # NcmMSetCatalog: Current mean:   15.087       5.2606       14.915
# # NcmMSetCatalog: Current msd:    0.013779     0.0060078    0.00018771
# # NcmMSetCatalog: Current sd:     1.968        0.85808      0.02681
# # NcmMSetCatalog: Current var:    3.8729       0.73631      0.00071876
# # NcmMSetCatalog: Current tau:    1            1            1
# # NcmMSetCatalog: Current skfac:  1.0022       1.0013       1.0016
# # NcmMSetCatalog: Maximal Shrink factor = 1.0016
# #----------------------------------------------------------------------------------
# # NcmMSetCatalog: Computing the constant break point for parameter `0', sample size `204':
# # NcmMSetCatalog: Constant break point at `0':
# # NcmFitESMCMC:acceptance ratio 96.8333% (last update 96.0000%), offboard ratio  0.0000% (last update  0.0000%).
# # NcmFitESMCMC:last ensemble variance of -2ln(L):       2.22583886417955 (2n = 4), min(-2ln(L)) =       13.0734285937316.
# # Task:NcmFitESMCMC, completed: 1200 of 2000, elapsed time: 00:00:00.0681
# # Task:NcmFitESMCMC, mean time: 00:00:00.0001 +/- 00:00:00.0000
# # Task:NcmFitESMCMC, time left: 00:00:00.0437 +/- 00:00:00.0127
# # Task:NcmFitESMCMC, current time:        Mon Jan 04 2021, 14:41:36
# # Task:NcmFitESMCMC, estimated to end at: Mon Jan 04 2021, 14:41:36 +/- 00:00:00.0127
# # NcmMSetCatalog: Current mean:   15.087       5.2616       14.915
# # NcmMSetCatalog: Current msd:    0.013706     0.0059762    0.00018676
# # NcmMSetCatalog: Current sd:     1.9672       0.85775      0.026806
# # NcmMSetCatalog: Current var:    3.8697       0.73573      0.00071855
# # NcmMSetCatalog: Current tau:    1            1            1
# # NcmMSetCatalog: Current skfac:  1.0022       1.0014       1.0017
# # NcmMSetCatalog: Maximal Shrink factor = 1.00166
# #----------------------------------------------------------------------------------
# # NcmMSetCatalog: Computing the constant break point for parameter `0', sample size `206':
# # NcmMSetCatalog: Constant break point at `0':
# # NcmFitESMCMC:acceptance ratio 96.4286% (last update 92.0000%), offboard ratio  0.0000% (last update  0.0000%).
# # NcmFitESMCMC:last ensemble variance of -2ln(L):       3.70608663581066 (2n = 4), min(-2ln(L)) =       13.0734285937316.
# # Task:NcmFitESMCMC, completed: 1400 of 2000, elapsed time: 00:00:00.0848
# # Task:NcmFitESMCMC, mean time: 00:00:00.0001 +/- 00:00:00.0000
# # Task:NcmFitESMCMC, time left: 00:00:00.0355 +/- 00:00:00.0097
# # Task:NcmFitESMCMC, current time:        Mon Jan 04 2021, 14:41:36
# # Task:NcmFitESMCMC, estimated to end at: Mon Jan 04 2021, 14:41:36 +/- 00:00:00.0097
# # NcmMSetCatalog: Current mean:   15.087       5.2605       14.915
# # NcmMSetCatalog: Current msd:    0.013633     0.0059463    0.00018571
# # NcmMSetCatalog: Current sd:     1.9662       0.85759      0.026784
# # NcmMSetCatalog: Current var:    3.8658       0.73547      0.00071738
# # NcmMSetCatalog: Current tau:    1            1            1
# # NcmMSetCatalog: Current skfac:  1.0022       1.0012       1.0015
# # NcmMSetCatalog: Maximal Shrink factor = 1.00155
# #----------------------------------------------------------------------------------
# # NcmMSetCatalog: Computing the constant break point for parameter `0', sample size `208':
# # NcmMSetCatalog: Constant break point at `0':
# # NcmFitESMCMC:acceptance ratio 96.4375% (last update 98.0000%), offboard ratio  0.0000% (last update  0.0000%).
# # NcmFitESMCMC:last ensemble variance of -2ln(L):       3.99126626616981 (2n = 4), min(-2ln(L)) =       13.0734285937316.
# # Task:NcmFitESMCMC, completed: 1600 of 2000, elapsed time: 00:00:00.1015
# # Task:NcmFitESMCMC, mean time: 00:00:00.0001 +/- 00:00:00.0000
# # Task:NcmFitESMCMC, time left: 00:00:00.0249 +/- 00:00:00.0064
# # Task:NcmFitESMCMC, current time:        Mon Jan 04 2021, 14:41:36
# # Task:NcmFitESMCMC, estimated to end at: Mon Jan 04 2021, 14:41:36 +/- 00:00:00.0064
# # NcmMSetCatalog: Current mean:   15.085       5.2597       14.915
# # NcmMSetCatalog: Current msd:    0.013557     0.0059185    0.00018477
# # NcmMSetCatalog: Current sd:     1.9646       0.85767      0.026776
# # NcmMSetCatalog: Current var:    3.8595       0.73559      0.00071694
# # NcmMSetCatalog: Current tau:    1            1            1
# # NcmMSetCatalog: Current skfac:  1.0022       1.0011       1.0014
# # NcmMSetCatalog: Maximal Shrink factor = 1.00141
# #----------------------------------------------------------------------------------
# # NcmMSetCatalog: Computing the constant break point for parameter `0', sample size `210':
# # NcmMSetCatalog: Constant break point at `0':
# # NcmFitESMCMC:acceptance ratio 96.1667% (last update 94.0000%), offboard ratio  0.0000% (last update  0.0000%).
# # NcmFitESMCMC:last ensemble variance of -2ln(L):       2.56335586714867 (2n = 4), min(-2ln(L)) =       13.0734285937316.
# # Task:NcmFitESMCMC, completed: 1800 of 2000, elapsed time: 00:00:00.1153
# # Task:NcmFitESMCMC, mean time: 00:00:00.0001 +/- 00:00:00.0000
# # Task:NcmFitESMCMC, time left: 00:00:00.0126 +/- 00:00:00.0030
# # Task:NcmFitESMCMC, current time:        Mon Jan 04 2021, 14:41:36
# # Task:NcmFitESMCMC, estimated to end at: Mon Jan 04 2021, 14:41:36 +/- 00:00:00.0030
# # NcmMSetCatalog: Current mean:   15.085       5.2602       14.915
# # NcmMSetCatalog: Current msd:    0.013485     0.0058846    0.00018386
# # NcmMSetCatalog: Current sd:     1.9634       0.85681      0.02677
# # NcmMSetCatalog: Current var:    3.8551       0.73412      0.00071665
# # NcmMSetCatalog: Current tau:    1            1            1
# # NcmMSetCatalog: Current skfac:  1.0022       1.0012       1.0014
# # NcmMSetCatalog: Maximal Shrink factor = 1.00136
# #----------------------------------------------------------------------------------
# # NcmMSetCatalog: Computing the constant break point for parameter `0', sample size `212':
# # NcmMSetCatalog: Constant break point at `0':
# # NcmFitESMCMC:acceptance ratio 96.2500% (last update 98.0000%), offboard ratio  0.0000% (last update  0.0000%).
# # NcmFitESMCMC:last ensemble variance of -2ln(L):       3.54007466333263 (2n = 4), min(-2ln(L)) =       13.0734285937316.
# # Task:NcmFitESMCMC, completed: 2000 of 2000, elapsed time: 00:00:00.1285
# # Task:NcmFitESMCMC, mean time: 00:00:00.0001 +/- 00:00:00.0000
# # Task:NcmFitESMCMC, time left: 00:00:00.0000 +/- 00:00:00.0000
# # Task:NcmFitESMCMC, current time:        Mon Jan 04 2021, 14:41:36
# # Task:NcmFitESMCMC, estimated to end at: Mon Jan 04 2021, 14:41:36 +/- 00:00:00.0000
# #----------------------------------------------------------------------------------
# # NcmMSetCatalog: Calculating catalog effective sample size from chain 212 => 0 using 100 blocks:
# # NcmMSetCatalog: - best cutoff time:         0
# # NcmMSetCatalog: - total number of points:   212  (21200)
# # NcmMSetCatalog: - number of points left:    212  (21200)
# # NcmMSetCatalog: - worst parameter:          NcmFit:m2lnL[00]
# # NcmMSetCatalog: - worst parameter ess:      212.00
# # NcmMSetCatalog: - worst parameter ar order: 0
# # NcmMSetCatalog: - ess's:                    212.00 212.00 212.00
# # NcmFitESMCMC: Largest relative error 1.000000e-03 not attained: 1.118711e-03
# # NcmFitESMCMC: ln (eVol) =      -2.20179038689571; ln (gVol) =      -2.16100434632551; lnNorm =      -8.88808937277618
# # NcmFitESMCMC: Running more 10 runs...
# #----------------------------------------------------------------------------------
# # NcmFitESMCMC: Calculating [000010] Ensemble Sampler Markov Chain Monte Carlo runs [APS-Move]
# # Task:NcmFitESMCMC, started at: Mon Jan 04 2021, 14:41:36
# # NcmMSetCatalog: Current mean:   15.085       5.2591       14.915
# # NcmMSetCatalog: Current msd:    0.013417     0.005856     0.00018306
# # NcmMSetCatalog: Current sd:     1.9627       0.85666      0.02678
# # NcmMSetCatalog: Current var:    3.8523       0.73386      0.00071716
# # NcmMSetCatalog: Current tau:    1            1            1
# # NcmMSetCatalog: Current skfac:  1.0022       1.0012       1.0015
# # NcmMSetCatalog: Maximal Shrink factor = 1.00147
# #----------------------------------------------------------------------------------
# # NcmMSetCatalog: Computing the constant break point for parameter `0', sample size `214':
# # NcmMSetCatalog: Constant break point at `0':
# # NcmFitESMCMC:acceptance ratio 96.3182% (last update 96.0000%), offboard ratio  0.0000% (last update  0.0000%).
# # NcmFitESMCMC:last ensemble variance of -2ln(L):       3.59712205184439 (2n = 4), min(-2ln(L)) =       13.0734285937316.
# # Task:NcmFitESMCMC, completed: 2200 of 3000, elapsed time: 00:00:00.1400
# # Task:NcmFitESMCMC, mean time: 00:00:00.0001 +/- 00:00:00.0000
# # Task:NcmFitESMCMC, time left: 00:00:00.0500 +/- 00:00:00.0109
# # Task:NcmFitESMCMC, current time:        Mon Jan 04 2021, 14:41:36
# # Task:NcmFitESMCMC, estimated to end at: Mon Jan 04 2021, 14:41:36 +/- 00:00:00.0109
# # NcmMSetCatalog: Current mean:   15.085       5.2594       14.915
# # NcmMSetCatalog: Current msd:    0.013355     0.0058246    0.00018221
# # NcmMSetCatalog: Current sd:     1.9628       0.85604      0.02678
# # NcmMSetCatalog: Current var:    3.8525       0.7328       0.00071716
# # NcmMSetCatalog: Current tau:    1            1            1
# # NcmMSetCatalog: Current skfac:  1.0022       1.0012       1.0015
# # NcmMSetCatalog: Maximal Shrink factor = 1.00153
# #----------------------------------------------------------------------------------
# # NcmMSetCatalog: Computing the constant break point for parameter `0', sample size `216':
# # NcmMSetCatalog: Constant break point at `0':
# # NcmFitESMCMC:acceptance ratio 96.3750% (last update 97.0000%), offboard ratio  0.0000% (last update  0.0000%).
# # NcmFitESMCMC:last ensemble variance of -2ln(L):       4.67971327717319 (2n = 4), min(-2ln(L)) =       13.0734285937316.
# # Task:NcmFitESMCMC, completed: 2400 of 3000, elapsed time: 00:00:00.1514
# # Task:NcmFitESMCMC, mean time: 00:00:00.0001 +/- 00:00:00.0000
# # Task:NcmFitESMCMC, time left: 00:00:00.0372 +/- 00:00:00.0078
# # Task:NcmFitESMCMC, current time:        Mon Jan 04 2021, 14:41:36
# # Task:NcmFitESMCMC, estimated to end at: Mon Jan 04 2021, 14:41:36 +/- 00:00:00.0078
# # NcmMSetCatalog: Current mean:   15.084       5.2588       14.915
# # NcmMSetCatalog: Current msd:    0.01329      0.0057923    0.00018146
# # NcmMSetCatalog: Current sd:     1.9622       0.85523      0.026792
# # NcmMSetCatalog: Current var:    3.8501       0.73141      0.00071782
# # NcmMSetCatalog: Current tau:    1            1            1
# # NcmMSetCatalog: Current skfac:  1.0021       1.0012       1.0015
# # NcmMSetCatalog: Maximal Shrink factor = 1.00147
# #----------------------------------------------------------------------------------
# # NcmMSetCatalog: Computing the constant break point for parameter `0', sample size `218':
# # NcmMSetCatalog: Constant break point at `0':
# # NcmFitESMCMC:acceptance ratio 96.6154% (last update 100.0000%), offboard ratio  0.0000% (last update  0.0000%).
# # NcmFitESMCMC:last ensemble variance of -2ln(L):       4.81708279170753 (2n = 4), min(-2ln(L)) =        13.073407631745.
# # Task:NcmFitESMCMC, completed: 2600 of 3000, elapsed time: 00:00:00.1625
# # Task:NcmFitESMCMC, mean time: 00:00:00.0001 +/- 00:00:00.0000
# # Task:NcmFitESMCMC, time left: 00:00:00.0246 +/- 00:00:00.0049
# # Task:NcmFitESMCMC, current time:        Mon Jan 04 2021, 14:41:36
# # Task:NcmFitESMCMC, estimated to end at: Mon Jan 04 2021, 14:41:36 +/- 00:00:00.0049
# # NcmMSetCatalog: Current mean:   15.085       5.2599       14.915
# # NcmMSetCatalog: Current msd:    0.013233     0.0057692    0.00018068
# # NcmMSetCatalog: Current sd:     1.9628       0.85572      0.026799
# # NcmMSetCatalog: Current var:    3.8524       0.73225      0.00071819
# # NcmMSetCatalog: Current tau:    1            1            1
# # NcmMSetCatalog: Current skfac:  1.0022       1.0012       1.0014
# # NcmMSetCatalog: Maximal Shrink factor = 1.00144
# #----------------------------------------------------------------------------------
# # NcmMSetCatalog: Computing the constant break point for parameter `0', sample size `220':
# # NcmMSetCatalog: Constant break point at `0':
# # NcmFitESMCMC:acceptance ratio 96.4286% (last update 92.0000%), offboard ratio  0.0000% (last update  0.0000%).
# # NcmFitESMCMC:last ensemble variance of -2ln(L):        4.2011914114323 (2n = 4), min(-2ln(L)) =        13.073407631745.
# # Task:NcmFitESMCMC, completed: 2800 of 3000, elapsed time: 00:00:00.1737
# # Task:NcmFitESMCMC, mean time: 00:00:00.0001 +/- 00:00:00.0000
# # Task:NcmFitESMCMC, time left: 00:00:00.0122 +/- 00:00:00.0024
# # Task:NcmFitESMCMC, current time:        Mon Jan 04 2021, 14:41:36
# # Task:NcmFitESMCMC, estimated to end at: Mon Jan 04 2021, 14:41:36 +/- 00:00:00.0024
# # NcmMSetCatalog: Current mean:   15.085       5.2606       14.915
# # NcmMSetCatalog: Current msd:    0.013181     0.0057485    0.00017996
# # NcmMSetCatalog: Current sd:     1.9639       0.8565       0.026814
# # NcmMSetCatalog: Current var:    3.8571       0.73359      0.00071899
# # NcmMSetCatalog: Current tau:    1            1            1
# # NcmMSetCatalog: Current skfac:  1.0022       1.0013       1.0015
# # NcmMSetCatalog: Maximal Shrink factor = 1.00147
# #----------------------------------------------------------------------------------
# # NcmMSetCatalog: Computing the constant break point for parameter `0', sample size `222':
# # NcmMSetCatalog: Constant break point at `0':
# # NcmFitESMCMC:acceptance ratio 96.4000% (last update 97.0000%), offboard ratio  0.0000% (last update  0.0000%).
# # NcmFitESMCMC:last ensemble variance of -2ln(L):       5.36225054988558 (2n = 4), min(-2ln(L)) =        13.073407631745.
# # Task:NcmFitESMCMC, completed: 3000 of 3000, elapsed time: 00:00:00.1850
# # Task:NcmFitESMCMC, mean time: 00:00:00.0001 +/- 00:00:00.0000
# # Task:NcmFitESMCMC, time left: 00:00:00.0000 +/- 00:00:00.0000
# # Task:NcmFitESMCMC, current time:        Mon Jan 04 2021, 14:41:36
# # Task:NcmFitESMCMC, estimated to end at: Mon Jan 04 2021, 14:41:36 +/- 00:00:00.0000
# #----------------------------------------------------------------------------------
# # NcmMSetCatalog: Calculating catalog effective sample size from chain 222 => 0 using 100 blocks:
# # NcmMSetCatalog: - best cutoff time:         0
# # NcmMSetCatalog: - total number of points:   222  (22200)
# # NcmMSetCatalog: - number of points left:    222  (22200)
# # NcmMSetCatalog: - worst parameter:          NcmFit:m2lnL[00]
# # NcmMSetCatalog: - worst parameter ess:      222.00
# # NcmMSetCatalog: - worst parameter ar order: 0
# # NcmMSetCatalog: - ess's:                    222.00 222.00 222.00
# # NcmFitESMCMC: Largest relative error 1.000000e-03 not attained: 1.092740e-03
# # NcmFitESMCMC: ln (eVol) =      -2.20203529207276; ln (gVol) =      -2.16099842852802; lnNorm =      -8.88815557589515
# # NcmFitESMCMC: Running more 10 runs...
# #----------------------------------------------------------------------------------
# # NcmFitESMCMC: Calculating [000010] Ensemble Sampler Markov Chain Monte Carlo runs [APS-Move]
# # Task:NcmFitESMCMC, started at: Mon Jan 04 2021, 14:41:36
# # NcmMSetCatalog: Current mean:   15.085       5.2604       14.915
# # NcmMSetCatalog: Current msd:    0.013112     0.0057192    0.00017925
# # NcmMSetCatalog: Current sd:     1.9624       0.85597      0.026828
# # NcmMSetCatalog: Current var:    3.851        0.73268      0.00071976
# # NcmMSetCatalog: Current tau:    1            1            1
# # NcmMSetCatalog: Current skfac:  1.0022       1.0013       1.0016
# # NcmMSetCatalog: Maximal Shrink factor = 1.00155
# #----------------------------------------------------------------------------------
# # NcmMSetCatalog: Computing the constant break point for parameter `0', sample size `224':
# # NcmMSetCatalog: Constant break point at `0':
# # NcmFitESMCMC:acceptance ratio 96.2188% (last update 94.0000%), offboard ratio  0.0000% (last update  0.0000%).
# # NcmFitESMCMC:last ensemble variance of -2ln(L):       3.20741435743487 (2n = 4), min(-2ln(L)) =        13.073407631745.
# # Task:NcmFitESMCMC, completed: 3200 of 4000, elapsed time: 00:00:00.1963
# # Task:NcmFitESMCMC, mean time: 00:00:00.0001 +/- 00:00:00.0000
# # Task:NcmFitESMCMC, time left: 00:00:00.0485 +/- 00:00:00.0088
# # Task:NcmFitESMCMC, current time:        Mon Jan 04 2021, 14:41:36
# # Task:NcmFitESMCMC, estimated to end at: Mon Jan 04 2021, 14:41:36 +/- 00:00:00.0088
# # NcmMSetCatalog: Current mean:   15.086       5.26         14.915
# # NcmMSetCatalog: Current msd:    0.013042     0.0056934    0.00017859
# # NcmMSetCatalog: Current sd:     1.9607       0.8559       0.026849
# # NcmMSetCatalog: Current var:    3.8444       0.73256      0.00072085
# # NcmMSetCatalog: Current tau:    1            1            1
# # NcmMSetCatalog: Current skfac:  1.0021       1.0012       1.0014
# # NcmMSetCatalog: Maximal Shrink factor = 1.00136
# #----------------------------------------------------------------------------------
# # NcmMSetCatalog: Computing the constant break point for parameter `0', sample size `226':
# # NcmMSetCatalog: Constant break point at `0':
# # NcmFitESMCMC:acceptance ratio 96.2353% (last update 96.0000%), offboard ratio  0.0000% (last update  0.0000%).
# # NcmFitESMCMC:last ensemble variance of -2ln(L):       2.79695140387444 (2n = 4), min(-2ln(L)) =        13.073407631745.
# # Task:NcmFitESMCMC, completed: 3400 of 4000, elapsed time: 00:00:00.2076
# # Task:NcmFitESMCMC, mean time: 00:00:00.0001 +/- 00:00:00.0000
# # Task:NcmFitESMCMC, time left: 00:00:00.0362 +/- 00:00:00.0063
# # Task:NcmFitESMCMC, current time:        Mon Jan 04 2021, 14:41:36
# # Task:NcmFitESMCMC, estimated to end at: Mon Jan 04 2021, 14:41:36 +/- 00:00:00.0063
# # NcmMSetCatalog: Current mean:   15.086       5.2592       14.915
# # NcmMSetCatalog: Current msd:    0.012998     0.0056653    0.00017788
# # NcmMSetCatalog: Current sd:     1.9626       0.85545      0.026859
# # NcmMSetCatalog: Current var:    3.8518       0.73179      0.00072142
# # NcmMSetCatalog: Current tau:    1            1            1
# # NcmMSetCatalog: Current skfac:  1.002        1.0012       1.0013
# # NcmMSetCatalog: Maximal Shrink factor = 1.00132
# #----------------------------------------------------------------------------------
# # NcmMSetCatalog: Computing the constant break point for parameter `0', sample size `228':
# # NcmMSetCatalog: Constant break point at `0':
# # NcmFitESMCMC:acceptance ratio 96.2500% (last update 95.0000%), offboard ratio  0.0000% (last update  0.0000%).
# # NcmFitESMCMC:last ensemble variance of -2ln(L):       4.93496079120789 (2n = 4), min(-2ln(L)) =        13.073407631745.
# # Task:NcmFitESMCMC, completed: 3600 of 4000, elapsed time: 00:00:00.2188
# # Task:NcmFitESMCMC, mean time: 00:00:00.0001 +/- 00:00:00.0000
# # Task:NcmFitESMCMC, time left: 00:00:00.0240 +/- 00:00:00.0041
# # Task:NcmFitESMCMC, current time:        Mon Jan 04 2021, 14:41:36
# # Task:NcmFitESMCMC, estimated to end at: Mon Jan 04 2021, 14:41:36 +/- 00:00:00.0041
# # NcmMSetCatalog: Current mean:   15.085       5.2591       14.915
# # NcmMSetCatalog: Current msd:    0.012948     0.0056414    0.00017705
# # NcmMSetCatalog: Current sd:     1.9637       0.85556      0.026851
# # NcmMSetCatalog: Current var:    3.8559       0.73198      0.00072099
# # NcmMSetCatalog: Current tau:    1            1            1
# # NcmMSetCatalog: Current skfac:  1.002        1.0012       1.0014
# # NcmMSetCatalog: Maximal Shrink factor = 1.00142
# #----------------------------------------------------------------------------------
# # NcmMSetCatalog: Computing the constant break point for parameter `0', sample size `230':
# # NcmMSetCatalog: Constant break point at `0':
# # NcmFitESMCMC:acceptance ratio 96.2895% (last update 95.0000%), offboard ratio  0.0000% (last update  0.0000%).
# # NcmFitESMCMC:last ensemble variance of -2ln(L):       4.02421608039569 (2n = 4), min(-2ln(L)) =        13.073407631745.
# # Task:NcmFitESMCMC, completed: 3800 of 4000, elapsed time: 00:00:00.2299
# # Task:NcmFitESMCMC, mean time: 00:00:00.0001 +/- 00:00:00.0000
# # Task:NcmFitESMCMC, time left: 00:00:00.0120 +/- 00:00:00.0020
# # Task:NcmFitESMCMC, current time:        Mon Jan 04 2021, 14:41:36
# # Task:NcmFitESMCMC, estimated to end at: Mon Jan 04 2021, 14:41:36 +/- 00:00:00.0020
# # NcmMSetCatalog: Current mean:   15.086       5.2599       14.915
# # NcmMSetCatalog: Current msd:    0.012893     0.0056151    0.00017635
# # NcmMSetCatalog: Current sd:     1.9638       0.85527      0.02686
# # NcmMSetCatalog: Current var:    3.8566       0.73149      0.00072149
# # NcmMSetCatalog: Current tau:    1            1            1
# # NcmMSetCatalog: Current skfac:  1.0021       1.0012       1.0014
# # NcmMSetCatalog: Maximal Shrink factor = 1.0014
# #----------------------------------------------------------------------------------
# # NcmMSetCatalog: Computing the constant break point for parameter `0', sample size `232':
# # NcmMSetCatalog: Constant break point at `0':
# # NcmFitESMCMC:acceptance ratio 96.2750% (last update 97.0000%), offboard ratio  0.0000% (last update  0.0000%).
# # NcmFitESMCMC:last ensemble variance of -2ln(L):        4.1769992423178 (2n = 4), min(-2ln(L)) =        13.073407631745.
# # Task:NcmFitESMCMC, completed: 4000 of 4000, elapsed time: 00:00:00.2412
# # Task:NcmFitESMCMC, mean time: 00:00:00.0001 +/- 00:00:00.0000
# # Task:NcmFitESMCMC, time left: 00:00:00.0000 +/- 00:00:00.0000
# # Task:NcmFitESMCMC, current time:        Mon Jan 04 2021, 14:41:36
# # Task:NcmFitESMCMC, estimated to end at: Mon Jan 04 2021, 14:41:36 +/- 00:00:00.0000
# #----------------------------------------------------------------------------------
# # NcmMSetCatalog: Calculating catalog effective sample size from chain 232 => 0 using 100 blocks:
# # NcmMSetCatalog: - best cutoff time:         0
# # NcmMSetCatalog: - total number of points:   232  (23200)
# # NcmMSetCatalog: - number of points left:    232  (23200)
# # NcmMSetCatalog: - worst parameter:          NcmFit:m2lnL[00]
# # NcmMSetCatalog: - worst parameter ess:      232.00
# # NcmMSetCatalog: - worst parameter ar order: 0
# # NcmMSetCatalog: - ess's:                    232.00 232.00 232.00
# # NcmFitESMCMC: Largest relative error 1.000000e-03 not attained: 1.067536e-03
# # NcmFitESMCMC: ln (eVol) =      -2.20145916927412; ln (gVol) =       -2.1606120386072; lnNorm =      -8.88755729086739
# # NcmFitESMCMC: Running more 10 runs...
# #----------------------------------------------------------------------------------
# # NcmFitESMCMC: Calculating [000010] Ensemble Sampler Markov Chain Monte Carlo runs [APS-Move]
# # Task:NcmFitESMCMC, started at: Mon Jan 04 2021, 14:41:36
# # NcmMSetCatalog: Current mean:   15.085       5.2592       14.915
# # NcmMSetCatalog: Current msd:    0.012837     0.0055903    0.00017566
# # NcmMSetCatalog: Current sd:     1.9637       0.85515      0.026871
# # NcmMSetCatalog: Current var:    3.8562       0.73128      0.00072206
# # NcmMSetCatalog: Current tau:    1            1            1
# # NcmMSetCatalog: Current skfac:  1.002        1.0012       1.0014
# # NcmMSetCatalog: Maximal Shrink factor = 1.0014
# #----------------------------------------------------------------------------------
# # NcmMSetCatalog: Computing the constant break point for parameter `0', sample size `234':
# # NcmMSetCatalog: Constant break point at `0':
# # NcmFitESMCMC:acceptance ratio 96.2381% (last update 96.0000%), offboard ratio  0.0000% (last update  0.0000%).
# # NcmFitESMCMC:last ensemble variance of -2ln(L):       4.41505937466059 (2n = 4), min(-2ln(L)) =        13.073407631745.
# # Task:NcmFitESMCMC, completed: 4200 of 5000, elapsed time: 00:00:00.2527
# # Task:NcmFitESMCMC, mean time: 00:00:00.0001 +/- 00:00:00.0000
# # Task:NcmFitESMCMC, time left: 00:00:00.0476 +/- 00:00:00.0075
# # Task:NcmFitESMCMC, current time:        Mon Jan 04 2021, 14:41:36
# # Task:NcmFitESMCMC, estimated to end at: Mon Jan 04 2021, 14:41:36 +/- 00:00:00.0075
# # NcmMSetCatalog: Current mean:   15.086       5.2592       14.915
# # NcmMSetCatalog: Current msd:    0.012783     0.0055734    0.00017499
# # NcmMSetCatalog: Current sd:     1.9638       0.8562       0.026883
# # NcmMSetCatalog: Current var:    3.8565       0.73307      0.00072268
# # NcmMSetCatalog: Current tau:    1            1            1
# # NcmMSetCatalog: Current skfac:  1.002        1.0012       1.0013
# # NcmMSetCatalog: Maximal Shrink factor = 1.00133
# #----------------------------------------------------------------------------------
# # NcmMSetCatalog: Computing the constant break point for parameter `0', sample size `236':
# # NcmMSetCatalog: Constant break point at `0':
# # NcmFitESMCMC:acceptance ratio 96.2045% (last update 98.0000%), offboard ratio  0.0000% (last update  0.0000%).
# # NcmFitESMCMC:last ensemble variance of -2ln(L):       3.89630036991412 (2n = 4), min(-2ln(L)) =        13.073407631745.
# # Task:NcmFitESMCMC, completed: 4400 of 5000, elapsed time: 00:00:00.2640
# # Task:NcmFitESMCMC, mean time: 00:00:00.0001 +/- 00:00:00.0000
# # Task:NcmFitESMCMC, time left: 00:00:00.0357 +/- 00:00:00.0055
# # Task:NcmFitESMCMC, current time:        Mon Jan 04 2021, 14:41:36
# # Task:NcmFitESMCMC, estimated to end at: Mon Jan 04 2021, 14:41:36 +/- 00:00:00.0055
# # NcmMSetCatalog: Current mean:   15.087       5.2598       14.915
# # NcmMSetCatalog: Current msd:    0.01273      0.0055509    0.00017434
# # NcmMSetCatalog: Current sd:     1.9639       0.85636      0.026896
# # NcmMSetCatalog: Current var:    3.857        0.73334      0.0007234
# # NcmMSetCatalog: Current tau:    1            1            1
# ...
# # NcmMSetCatalog: - worst parameter ess:      247.00
# # NcmMSetCatalog: - worst parameter ar order: 0
# # NcmMSetCatalog: - ess's:                    247.00 247.00 247.00
# # NcmMSetCatalog: Trimming the catalog at: 15.
# # NcmFitESMCMC: Largest relative error 1.000000e-03 not attained: 1.032422e-03
# # NcmFitESMCMC: ln (eVol) =      -2.20261236218184; ln (gVol) =      -2.16431170117024; lnNorm =      -8.88785261734176
# # NcmFitESMCMC: Running more 10 runs...
# #----------------------------------------------------------------------------------
# # NcmFitESMCMC: Calculating [000010] Ensemble Sampler Markov Chain Monte Carlo runs [APS-Move]
# # Task:NcmFitESMCMC, started at: Mon Jan 04 2021, 14:41:36
# # NcmMSetCatalog: Current mean:   15.084       5.2536       14.915
# # NcmMSetCatalog: Current msd:    0.012406     0.0054062    0.00017023
# # NcmMSetCatalog: Current sd:     1.9577       0.85309      0.026862
# # NcmMSetCatalog: Current var:    3.8324       0.72775      0.00072156
# # NcmMSetCatalog: Current tau:    1            1            1
# # NcmMSetCatalog: Current skfac:  1.0015       1.0011       1.0015
# # NcmMSetCatalog: Maximal Shrink factor = 1.00147
# #----------------------------------------------------------------------------------
# # NcmMSetCatalog: Computing the constant break point for parameter `0', sample size `249':
# # NcmMSetCatalog: Constant break point at `0':
# # NcmFitESMCMC:acceptance ratio 95.9722% (last update 94.0000%), offboard ratio  0.0000% (last update  0.0000%).
# # NcmFitESMCMC:last ensemble variance of -2ln(L):       3.33372873350307 (2n = 4), min(-2ln(L)) =        13.073407631745.
# # Task:NcmFitESMCMC, completed: 7200 of 8000, elapsed time: 00:00:00.4199
# # Task:NcmFitESMCMC, mean time: 00:00:00.0001 +/- 00:00:00.0000
# # Task:NcmFitESMCMC, time left: 00:00:00.0464 +/- 00:00:00.0056
# # Task:NcmFitESMCMC, current time:        Mon Jan 04 2021, 14:41:37
# # Task:NcmFitESMCMC, estimated to end at: Mon Jan 04 2021, 14:41:37 +/- 00:00:00.0056
# # NcmMSetCatalog: Current mean:   15.084       5.2533       14.915
# # NcmMSetCatalog: Current msd:    0.012356     0.0053853    0.00016958
# # NcmMSetCatalog: Current sd:     1.9575       0.85319      0.026867
# # NcmMSetCatalog: Current var:    3.832        0.72794      0.00072182
# # NcmMSetCatalog: Current tau:    1            1            1
# # NcmMSetCatalog: Current skfac:  1.0014       1.0011       1.0014
# # NcmMSetCatalog: Maximal Shrink factor = 1.00145
# #----------------------------------------------------------------------------------
# # NcmMSetCatalog: Computing the constant break point for parameter `0', sample size `251':
# # NcmMSetCatalog: Constant break point at `0':
# # NcmFitESMCMC:acceptance ratio 95.9865% (last update 98.0000%), offboard ratio  0.0000% (last update  0.0000%).
# # NcmFitESMCMC:last ensemble variance of -2ln(L):       3.75715729609637 (2n = 4), min(-2ln(L)) =        13.073407631745.
# # Task:NcmFitESMCMC, completed: 7400 of 8000, elapsed time: 00:00:00.4303
# # Task:NcmFitESMCMC, mean time: 00:00:00.0001 +/- 00:00:00.0000
# # Task:NcmFitESMCMC, time left: 00:00:00.0347 +/- 00:00:00.0041
# # Task:NcmFitESMCMC, current time:        Mon Jan 04 2021, 14:41:37
# # Task:NcmFitESMCMC, estimated to end at: Mon Jan 04 2021, 14:41:37 +/- 00:00:00.0041
# # NcmMSetCatalog: Current mean:   15.087       5.2537       14.915
# # NcmMSetCatalog: Current msd:    0.012326     0.0053683    0.00016907
# # NcmMSetCatalog: Current sd:     1.9606       0.85389      0.026892
# # NcmMSetCatalog: Current var:    3.8438       0.72912      0.00072316
# # NcmMSetCatalog: Current tau:    1            1            1
# # NcmMSetCatalog: Current skfac:  1.0014       1.0011       1.0015
# # NcmMSetCatalog: Maximal Shrink factor = 1.00149
# #----------------------------------------------------------------------------------
# # NcmMSetCatalog: Computing the constant break point for parameter `0', sample size `253':
# # NcmMSetCatalog: Constant break point at `0':
# # NcmFitESMCMC:acceptance ratio 95.9474% (last update 94.0000%), offboard ratio  0.0000% (last update  0.0000%).
# # NcmFitESMCMC:last ensemble variance of -2ln(L):       5.43733194815016 (2n = 4), min(-2ln(L)) =        13.073407631745.
# # Task:NcmFitESMCMC, completed: 7600 of 8000, elapsed time: 00:00:00.4416
# # Task:NcmFitESMCMC, mean time: 00:00:00.0001 +/- 00:00:00.0000
# # Task:NcmFitESMCMC, time left: 00:00:00.0231 +/- 00:00:00.0027
# # Task:NcmFitESMCMC, current time:        Mon Jan 04 2021, 14:41:37
# # Task:NcmFitESMCMC, estimated to end at: Mon Jan 04 2021, 14:41:37 +/- 00:00:00.0027
# # NcmMSetCatalog: Current mean:   15.088       5.2534       14.915
# # NcmMSetCatalog: Current msd:    0.012304     0.0053517    0.00016847
# # NcmMSetCatalog: Current sd:     1.9649       0.85459      0.026902
# # NcmMSetCatalog: Current var:    3.8607       0.73033      0.0007237
# # NcmMSetCatalog: Current tau:    1            1            1
# # NcmMSetCatalog: Current skfac:  1.0014       1.0011       1.0014
# # NcmMSetCatalog: Maximal Shrink factor = 1.00145
# #----------------------------------------------------------------------------------
# # NcmMSetCatalog: Computing the constant break point for parameter `0', sample size `255':
# # NcmMSetCatalog: Constant break point at `0':
# # NcmFitESMCMC:acceptance ratio 95.9103% (last update 92.0000%), offboard ratio  0.0000% (last update  0.0000%).
# # NcmFitESMCMC:last ensemble variance of -2ln(L):       7.64291861555975 (2n = 4), min(-2ln(L)) =        13.073407631745.
# # Task:NcmFitESMCMC, completed: 7800 of 8000, elapsed time: 00:00:00.4520
# # Task:NcmFitESMCMC, mean time: 00:00:00.0001 +/- 00:00:00.0000
# # Task:NcmFitESMCMC, time left: 00:00:00.0115 +/- 00:00:00.0013
# # Task:NcmFitESMCMC, current time:        Mon Jan 04 2021, 14:41:37
# # Task:NcmFitESMCMC, estimated to end at: Mon Jan 04 2021, 14:41:37 +/- 00:00:00.0013
# # NcmMSetCatalog: Current mean:   15.089       5.253        14.915
# # NcmMSetCatalog: Current msd:    0.012268     0.0053317    0.00016788
# # NcmMSetCatalog: Current sd:     1.9667       0.85474      0.026913
# # NcmMSetCatalog: Current var:    3.8677       0.73058      0.00072432
# # NcmMSetCatalog: Current tau:    1            1            1
# # NcmMSetCatalog: Current skfac:  1.0013       1.0011       1.0014
# # NcmMSetCatalog: Maximal Shrink factor = 1.00145
# #----------------------------------------------------------------------------------
# # NcmMSetCatalog: Computing the constant break point for parameter `0', sample size `257':
# # NcmMSetCatalog: Constant break point at `0':
# # NcmFitESMCMC:acceptance ratio 95.9000% (last update 95.0000%), offboard ratio  0.0000% (last update  0.0000%).
# # NcmFitESMCMC:last ensemble variance of -2ln(L):       5.26862594790589 (2n = 4), min(-2ln(L)) =        13.073407631745.
# # Task:NcmFitESMCMC, completed: 8000 of 8000, elapsed time: 00:00:00.4621
# # Task:NcmFitESMCMC, mean time: 00:00:00.0001 +/- 00:00:00.0000
# # Task:NcmFitESMCMC, time left: 00:00:00.0000 +/- 00:00:00.0000
# # Task:NcmFitESMCMC, current time:        Mon Jan 04 2021, 14:41:37
# # Task:NcmFitESMCMC, estimated to end at: Mon Jan 04 2021, 14:41:37 +/- 00:00:00.0000
# #----------------------------------------------------------------------------------
# # NcmMSetCatalog: Calculating catalog effective sample size from chain 257 => 0 using 100 blocks:
# # NcmMSetCatalog: - best cutoff time:         0
# # NcmMSetCatalog: - total number of points:   257  (25700)
# # NcmMSetCatalog: - number of points left:    257  (25700)
# # NcmMSetCatalog: - worst parameter:          NcmFit:m2lnL[00]
# # NcmMSetCatalog: - worst parameter ess:      213.72
# # NcmMSetCatalog: - worst parameter ar order: 0
# # NcmMSetCatalog: - ess's:                    213.72 257.00 257.00
# # NcmFitESMCMC: Largest relative error 1.000000e-03 not attained: 1.014976e-03
# # NcmFitESMCMC: ln (eVol) =      -2.19941281279863; ln (gVol) =      -2.16011084485328; lnNorm =      -8.88669262022111
# # NcmFitESMCMC: Running more 10 runs...
# #----------------------------------------------------------------------------------
# # NcmFitESMCMC: Calculating [000010] Ensemble Sampler Markov Chain Monte Carlo runs [APS-Move]
# # Task:NcmFitESMCMC, started at: Mon Jan 04 2021, 14:41:36
# # NcmMSetCatalog: Current mean:   15.088       5.2538       14.915
# # NcmMSetCatalog: Current msd:    0.013395     0.0053126    0.00016723
# # NcmMSetCatalog: Current sd:     1.9659       0.85498      0.026913
# # NcmMSetCatalog: Current var:    3.8648       0.731        0.00072431
# # NcmMSetCatalog: Current tau:    1.2025       1            1
# # NcmMSetCatalog: Current skfac:  1.0013       1.0011       1.0014
# # NcmMSetCatalog: Maximal Shrink factor = 1.00139
# #----------------------------------------------------------------------------------
# # NcmMSetCatalog: Computing the constant break point for parameter `0', sample size `259':
# # NcmMSetCatalog: Constant break point at `0':
# # NcmFitESMCMC:acceptance ratio 95.8902% (last update 97.0000%), offboard ratio  0.0000% (last update  0.0000%).
# # NcmFitESMCMC:last ensemble variance of -2ln(L):       3.61099334929703 (2n = 4), min(-2ln(L)) =        13.073407631745.
# # Task:NcmFitESMCMC, completed: 8200 of 9000, elapsed time: 00:00:00.4738
# # Task:NcmFitESMCMC, mean time: 00:00:00.0001 +/- 00:00:00.0000
# # Task:NcmFitESMCMC, time left: 00:00:00.0460 +/- 00:00:00.0052
# # Task:NcmFitESMCMC, current time:        Mon Jan 04 2021, 14:41:37
# # Task:NcmFitESMCMC, estimated to end at: Mon Jan 04 2021, 14:41:37 +/- 00:00:00.0052
# # NcmMSetCatalog: Current mean:   15.089       5.2543       14.915
# # NcmMSetCatalog: Current msd:    0.013355     0.0052954    0.00016666
# # NcmMSetCatalog: Current sd:     1.9675       0.8555       0.026924
# # NcmMSetCatalog: Current var:    3.8709       0.73189      0.00072493
# # NcmMSetCatalog: Current tau:    1.2025       1            1
# # NcmMSetCatalog: Current skfac:  1.0013       1.0011       1.0013
# # NcmMSetCatalog: Maximal Shrink factor = 1.00132
# #----------------------------------------------------------------------------------
# # NcmMSetCatalog: Computing the constant break point for parameter `0', sample size `261':
# # NcmMSetCatalog: Constant break point at `0':
# # NcmFitESMCMC:acceptance ratio 95.8095% (last update 86.0000%), offboard ratio  0.0000% (last update  0.0000%).
# # NcmFitESMCMC:last ensemble variance of -2ln(L):        4.1768169965836 (2n = 4), min(-2ln(L)) =        13.073407631745.
# # Task:NcmFitESMCMC, completed: 8400 of 9000, elapsed time: 00:00:00.4887
# # Task:NcmFitESMCMC, mean time: 00:00:00.0001 +/- 00:00:00.0000
# # Task:NcmFitESMCMC, time left: 00:00:00.0346 +/- 00:00:00.0038
# # Task:NcmFitESMCMC, current time:        Mon Jan 04 2021, 14:41:37
# # Task:NcmFitESMCMC, estimated to end at: Mon Jan 04 2021, 14:41:37 +/- 00:00:00.0038
# # NcmMSetCatalog: Current mean:   15.091       5.2546       14.915
# # NcmMSetCatalog: Current msd:    0.013306     0.005273     0.00016605
# # NcmMSetCatalog: Current sd:     1.9678       0.85514      0.026928
# # NcmMSetCatalog: Current var:    3.8724       0.73126      0.00072514
# # NcmMSetCatalog: Current tau:    1.2025       1            1
# # NcmMSetCatalog: Current skfac:  1.0013       1.0011       1.0014
# # NcmMSetCatalog: Maximal Shrink factor = 1.00136
# #----------------------------------------------------------------------------------
# # NcmMSetCatalog: Computing the constant break point for parameter `0', sample size `263':
# # NcmMSetCatalog: Constant break point at `0':
# # NcmFitESMCMC:acceptance ratio 95.8372% (last update 97.0000%), offboard ratio  0.0000% (last update  0.0000%).
# # NcmFitESMCMC:last ensemble variance of -2ln(L):       3.19453677819525 (2n = 4), min(-2ln(L)) =        13.073407631745.
# # Task:NcmFitESMCMC, completed: 8600 of 9000, elapsed time: 00:00:00.5020
# # Task:NcmFitESMCMC, mean time: 00:00:00.0001 +/- 00:00:00.0000
# # Task:NcmFitESMCMC, time left: 00:00:00.0233 +/- 00:00:00.0026
# # Task:NcmFitESMCMC, current time:        Mon Jan 04 2021, 14:41:37
# # Task:NcmFitESMCMC, estimated to end at: Mon Jan 04 2021, 14:41:37 +/- 00:00:00.0026
# # NcmMSetCatalog: Current mean:   15.092       5.2551       14.915
# # NcmMSetCatalog: Current msd:    0.013266     0.0052494    0.00016541
# # NcmMSetCatalog: Current sd:     1.9693       0.85454      0.026927
# # NcmMSetCatalog: Current var:    3.8782       0.73024      0.00072504
# # NcmMSetCatalog: Current tau:    1.2025       1            1
# # NcmMSetCatalog: Current skfac:  1.0013       1.0011       1.0013
# # NcmMSetCatalog: Maximal Shrink factor = 1.00134
# #----------------------------------------------------------------------------------
# # NcmMSetCatalog: Computing the constant break point for parameter `0', sample size `265':
# # NcmMSetCatalog: Constant break point at `0':
# # NcmFitESMCMC:acceptance ratio 95.8864% (last update 98.0000%), offboard ratio  0.0000% (last update  0.0000%).
# # NcmFitESMCMC:last ensemble variance of -2ln(L):       3.86199891048188 (2n = 4), min(-2ln(L)) =        13.073407631745.
# # Task:NcmFitESMCMC, completed: 8800 of 9000, elapsed time: 00:00:00.5131
# # Task:NcmFitESMCMC, mean time: 00:00:00.0001 +/- 00:00:00.0000
# # Task:NcmFitESMCMC, time left: 00:00:00.0116 +/- 00:00:00.0013
# # Task:NcmFitESMCMC, current time:        Mon Jan 04 2021, 14:41:37
# # Task:NcmFitESMCMC, estimated to end at: Mon Jan 04 2021, 14:41:37 +/- 00:00:00.0013
# # NcmMSetCatalog: Current mean:   15.092       5.2559       14.915
# # NcmMSetCatalog: Current msd:    0.013216     0.0052282    0.00016481
# # NcmMSetCatalog: Current sd:     1.9693       0.8543       0.02693
# # NcmMSetCatalog: Current var:    3.878        0.72983      0.00072523
# # NcmMSetCatalog: Current tau:    1.2025       1            1
# # NcmMSetCatalog: Current skfac:  1.0012       1.0011       1.0013
# # NcmMSetCatalog: Maximal Shrink factor = 1.00129
# #----------------------------------------------------------------------------------
# # NcmMSetCatalog: Computing the constant break point for parameter `0', sample size `267':
# # NcmMSetCatalog: Constant break point at `0':
# # NcmFitESMCMC:acceptance ratio 95.8889% (last update 95.0000%), offboard ratio  0.0000% (last update  0.0000%).
# # NcmFitESMCMC:last ensemble variance of -2ln(L):       3.21810213315304 (2n = 4), min(-2ln(L)) =        13.073407631745.
# # Task:NcmFitESMCMC, completed: 9000 of 9000, elapsed time: 00:00:00.5244
# # Task:NcmFitESMCMC, mean time: 00:00:00.0001 +/- 00:00:00.0000
# # Task:NcmFitESMCMC, time left: 00:00:00.0000 +/- 00:00:00.0000
# # Task:NcmFitESMCMC, current time:        Mon Jan 04 2021, 14:41:37
# # Task:NcmFitESMCMC, estimated to end at: Mon Jan 04 2021, 14:41:37 +/- 00:00:00.0000
# #----------------------------------------------------------------------------------
# # NcmMSetCatalog: Calculating catalog effective sample size from chain 267 => 0 using 100 blocks:
# # NcmMSetCatalog: - best cutoff time:         0
# # NcmMSetCatalog: - total number of points:   267  (26700)
# # NcmMSetCatalog: - number of points left:    267  (26700)
# # NcmMSetCatalog: - worst parameter:          NcmFit:m2lnL[00]
# # NcmMSetCatalog: - worst parameter ess:      220.62
# # NcmMSetCatalog: - worst parameter ar order: 0
# # NcmMSetCatalog: - ess's:                    220.62 267.00 267.00
# #----------------------------------------------------------------------------------
# # NcmFitESMCMC: Largest relative error 1.000000e-03 attained: 9.947422e-04
# # NcmMSetCatalog: Current mean:   15.092       5.2559       14.915
# # NcmMSetCatalog: Current msd:    0.013258     0.0052282    0.00016481
# # NcmMSetCatalog: Current sd:     1.9693       0.8543       0.02693
# # NcmMSetCatalog: Current var:    3.878        0.72983      0.00072523
# # NcmMSetCatalog: Current tau:    1.2102       1            1

# %% [markdown]
# ## Correct non- projected model
#
# Here, instead of building an object directly on top of NcmDataGauss*, we use NumCosmo's framework to build non-binned likelihood for weak-lensing cluster analysis.
#
# For that we need two objects: a NcGalaxyWLReducedShearGauss that model a Gaussian distributed reduced shear likelihood, here the observables matrix is simply $(r, \gamma_t, \sigma_{\gamma_t})$ for each galaxy. If the data has spectroscopic redshifts then we use NcGalaxyRedshiftSpec with an array of real redshifts. When photometric errors are included we use the NcGalaxyRedshiftGauss object that receives $(z, \sigma_z)$ for each galaxy.
#
# Once we have the data objects ready we can proceed as in the previous examples.

# %%
def create_nc_data_cluster_wl (theta, g_t, z_source, z_cluster, cosmo, dist, sigma_z = None, sigma_g = None):
    r  = clmm.convert_units (theta, "radians", "Mpc", redshift = z_cluster, cosmo = cosmo)
    ga = Ncm.ObjArray.new ()
    
    sigma_g = 1.0e-4 if not sigma_g else sigma_g
    m_obs = np.column_stack ((r, g_t, np.repeat (sigma_g, len (r))))
    
    grsg = Nc.GalaxyWLReducedShearGauss (pos = Nc.GalaxyWLReducedShearGaussPos.R)
    grsg.set_obs (Ncm.Matrix.new_array (m_obs.flatten (), 3))
    
    if sigma_z:
        gzgs = Nc.GalaxyRedshiftGauss ()
        z_obs = np.column_stack ((z_source, (1.0 + z_source) * sigma_z))
        gzgs.set_obs (Ncm.Matrix.new_array (z_obs.flatten (), 2))
    else:
        gzgs = Nc.GalaxyRedshiftSpec ()
        gzgs.set_z (Ncm.Vector.new_array (z_source))

    gwl  = Nc.GalaxyWL (wl_dist = grsg, gz_dist = gzgs)
    ga.add (gwl)

    nc_dcwl = Nc.DataClusterWL (galaxy_array = ga, z_cluster = z_cluster)
    nc_dcwl.set_init (True)
    
    return nc_dcwl

def create_fit_obj (data_array, mset):
    dset = Ncm.Dataset.new ()
    for data in data_array:
        dset.append_data (data)
    lh = Ncm.Likelihood.new (dset)
    fit = Ncm.Fit.new (Ncm.FitType.NLOPT, "ln-neldermead", lh, mset, Ncm.FitGradType.NUMDIFF_FORWARD)
    #fit.set_params_reltol (1.0e-8)
    #fit.set_m2lnL_reltol (1.0e-11)
    
    return fit

ggt1 = create_nc_data_cluster_wl (theta1, g_t1, cl1.galcat['z'], cluster_z, cosmo, cosmo.dist, sigma_z = None, sigma_g = None)
ggt2 = create_nc_data_cluster_wl (theta2, g_t2, cl2.galcat['z'], cluster_z, cosmo, cosmo.dist, sigma_z = None, sigma_g = None)
ggt3 = create_nc_data_cluster_wl (theta3, g_t3, cl3.galcat['z'], cluster_z, cosmo, cosmo.dist, sigma_z = 0.05, sigma_g = 0.05)

# %% [markdown]
# As the likelihood is not Gaussian, here we compute the [Observed Fisher Matrix](https://en.wikipedia.org/wiki/Observed_information) (`obs_fisher`).

# %%
fit1 = create_fit_obj ([ggt1], mset1)
fit2 = create_fit_obj ([ggt2], mset2)
fit3 = create_fit_obj ([ggt3], mset3)

fit1.run (Ncm.FitRunMsgs.SIMPLE)
fit1.obs_fisher ()
fit1.log_covar ()

fit2.run (Ncm.FitRunMsgs.SIMPLE)
fit2.obs_fisher ()
fit2.log_covar ()

fit3.run (Ncm.FitRunMsgs.SIMPLE)
fit3.obs_fisher ()
fit3.log_covar ()

mest1 = 10**mset1.param_get (MDelta_pi.mid, MDelta_pi.pid)
mest2 = 10**mset2.param_get (MDelta_pi.mid, MDelta_pi.pid)
mest3 = 10**mset3.param_get (MDelta_pi.mid, MDelta_pi.pid)

print ("% 22.15e % 22.15e % 22.15e" % (mest1, mest2, mest3))
# Out:
# #----------------------------------------------------------------------------------
# # Model fitting. Interating using:
# #  - solver:            NLOpt:ln-neldermead
# #  - differentiation:   Numerical differentiantion (forward)
# #..............
# #  Minimum found with precision: |df|/f =  1.00000e-08 and |dx| =  1.00000e-05
# #  Elapsed time: 00 days, 00:00:00.1384960
# #  iteration            [000057]
# #  function evaluations [000059]
# #  gradient evaluations [000000]
# #  degrees of freedom   [009998]
# #  m2lnL     =   0.0247264130923619 (   0.024726413 )
# #  Fit parameters:
# #     3.9999835855765      15.0000069687639
# #----------------------------------------------------------------------------------
# # NcmMSet parameters covariance matrix
# #                                                       -------------------------------
# #      cDelta[04000:00] =  4           +/-  0.0004535   |  1           | -0.6532      |
# # log10MDelta[04000:01] =  15          +/-  4.995e-05   | -0.6532      |  1           |
# #                                                       -------------------------------
# #----------------------------------------------------------------------------------
# # Model fitting. Interating using:
# #  - solver:            NLOpt:ln-neldermead
# #  - differentiation:   Numerical differentiantion (forward)
# #..............
# #  Minimum found with precision: |df|/f =  1.00000e-08 and |dx| =  1.00000e-05
# #  Elapsed time: 00 days, 00:00:00.1751430
# #  iteration            [000059]
# #  function evaluations [000061]
# #  gradient evaluations [000000]
# #  degrees of freedom   [009998]
# #  m2lnL     =    0.655239547895844 (    0.65523955 )
# #  Fit parameters:
# #     4.00018620223259     14.9999967336657
# #----------------------------------------------------------------------------------
# # NcmMSet parameters covariance matrix
# #                                                       -------------------------------
# #      cDelta[04000:00] =  4           +/-  0.0002977   |  1           | -0.705       |
# # log10MDelta[04000:01] =  15          +/-  4.276e-05   | -0.705       |  1           |
# #                                                       -------------------------------
# #----------------------------------------------------------------------------------
# # Model fitting. Interating using:
# #  - solver:            NLOpt:ln-neldermead
# #  - differentiation:   Numerical differentiantion (forward)
# #..............
# #  Minimum found with precision: |df|/f =  1.00000e-08 and |dx| =  1.00000e-05
# #  Elapsed time: 00 days, 00:00:05.9714130
# #  iteration            [000052]
# #  function evaluations [000054]
# #  gradient evaluations [000000]
# #  degrees of freedom   [009998]
# #  m2lnL     =     9707.14717790159 (     9707.1472 )
# #  Fit parameters:
# #     3.98315204012609     15.0221831296522
# #----------------------------------------------------------------------------------
# # NcmMSet parameters covariance matrix
# #                                                       -------------------------------
# #      cDelta[04000:00] =  3.983       +/-  0.2096      |  1           | -0.6822      |
# # log10MDelta[04000:01] =  15.02       +/-  0.02192     | -0.6822      |  1           |
# #                                                       -------------------------------
#  1.000016046300544e+15  9.999924790155086e+14  1.052405549813602e+15

# %% [markdown]
# ## Visualizing the results
#
# Note below that we no longer have biased results, all results are well within the error bars. Note also that the error bars are substantially smaller than in the binned case.

# %%
rr = np.logspace(-0.5, np.log10(5), 100)

gt_model1 = moo1.eval_reduced_shear (rr, cluster_z, np.mean(cl1.galcat['z']))
gt_model2 = moo2.eval_reduced_shear (rr, cluster_z, np.mean(cl2.galcat['z']))
gt_model3 = moo3.eval_reduced_shear (rr, cluster_z, np.mean(cl3.galcat['z']))

m_est1 = 10**mset1.param_get (MDelta_pi.mid, MDelta_pi.pid)
m_est2 = 10**mset2.param_get (MDelta_pi.mid, MDelta_pi.pid)
m_est3 = 10**mset3.param_get (MDelta_pi.mid, MDelta_pi.pid)

m_est_err1 = fit1.covar_sd (MDelta_pi.mid, MDelta_pi.pid) * m_est1 * math.log (10.0)
m_est_err2 = fit2.covar_sd (MDelta_pi.mid, MDelta_pi.pid) * m_est2 * math.log (10.0)
m_est_err3 = fit3.covar_sd (MDelta_pi.mid, MDelta_pi.pid) * m_est3 * math.log (10.0)

print ("% 22.15e +/- %.0e % 22.15e +/- %.0e % 22.15e +/- %.0e" % (m_est1, m_est_err1, m_est2, m_est_err2, m_est3, m_est_err3))
# Out:
#  1.000016046300544e+15 +/- 1e+11  9.999924790155086e+14 +/- 1e+11  1.052405549813602e+15 +/- 5e+13

# %% [markdown]
# ### To investigate further the results we make a MCMC analysis below.

# %%
Ncm.func_eval_set_max_threads (0)
Ncm.func_eval_log_pool_stats ()

init_sampler = Ncm.MSetTransKernGauss.new (0)
init_sampler.set_mset (mset3)
init_sampler.set_prior_from_mset ()
init_sampler.set_cov_from_rescale (1.0e-1)

nwalkers = 100
stretch = Ncm.FitESMCMCWalkerAPS.new (nwalkers, mset3.fparams_len ())

esmcmc  = Ncm.FitESMCMC.new (fit3, nwalkers, init_sampler, stretch, Ncm.FitRunMsgs.SIMPLE)
esmcmc.set_data_file ("example2_fit3_esmcmc_out_aps.fits")
esmcmc.set_auto_trim (True)
esmcmc.set_auto_trim_div (100)
esmcmc.set_max_runs_time (2.0 * 60.0)

esmcmc.start_run ()
esmcmc.run_lre (20, 1.0e-3)
esmcmc.end_run ()
# Out:
# # NcmThreadPool:Unused:      0
# # NcmThreadPool:Max Unused:  2
# # NcmThreadPool:Running:     0
# # NcmThreadPool:Unprocessed: 0
# # NcmThreadPool:Unused:      0
# #----------------------------------------------------------------------------------
# # NcmFitESMCMC: Starting Ensamble Sampler Markov Chain Monte Carlo.
# #   Number of walkers: 0100.
# #   Number of threads: 0000.
# #----------------------------------------------------------------------------------
# # NcmFitESMCMC: Skipping 10000 points (100.000000 iterations), will start at 10001-th point.
# #----------------------------------------------------------------------------------
# # NcmFitESMCMC: validating catalog rows [9900, 10000)
# # NcmFitESMCMC: Catalog row  9900: m2lnL =     9709.01105102956, recalculated to     9709.01105102956, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row  9901: m2lnL =     9712.92555200315, recalculated to     9712.92555200315, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row  9902: m2lnL =     9708.01383528087, recalculated to     9708.01383528087, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row  9903: m2lnL =     9712.00451480405, recalculated to     9712.00451480405, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row  9904: m2lnL =     9707.43276752621, recalculated to     9707.43276752621, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row  9905: m2lnL =     9712.14264150086, recalculated to     9712.14264150086, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row  9906: m2lnL =     9708.15919216783, recalculated to     9708.15919216783, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row  9907: m2lnL =     9708.29834818086, recalculated to     9708.29834818086, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row  9908: m2lnL =     9711.45051125302, recalculated to     9711.45051125302, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row  9909: m2lnL =     9707.91489440858, recalculated to     9707.91489440858, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row  9910: m2lnL =     9708.70680530474, recalculated to     9708.70680530474, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row  9911: m2lnL =     9710.71240288808, recalculated to     9710.71240288808, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row  9912: m2lnL =     9707.72457348558, recalculated to     9707.72457348558, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row  9913: m2lnL =     9709.91195341067, recalculated to     9709.91195341067, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row  9914: m2lnL =     9712.94281173291, recalculated to     9712.94281173291, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row  9915: m2lnL =     9707.20450337979, recalculated to     9707.20450337979, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row  9916: m2lnL =      9707.1543091267, recalculated to      9707.1543091267, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row  9917: m2lnL =      9708.2830285413, recalculated to      9708.2830285413, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row  9918: m2lnL =     9708.02955858617, recalculated to     9708.02955858617, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row  9919: m2lnL =     9708.55600238881, recalculated to     9708.55600238881, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row  9920: m2lnL =     9709.74436174879, recalculated to     9709.74436174879, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row  9921: m2lnL =     9707.43198786792, recalculated to     9707.43198786792, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row  9922: m2lnL =     9707.50683345115, recalculated to     9707.50683345115, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row  9923: m2lnL =     9707.87451481594, recalculated to     9707.87451481594, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row  9924: m2lnL =      9709.4419312694, recalculated to      9709.4419312694, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row  9925: m2lnL =     9712.07489952645, recalculated to     9712.07489952645, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row  9926: m2lnL =     9707.49871435102, recalculated to     9707.49871435102, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row  9927: m2lnL =     9707.48140035972, recalculated to     9707.48140035972, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row  9928: m2lnL =      9708.4886202817, recalculated to      9708.4886202817, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row  9929: m2lnL =     9708.10676391203, recalculated to     9708.10676391203, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row  9930: m2lnL =     9708.49394159325, recalculated to     9708.49394159325, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row  9931: m2lnL =     9707.28883252704, recalculated to     9707.28883252704, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row  9932: m2lnL =     9711.68700493715, recalculated to     9711.68700493715, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row  9933: m2lnL =     9713.39916272833, recalculated to     9713.39916272833, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row  9934: m2lnL =     9708.02740483876, recalculated to     9708.02740483876, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row  9935: m2lnL =     9707.16849882218, recalculated to     9707.16849882218, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row  9936: m2lnL =     9707.24077346919, recalculated to     9707.24077346919, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row  9937: m2lnL =     9708.46364336973, recalculated to     9708.46364336973, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row  9938: m2lnL =      9707.2781464355, recalculated to      9707.2781464355, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row  9939: m2lnL =     9711.02875396817, recalculated to     9711.02875396817, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row  9940: m2lnL =     9707.38344023777, recalculated to     9707.38344023777, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row  9941: m2lnL =     9707.38584824947, recalculated to     9707.38584824947, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row  9942: m2lnL =     9710.79387504807, recalculated to     9710.79387504807, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row  9943: m2lnL =     9708.53719448276, recalculated to     9708.53719448276, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row  9944: m2lnL =     9707.20780463023, recalculated to     9707.20780463023, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row  9945: m2lnL =     9707.51401623125, recalculated to     9707.51401623125, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row  9946: m2lnL =      9707.2873178415, recalculated to      9707.2873178415, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row  9947: m2lnL =     9707.58471593675, recalculated to     9707.58471593675, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row  9948: m2lnL =      9709.9654295778, recalculated to      9709.9654295778, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row  9949: m2lnL =     9708.16361335479, recalculated to     9708.16361335479, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row  9950: m2lnL =     9708.98073166285, recalculated to     9708.98073166285, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row  9951: m2lnL =      9710.0655813042, recalculated to      9710.0655813042, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row  9952: m2lnL =     9708.32087462172, recalculated to     9708.32087462172, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row  9953: m2lnL =     9710.56756642625, recalculated to     9710.56756642625, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row  9954: m2lnL =     9712.55879364114, recalculated to     9712.55879364114, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row  9955: m2lnL =     9708.05750910203, recalculated to     9708.05750910203, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row  9956: m2lnL =     9707.79765301402, recalculated to     9707.79765301402, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row  9957: m2lnL =     9708.36367784482, recalculated to     9708.36367784482, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row  9958: m2lnL =     9708.41518706402, recalculated to     9708.41518706402, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row  9959: m2lnL =     9710.47304768984, recalculated to     9710.47304768984, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row  9960: m2lnL =     9709.87771644519, recalculated to     9709.87771644519, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row  9961: m2lnL =     9707.58662611858, recalculated to     9707.58662611858, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row  9962: m2lnL =     9708.42324866939, recalculated to     9708.42324866939, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row  9963: m2lnL =     9719.32970526708, recalculated to     9719.32970526708, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row  9964: m2lnL =     9707.56636561664, recalculated to     9707.56636561664, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row  9965: m2lnL =     9714.29048022207, recalculated to     9714.29048022207, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row  9966: m2lnL =     9708.49063785897, recalculated to     9708.49063785897, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row  9967: m2lnL =     9709.62364393669, recalculated to     9709.62364393669, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row  9968: m2lnL =     9709.99336870501, recalculated to     9709.99336870501, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row  9969: m2lnL =     9709.19487831957, recalculated to     9709.19487831957, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row  9970: m2lnL =     9710.56209948121, recalculated to     9710.56209948121, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row  9971: m2lnL =     9709.26509203212, recalculated to     9709.26509203212, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row  9972: m2lnL =     9714.83207889775, recalculated to     9714.83207889775, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row  9973: m2lnL =     9707.45574171586, recalculated to     9707.45574171586, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row  9974: m2lnL =     9708.45454654864, recalculated to     9708.45454654864, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row  9975: m2lnL =     9707.69568090063, recalculated to     9707.69568090063, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row  9976: m2lnL =     9707.48062404186, recalculated to     9707.48062404186, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row  9977: m2lnL =     9707.76572335565, recalculated to     9707.76572335565, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row  9978: m2lnL =     9708.02625245979, recalculated to     9708.02625245979, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row  9979: m2lnL =     9708.55620783306, recalculated to     9708.55620783306, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row  9980: m2lnL =     9710.56712068339, recalculated to     9710.56712068339, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row  9981: m2lnL =     9707.50233678019, recalculated to     9707.50233678019, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row  9982: m2lnL =      9710.6161237112, recalculated to      9710.6161237112, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row  9983: m2lnL =     9708.26175752989, recalculated to     9708.26175752989, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row  9984: m2lnL =     9708.37584227394, recalculated to     9708.37584227394, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row  9985: m2lnL =     9707.44700799504, recalculated to     9707.44700799504, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row  9986: m2lnL =     9707.67305385533, recalculated to     9707.67305385533, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row  9987: m2lnL =     9714.70671191098, recalculated to     9714.70671191098, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row  9988: m2lnL =     9713.39373571552, recalculated to     9713.39373571552, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row  9989: m2lnL =     9709.33211645567, recalculated to     9709.33211645567, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row  9990: m2lnL =     9707.36531690857, recalculated to     9707.36531690857, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row  9991: m2lnL =      9707.3006902098, recalculated to      9707.3006902098, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row  9992: m2lnL =     9707.28866673618, recalculated to     9707.28866673618, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row  9993: m2lnL =     9707.96351946538, recalculated to     9707.96351946538, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row  9994: m2lnL =     9714.25021453908, recalculated to     9714.25021453908, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row  9995: m2lnL =     9708.12796305491, recalculated to     9708.12796305491, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row  9996: m2lnL =     9714.26567775787, recalculated to     9714.26567775787, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row  9997: m2lnL =     9710.80843043741, recalculated to     9710.80843043741, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row  9998: m2lnL =     9708.76786494302, recalculated to     9708.76786494302, diff = 0.00000e+00, SUCCEEDED!
# # NcmFitESMCMC: Catalog row  9999: m2lnL =     9707.53021880262, recalculated to     9707.53021880262, diff = 0.00000e+00, SUCCEEDED!
# #----------------------------------------------------------------------------------
# # NcmFitESMCMC: Largest relative error 1.000000e-03 attained: 5.062958e-04
# # NcmMSetCatalog: Current mean:   9709.2       3.9882       15.021
# # NcmMSetCatalog: Current msd:    0.036545     0.0020192    0.00022226
# # NcmMSetCatalog: Current sd:     2.7882       0.20192      0.022226
# # NcmMSetCatalog: Current var:    7.7742       0.040772     0.00049401
# # NcmMSetCatalog: Current tau:    1.7179       1            1

# %% [markdown]
# ### Below we plot both MCMC results
#
# The wrong analysis has a strong bias in $\log_{10}(M_\Delta)$ (the peak of the wrong model is more than $3\sigma$ away from the correct model best-fit) and much larger variance.

# %%
s1d1 = chi2.cdf (1.0, df = 1)
s1d2 = chi2.cdf (4.0, df = 1)
s2d1 = chi2.cdf (1.0, df = 2)
s2d2 = chi2.cdf (4.0, df = 2)
s2d3 = chi2.cdf (9.0, df = 2)
qts = [0.5 - s1d2 / 2.0, 0.5 - s1d1 / 2.0, 0.5, 0.5 + s1d1 / 2.0, 0.5 + s1d2 / 2.0]

mcat = esmcmc.peek_catalog ()
rows = np.array ([mcat.peek_row (i).dup_array () for i in range (nwalkers * 10, mcat.len ())])
params = ["$" + mcat.col_symb (i) + "$" for i in range (mcat.ncols ())]
figure = corner.corner (rows[:,1:], labels = params[1:], reverse = False,
                        quantiles=qts, levels = (s2d1, s2d2, s2d3), 
                        bins = 40, smooth = 0.8, smooth1d = 0.8, color = (0.5, 0.2, 0.5, 1.0))

rows = np.array ([mcat_wrong.peek_row (i).dup_array () for i in range (nwalkers * 10, mcat_wrong.len ())])
params = ["$" + mcat_wrong.col_symb (i) + "$" for i in range (mcat_wrong.ncols ())]
figure = corner.corner (rows[:,1:], labels = params[1:], reverse = False,
                        levels = (s2d1, s2d2, s2d3), color = (0.1, 0.2, 0.5, 0.5),
                        bins = 40, smooth = 0.8, smooth1d = 0.8, fig = figure)


figure.set_size_inches(12, 6)

# %%
ser = Ncm.Serialize.new (0)
data = fit3.lh.dset.get_data (0)
ser.to_file (data, "example2_fit3_data.obj")
