# %% [markdown]
# # Mass conversion between different mass definitions
# ## Mass conversion between spherical overdensity mass definitions
#
# In this notebook, we demonstrates how to convert the mass and concentration between various mass definitions (going from $200m$ to $500c$ in this example), and related functionalities, using both the object-oriented and functional interfaces of the code.

# %%
import clmm
import matplotlib.pyplot as plt
import numpy as np
from default_config import dc2_cosmo as cosmo

# %% [markdown]
# We define a cosmology first:

# %%
# first SOD definition
# paper_modeling = dict(
#    massdef="mean",
#    delta_mdef=200,
#    halo_profile_model="nfw",
# )
# paper_halo = dict(
#    mdelta=1e14,
#    cdelta=4,
#    z_cl=0.4,
# )

from default_config import paper_halo, paper_modeling

# %%
# get a value for alpha
ein_def1 = clmm.Modeling(
    massdef=paper_modeling["massdef"],
    delta_mdef=paper_modeling["delta_mdef"],
    halo_profile_model="einasto",
)
ein_def1.set_mass(paper_halo["mdelta"])
ein_def1.set_concentration(paper_halo["cdelta"])

alpha = ein_def1.get_einasto_alpha(paper_halo["z_cl"])
alpha

# %%
baseline_case = {**paper_halo}
baseline_case["redshift"] = baseline_case.pop("z_cl")
var_mod = {
    "delta_mdef2": (150, 200, 500),
    "halo_profile_model2": ("nfw", "einasto", "hernquist"),
    "massdef2": ("mean", "critical"),
}


def loop_keys(keys_use, current_info, cfg_dict, list_cases):
    if len(keys_use) == 0:
        list_cases.append(
            current_info
            | {
                "data": clmm.convert_profile_mass_concentration(
                    cosmo=cosmo,
                    alpha=alpha,
                    **baseline_case,
                    **current_info,
                )
            }
        )
        return

    new_keys = list(keys_use)
    key = new_keys.pop(0)
    for value in cfg_dict[key]:
        new_info = current_info | {key: value}
        loop_keys(new_keys, new_info, cfg_dict, list_cases)


new_defs3 = []
loop_keys(list(var_mod.keys()), {}, var_mod, new_defs3)

# %%
from paper_formating import prep_plot

# %%
new_defs3

# %%
_config = {
    "delta_mdef2": {
        150: {"c": "C0", "edgecolors": "C0"},
        200: {"c": "C1", "edgecolors": "C1"},
        500: {"c": "C2", "edgecolors": "C2"},
    },
    "halo_profile_model2": {
        "nfw": {"marker": ".", "lw": 0.5, "zorder": 10},
        "einasto": {"marker": "^", "lw": 0.5, "zorder": 2},
        "hernquist": {"marker": "v", "lw": 0.5, "zorder": 2},
    },
    "massdef2": {"mean": {"edgecolors": "1"}, "critical": {"c": "1"}},
}
_leg = {
    "massdef2": r"$\rho$: ",
    "delta_mdef2": r"$\Delta$: ",
    "halo_profile_model2": "",
}
_leg_val = {
    "nfw": "NFW",
    "einasto": "Einasto",
    "hernquist": "Hernquist",
}
fig = prep_plot(figsize=(9, 9))
ax = plt.axes()
for _case in new_defs3:
    _kwargs = {"s": 200}
    label = []
    for key, value in _case.items():
        if key != "data":
            _kwargs.update(_config[key][value])
            label.append(_leg[key] + f"{_leg_val.get(value, value)}")
    label = ", ".join(label)
    ax.scatter(*_case["data"], **_kwargs, label=label)
"""
for i in range(0, len(new_defs3), 2):
    ax.plot(
        *np.transpose(
        (new_defs3[i]["data"],
        new_defs3[i+1]["data"])),
        ls=":",
        lw=.5,
        c=f"C{int(i/6)}"
    )
"""
ax.legend(ncols=3)
# ax.set_xscale("log")
# """
handles, labels = ax.get_legend_handles_labels()

leg1 = ax.legend(
    handles[:6:2],
    [lab.split(", ")[1] for lab in labels[:6:2]],
    loc=(0.38, 0.73),
    fontsize=8,
    # borderpad=2,
    labelspacing=1.1,
)
leg2 = ax.legend(
    handles[::6],
    [lab.split(", ")[0] for lab in labels[::6]],
    loc=(0.015, 0.6),
    fontsize=8,
)
leg3 = ax.legend(
    handles[:2],
    [lab.split(", ")[-1] for lab in labels[:2]],
    loc=(0.015, 0.83),
    fontsize=8,
)
ax.add_artist(leg1)
ax.add_artist(leg2)
# """
ax.set_xlabel("$M$ [$M_\odot$]")
ax.set_ylabel("concentration")
fit_kwargs = {"color": "r", "zorder": 1, "lw": 1}  # , "ls": "--"}
ax.axvline(1e14, **fit_kwargs)
ax.axhline(4, **fit_kwargs)
ax.grid(lw=0.5)
ax.minorticks_on()
ax.grid(which="minor", lw=0.1)
ax.set_axisbelow(True)
plt.tight_layout()
plt.savefig("mass_conversion.png")

# %%
new_defs3

# %%
new_defs4 = [new_defs3[i] for i in [0, 2, 4, 6, 7, 8, 9, 10, 11, 12, 14, 16]]

# %%
_config = {
    "delta_mdef2": {
        150: {"c": "C0", "edgecolors": "C0"},
        200: {"c": "C1", "edgecolors": "C1"},
        500: {"c": "C2", "edgecolors": "C2"},
    },
    "halo_profile_model2": {
        "nfw": {"marker": ".", "lw": 0.5, "zorder": 10},
        "einasto": {"marker": "^", "lw": 0.5, "zorder": 2},
        "hernquist": {"marker": "v", "lw": 0.5, "zorder": 2},
    },
    "massdef2": {"mean": {"edgecolors": "1"}, "critical": {"c": "1"}},
}
_leg = {
    "massdef2": r"$\rho$: ",
    "delta_mdef2": r"$\Delta$: ",
    "halo_profile_model2": "",
}
_leg_val = {
    "nfw": "NFW",
    "einasto": "Einasto",
    "hernquist": "Hernquist",
}
fig = prep_plot(figsize=(9, 9))
ax = plt.axes()
for _case in new_defs4:
    _kwargs = {"s": 200}
    label = []
    for key, value in _case.items():
        if key != "data":
            _kwargs.update(_config[key][value])
            label.append(_leg[key] + f"{_leg_val.get(value, value)}")
    label = ", ".join(label)
    ax.scatter(*_case["data"], **_kwargs, label=label)

ax.legend(ncols=3)
# ax.set_xscale("log")
# """
handles, labels = ax.get_legend_handles_labels()

inds = [3, 5, 7]
leg1 = ax.legend(
    [handles[i] for i in inds],
    [labels[i].split(", ")[1] for i in inds],
    loc=(0.015, 0.77),
    fontsize=7,
    # borderpad=2,
    labelspacing=1.1,
)


inds = [0, 3, 9]
leg2 = ax.legend(
    [handles[i] for i in inds],
    [labels[i].split(", ")[0] for i in inds],
    loc=(0.015, 0.59),
    fontsize=7,
)


inds = [3, 4]
leg3 = ax.legend(
    [handles[i] for i in inds],
    [labels[i].split(", ")[-1] for i in inds],
    loc=(0.34, 0.86),
    fontsize=7,
)
ax.add_artist(leg1)
ax.add_artist(leg2)
# """
ax.set_xlabel("$M$ [$M_\odot$]")
ax.set_ylabel("concentration")
fit_kwargs = {"color": "r", "zorder": 1, "lw": 1}  # , "ls": "--"}
ax.axvline(1e14, **fit_kwargs)
ax.axhline(4, **fit_kwargs)
ax.grid(lw=0.5)
ax.minorticks_on()
ax.grid(which="minor", lw=0.1)
ax.set_axisbelow(True)
plt.tight_layout()
plt.savefig("mass_conversion_simple.png")

# %%
_config = {
    "delta_mdef2": {
        150: {"c": "C0", "edgecolors": "C0"},
        200: {"c": "C1", "edgecolors": "C1"},
        500: {"c": "C2", "edgecolors": "C2"},
    },
    "halo_profile_model2": {
        "nfw": {"marker": ".", "lw": 0.5, "zorder": 10},
        "einasto": {"marker": "^", "lw": 0.5, "zorder": 2},
        "hernquist": {"marker": "v", "lw": 0.5, "zorder": 2},
    },
    "massdef2": {"mean": {"edgecolors": "1"}, "critical": {"c": "1"}},
}
_leg = {
    "massdef2": r"$\rho$: ",
    "delta_mdef2": r"$\Delta$: ",
    "halo_profile_model2": "",
}
_leg_val = {
    "nfw": "NFW",
    "einasto": "Einasto",
    "hernquist": "Hernquist",
}
fig = prep_plot(figsize=(9, 9))
ax = plt.axes()
for _case in new_defs4:
    _kwargs = {"s": 200}
    label = []
    for key, value in _case.items():
        if key != "data":
            _kwargs.update(_config[key][value])
            label.append(_leg[key] + f"{_leg_val.get(value, value)}")
    label = ", ".join(label)
    ax.scatter(*_case["data"], **_kwargs, label=label)

ax.legend(ncols=3)
# ax.set_xscale("log")
# """
handles, labels = ax.get_legend_handles_labels()

inds = [3, 5, 7]
leg1 = ax.legend(
    [handles[i] for i in inds],
    [labels[i].split(", ")[1] for i in inds],
    loc=(0.015, 0.77),
    fontsize=7,
    # borderpad=2,
    labelspacing=1.1,
)


inds = [0, 3, 9]
leg2 = ax.legend(
    [handles[i] for i in inds],
    [labels[i].split(", ")[0] for i in inds],
    loc=(0.015, 0.59),
    fontsize=7,
)


inds = [3, 4]
leg3 = ax.legend(
    [handles[i] for i in inds],
    [labels[i].split(", ")[-1] for i in inds],
    loc=(0.34, 0.86),
    fontsize=7,
)
ax.add_artist(leg1)
ax.add_artist(leg2)
ax.set_yticks([1, 2, 3, 4])
# """
ax.set_xlabel("$M$ [$M_\odot$]")
ax.set_ylabel("concentration")
fit_kwargs = {"color": "r", "zorder": 1, "lw": 1}  # , "ls": "--"}
ax.axvline(1e14, **fit_kwargs)
ax.axhline(4, **fit_kwargs)
ax.grid(lw=0.5)
ax.minorticks_on()
ax.grid(which="minor", lw=0.1)
ax.set_axisbelow(True)
plt.tight_layout()
plt.savefig("mass_conversion_simple.png")

# %%
fig = prep_plot(figsize=(9, 9))
ax = plt.axes()

r_vals = np.logspace(np.log10(0.5), np.log10(2))
r_vals = np.logspace(-1, 1)

for i0, inds in enumerate((range(3), [3, 5, 7], range(9, 12))):
    for i, ls in zip(inds, ["-", "--", ":"]):
        plt.plot(
            r_vals,
            clmm.theory.compute_3d_density(
                r_vals,
                mdelta=new_defs4[i]["data"][0],
                cdelta=new_defs4[i]["data"][1],
                z_cl=0.4,
                cosmo=cosmo,
                massdef=new_defs4[i]["massdef2"],
                delta_mdef=new_defs4[i]["delta_mdef2"],
                halo_profile_model=new_defs4[i]["halo_profile_model2"],
            ),
            color=f"C{i0}",
            lw=3 - i0,
            ls=ls,
        )
for _case in new_defs4:
    _kwargs = {"s": 200}
    label = []
    for key, value in _case.items():
        if key != "data":
            _kwargs.update(_config[key][value])
            label.append(_leg[key] + f"{_leg_val.get(value, value)}")
    label = ", ".join(label)
    _comp_kwargs = dict(
        cosmo=cosmo,
        massdef=_case["massdef2"],
        delta_mdef=_case["delta_mdef2"],
        mdelta=_case["data"][0],
    )
    _r_val = clmm.theory.generic.compute_rdelta(**_comp_kwargs, redshift=0.4)
    ax.scatter(
        _r_val,
        clmm.theory.compute_3d_density(
            _r_val,
            **_comp_kwargs,
            cdelta=_case["data"][1],
            z_cl=0.4,
            halo_profile_model=_case["halo_profile_model2"],
        ),
        **_kwargs,
        label=label,
    )


ax.set_xscale("log")
ax.set_yscale("log")
ax.set_xlabel("$r$ [Mpc]")
ax.set_ylabel("density")
fit_kwargs = {"color": "r", "zorder": 1, "lw": 1}  # , "ls": "--"}
ax.grid(lw=0.5)
ax.minorticks_on()
ax.grid(which="minor", lw=0.1)
ax.set_axisbelow(True)
plt.tight_layout()
plt.savefig("mass_conversion_profiles.png")

# %%
def _get_case_label(_case):
    label = []
    for key, value in _case.items():
        if key != "data":
            label.append(_leg[key] + f"{_leg_val.get(value, value)}")
    label = ", ".join(label)
    return label

# %%
fig = prep_plot(figsize=(9, 9))
ax = plt.axes()

r_vals = np.logspace(np.log10(0.5), np.log10(2))
# r_vals = np.logspace(-1, 1)

for i0, inds in enumerate((range(3), [3, 5, 7], range(9, 12))):
    for i, ls in zip(inds, ["-", "--", ":"]):
        ax.plot(
            r_vals,
            clmm.theory.compute_3d_density(
                r_vals,
                mdelta=new_defs4[i]["data"][0],
                cdelta=new_defs4[i]["data"][1],
                z_cl=0.4,
                cosmo=cosmo,
                massdef=new_defs4[i]["massdef2"],
                delta_mdef=new_defs4[i]["delta_mdef2"],
                halo_profile_model=new_defs4[i]["halo_profile_model2"],
            ),
            color=f"C{i0}",
            lw=1.2,
            ls=ls,
            label=_get_case_label(new_defs4[i]),
        )


for _case in new_defs4:
    _kwargs = {"s": 200}
    for key, value in _case.items():
        if key != "data":
            _kwargs.update(_config[key][value])
    _comp_kwargs = dict(
        cosmo=cosmo,
        massdef=_case["massdef2"],
        delta_mdef=_case["delta_mdef2"],
        mdelta=_case["data"][0],
    )
    _r_val = clmm.theory.generic.compute_rdelta(**_comp_kwargs, redshift=0.4)
    ax.scatter(
        _r_val,
        clmm.theory.compute_3d_density(
            _r_val,
            **_comp_kwargs,
            cdelta=_case["data"][1],
            z_cl=0.4,
            halo_profile_model=_case["halo_profile_model2"],
        ),
        **_kwargs,
    )

ax.legend(fontsize=6)
handles, labels = ax.get_legend_handles_labels()
inds = [0, 1, 2]
leg1 = ax.legend(
    [handles[i] for i in inds],
    [labels[i].split(", ")[1] for i in inds],
    loc=(0.65, 0.77),
    fontsize=7,
    # borderpad=2,
    labelspacing=1.1,
)
inds = [0, 3, 6]
leg2 = ax.legend(
    [handles[i] for i in inds],
    [labels[i].split(", ")[0] for i in inds],
    loc=(0.65, 0.58),
    fontsize=7,
)
ax.add_artist(leg1)


ax.set_xlim(0.65, 1.25)
ax.set_ylim(2e12, 1.7e13)
# ax.set_xscale("log")
# ax.set_yscale("log")
ax.set_xlabel("$r$ [Mpc]")
ax.set_ylabel(r"$\rho(r)$ [$M_\odot Mpc^{-3}$]")
fit_kwargs = {"color": "r", "zorder": 1, "lw": 1}  # , "ls": "--"}
ax.grid(lw=0.5)
ax.minorticks_on()
ax.grid(which="minor", lw=0.1)
ax.set_axisbelow(True)
plt.tight_layout()
plt.savefig("mass_conversion_profiles.png")

# %%
fig = prep_plot(figsize=(9, 9))
ax = plt.axes()

r_vals = np.logspace(np.log10(0.5), np.log10(2))
# r_vals = np.logspace(-1, 1)


base = lambda r: clmm.theory.compute_3d_density(
    r,
    mdelta=new_defs4[3]["data"][0],
    cdelta=new_defs4[3]["data"][1],
    z_cl=0.4,
    cosmo=cosmo,
    massdef=new_defs4[3]["massdef2"],
    delta_mdef=new_defs4[3]["delta_mdef2"],
    halo_profile_model=new_defs4[3]["halo_profile_model2"],
)


for i0, inds in enumerate((range(3), [3, 5, 7], range(9, 12))):
    for i, ls in zip(inds, ["-", "--", ":"]):
        ax.plot(
            r_vals,
            clmm.theory.compute_3d_density(
                r_vals,
                mdelta=new_defs4[i]["data"][0],
                cdelta=new_defs4[i]["data"][1],
                z_cl=0.4,
                cosmo=cosmo,
                massdef=new_defs4[i]["massdef2"],
                delta_mdef=new_defs4[i]["delta_mdef2"],
                halo_profile_model=new_defs4[i]["halo_profile_model2"],
            )
            / base(r_vals),
            color=f"C{i0}",
            lw=0.7,
            ls=ls,
            label=_get_case_label(new_defs4[i]),
        )


for _case in new_defs4:
    _kwargs = {"s": 50}
    for key, value in _case.items():
        if key != "data":
            _kwargs.update(_config[key][value])
    _comp_kwargs = dict(
        cosmo=cosmo,
        massdef=_case["massdef2"],
        delta_mdef=_case["delta_mdef2"],
        mdelta=_case["data"][0],
    )
    _r_val = clmm.theory.generic.compute_rdelta(**_comp_kwargs, redshift=0.4)
    ax.scatter(
        _r_val,
        clmm.theory.compute_3d_density(
            _r_val,
            **_comp_kwargs,
            cdelta=_case["data"][1],
            z_cl=0.4,
            halo_profile_model=_case["halo_profile_model2"],
        )
        / base(_r_val),
        **_kwargs,
    )

ax.legend(fontsize=6)
handles, labels = ax.get_legend_handles_labels()
inds = [0, 1, 2]
leg1 = ax.legend(
    [handles[i] for i in inds],
    [labels[i].split(", ")[1] for i in inds],
    loc=(0.65, 0.77),
    fontsize=7,
    # borderpad=2,
    labelspacing=1.1,
)
inds = [0, 3, 6]
leg2 = ax.legend(
    [handles[i] for i in inds],
    [labels[i].split(", ")[0] for i in inds],
    loc=(0.65, 0.59),
    fontsize=7,
)
ax.add_artist(leg1)


ax.set_xlim(0.6, 1.25)
# ax.set_ylim(2e12, 2.e13)
# ax.set_xscale("log")
# ax.set_yscale("log")
ax.set_xlabel("$r$ [Mpc]")
ax.set_ylabel(r"diff $\rho(r)$ [$M_\odot Mpc^{-3}$]")
fit_kwargs = {"color": "r", "zorder": 1, "lw": 1}  # , "ls": "--"}
ax.grid(lw=0.5)
ax.minorticks_on()
ax.grid(which="minor", lw=0.1)
ax.set_axisbelow(True)
plt.tight_layout()
# plt.savefig("mass_conversion_profiles.png")

# %%
_config = {
    "delta_mdef2": {
        150: {"c": "C0", "edgecolors": "C0"},
        200: {"c": "C1", "edgecolors": "C1"},
        500: {"c": "C2", "edgecolors": "C2"},
    },
    "halo_profile_model2": {
        "nfw": {"marker": ".", "lw": 0.5, "zorder": 10},
        "einasto": {"marker": "^", "lw": 0.5, "zorder": 2},
        "hernquist": {"marker": "v", "lw": 0.5, "zorder": 2},
    },
    "massdef2": {"mean": {"edgecolors": "1"}, "critical": {"c": "1"}},
}
_leg = {
    "massdef2": r"$\rho$: ",
    "delta_mdef2": r"$\Delta$: ",
    "halo_profile_model2": "",
}
_leg_val = {
    "nfw": "NFW",
    "einasto": "Einasto",
    "hernquist": "Hernquist",
}
fig = prep_plot(figsize=(9, 9))
ax = plt.axes()
for _case in new_defs4:
    _kwargs = {"s": 200}
    label = []
    for key, value in _case.items():
        if key != "data":
            _kwargs.update(_config[key][value])
            label.append(_leg[key] + f"{_leg_val.get(value, value)}")
    label = ", ".join(label)
    ax.scatter(*_case["data"], **_kwargs, label=label)
"""
for i, j in ((),):
    ax.plot(
        *np.transpose((new_defs4[i]["data"], new_defs4[j]["data"])),
        ls=":",
        lw=0.5,
        c=f"C{int(i/6)}",
    )

ax.legend(ncols=3)
# ax.set_xscale("log")
# """
handles, labels = ax.get_legend_handles_labels()

inds = [3, 5, 7]
leg1 = ax.legend(
    [handles[i] for i in inds],
    [labels[i].split(", ")[1] for i in inds],
    loc=(0.015, 0.77),
    fontsize=7,
    # borderpad=2,
    labelspacing=1.1,
)


inds = [0, 3, 9]
leg2 = ax.legend(
    [handles[i] for i in inds],
    [labels[i].split(", ")[0] for i in inds],
    loc=(0.015, 0.59),
    fontsize=7,
)


inds = [3, 4]
leg3 = ax.legend(
    [handles[i] for i in inds],
    [labels[i].split(", ")[-1] for i in inds],
    loc=(0.34, 0.86),
    fontsize=7,
)
ax.add_artist(leg1)
ax.add_artist(leg2)
# """
ax.set_xlabel("$M$ [$M_\odot$]")
ax.set_ylabel("concentration")
fit_kwargs = {"color": "r", "zorder": 1, "lw": 1}  # , "ls": "--"}
ax.axvline(1e14, **fit_kwargs)
ax.axhline(4, **fit_kwargs)
ax.grid(lw=0.5)
ax.minorticks_on()
ax.grid(which="minor", lw=0.1)
ax.set_axisbelow(True)
plt.tight_layout()
plt.savefig("mass_conversion_simple_arrow.png")
