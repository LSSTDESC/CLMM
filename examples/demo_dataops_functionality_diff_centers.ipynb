# %% [markdown]
# # Measure a Profile for Different Centers
#
# _the LSST-DESC CLMM team_
#
# This notebook demonstrates how to use `CLMM` to measure a profile and how to estimate a WL halo mass from observations of a galaxy cluster for different centers. This notebook is based on notebook "demo_dataops_functionality.ipynb".

# %%
import matplotlib.pyplot as plt
import clmm
import clmm.dataops
from clmm.dataops import compute_tangential_and_cross_components, make_radial_profile, make_bins
from clmm.galaxycluster import GalaxyCluster
import clmm.utils as u
from clmm import Cosmology
from clmm.support import mock_data as mock
import clmm.galaxycluster as gc
from numpy import random 
import numpy as np
import clmm.dataops as da
from clmm.support.sampler import fitters

# %% [markdown]
# Make sure we know which version we're using

# %%
clmm.__version__
# Out:
# '1.0.7'

# %% [markdown]
# ### Define cosmology object

# %%
mock_cosmo = Cosmology(H0 = 70.0, Omega_dm0 = 0.27 - 0.045, Omega_b0 = 0.045, Omega_k0 = 0.0)
np.random.seed(11)

# %% [markdown]
# ## 1. Generate cluster objects from mock data
# In this example, the mock data only includes galaxies drawn from redshift distribution.

# %% [markdown]
# Define toy cluster parameters for mock data generation

# %%
cosmo = mock_cosmo
cluster_id = "Awesome_cluster"
cluster_m = 1.e15
cluster_z = 0.3
concentration = 4
ngals = 10000

zsrc_min = cluster_z + 0.1 # we only want to draw background galaxies

noisy_data_z = mock.generate_galaxy_catalog(cluster_m,
                                            cluster_z,
                                            concentration,
                                            cosmo,
                                            'chang13',
                                            zsrc_min=zsrc_min,
                                            ngals=ngals)

# %% [markdown]
# We want to load this mock data into several CLMM cluster objects centered between (-0.2, -0.2) - (0.2, 0.2) degrees and save them in a list. The user can change the number of cluster centers if desired. We set the first center to (0,0) for comparison reasons, which corresponds to a == 0.

# %%
center_number = 5
cluster_list = []
for a in range (0, center_number):
    if a == 0:
        cluster_ra = 0.
        cluster_dec = 0.
    else:
        cluster_ra = random.uniform(-0.2, 0.2)
        cluster_dec =random.uniform(-0.2, 0.2)
    cl = clmm.GalaxyCluster(cluster_id, cluster_ra, cluster_dec,
                               cluster_z, noisy_data_z)
    print("Cluster info = ID:", cl.unique_id, "; ra:", cl.ra,
          "; dec:", cl.dec, "; z_l :", cl.z)
    print("The number of source galaxies is :", len(cl.galcat))
    cluster_list.append(cl)
# Out:
# Cluster info = ID: Awesome_cluster ; ra: 0.0 ; dec: 0.0 ; z_l : 0.3
# The number of source galaxies is : 10000
# Cluster info = ID: Awesome_cluster ; ra: 0.05535444916208837 ; dec: 0.1842807487466317 ; z_l : 0.3
# The number of source galaxies is : 10000
# Cluster info = ID: Awesome_cluster ; ra: 0.17275183700457836 ; dec: -0.12177646449521223 ; z_l : 0.3
# The number of source galaxies is : 10000
# Cluster info = ID: Awesome_cluster ; ra: -0.11045853251716227 ; dec: -0.14728430772494586 ; z_l : 0.3
# The number of source galaxies is : 10000
# Cluster info = ID: Awesome_cluster ; ra: -0.03262024052944973 ; dec: -0.13352672412670175 ; z_l : 0.3
# The number of source galaxies is : 10000

# %% [markdown]
# ## 2. Basic checks and plots
# - galaxy positions
# - redshift distribution
#
# For a better visualization, we plot all the different centers in the Cluster, represented by the red dots.

# %%
bin_edges = make_bins(0.3, 6, 10) # We want to specify the same bins for all the centers.
f, ax = plt.subplots(1, 2, figsize=(12, 4))
for cl in cluster_list:
    ax[0].scatter(cl.galcat['ra'], cl.galcat['dec'], color='blue', s=1, alpha=0.3)
    ax[0].plot(cl.ra, cl.dec, 'ro')
    ax[0].set_ylabel('dec', fontsize="large")
    ax[0].set_xlabel('ra', fontsize="large")

    hist = ax[1].hist(cl.galcat['z'], bins=bin_edges)[0]

    ax[1].axvline(cl.z, c='r', ls='--')
    ax[1].set_xlabel('$z_{source}$', fontsize="large")
    xt = {t:f'{t}' for t in ax[1].get_xticks() if t!=0}
    xt[cl.z] ='$z_{cl}$'
    xto = sorted(list(xt.keys())+[cl.z])
    ax[1].set_xticks(xto)
    ax[1].set_xticklabels(xt[t] for t in xto)
    ax[1].get_xticklabels()[xto.index(cl.z)].set_color('red')
    plt.xlim(0, max(xto))
plt.show()

# %% [markdown]
# ## 3. Compute the center effect on the shear profiles
#
# Next, we generate the profiles for all the Cluster objects and save the profiles into a list. We also save the `gt`, `gx`, and `radius` columns of each `profile` into lists, so we can make a plot of these components.

# %%
fig = plt.figure(figsize=(10, 6))
profile_list = []

for cl in cluster_list:
    theta, e_t, e_x = compute_tangential_and_cross_components(
                    ra_lens=cl.ra, dec_lens=cl.dec,
                    ra_source=cl.galcat['ra'], dec_source=cl.galcat['dec'],
                    shear1=cl.galcat['e1'], shear2=cl.galcat['e2'],
                    geometry="flat")
    cl.compute_tangential_and_cross_components(geometry="flat", add=True)
    cl.make_radial_profile("Mpc", cosmo=cosmo,bins=bin_edges, include_empty_bins=False)
    profile_list.append(cl.profile)

for a in range (0, len(profile_list)):
    center_distance = (cluster_list[a].ra**2 + cluster_list[a].dec**2)**(1/2)
    fig.gca().errorbar(profile_list[a]['radius'],profile_list[a]['gt'],profile_list[a]['gt_err'],linestyle='-', 
    marker='o', label =f'Distance from (0,0):{"{:.2f}".format(center_distance)}°')

plt.xlabel('log(radius)')
plt.ylabel('gt')

plt.legend()
plt.show()

# %%
fig2 = plt.figure(figsize=(10, 6))

for a in range (0, len(profile_list)):
    center_distance = (cluster_list[a].ra**2 + cluster_list[a].dec**2)**(1/2)
    fig2.gca().errorbar(profile_list[a]['radius'],profile_list[a]['gx'],profile_list[a]['gx_err'],linestyle='-', 
    marker='o', label =f'Offset distance:{"{:.2f}".format(center_distance)}°')
    
plt.xlabel('log(radius)')
plt.ylabel('gx')
plt.legend(loc=4)

plt.show()

# %% [markdown]
# Since we consider GalaxyCluster objects with no shape noise or photo-z errors, the center (0,0) gives the expected result `gx = 0`. For the other cluster centers, we can see that there is a non-zero cross shear component, which is an expected implication of the center change. Also, greater distances from the (0,0) lead to bigger absolute cross components.

# %% [markdown]
# ## 4. Compute the center effect by fitting the Halo mass
#
# In this last step, we compute the fitting Halo mass with the `nfw` model and, using a plot, compare the impact of the Cluster centers on the weak lensing mass.

# %%
from clmm.support.sampler import samplers

# %% [markdown]
# The function below defines the Halo model. For further information, check the notebook "Example2_Fit_Halo_Mass_to_Shear_Catalog.ipynb"

# %%
logm_0 = random.uniform(13., 17., 1)[0]
def shear_profile_model(r, logm, z_src):
    m = 10.**logm
    gt_model = clmm.compute_reduced_tangential_shear(r,
                                                     m, concentration,
                                                     cluster_z, z_src, cosmo,
                                                     delta_mdef=200,
                                                     halo_profile_model='nfw')    
    return gt_model

# %%
count = 1 #This value is just for a better visualization of the plot, so the are not in the same vertical line.
for a in range(0, len(cluster_list)):
    popt,pcov = fitters['curve_fit'](lambda r, logm:shear_profile_model(r, logm, profile_list[a]['z']), 
                    profile_list[a]['radius'], 
                    profile_list[a]['gt'], 
                    profile_list[a]['gt_err'], bounds=[13.,17.])

    m_est1 = 10.**popt[0]
    m_est_err1 =  m_est1 * np.sqrt(pcov[0][0]) * np.log(10) # convert the error on logm to error on m

    center_distance = (cluster_list[a].ra**2 + cluster_list[a].dec**2)**(1/2)
    center_distance = "{:.2f}".format(center_distance)
    print(f"The log of the mass is :{np.log(m_est1)}, for the offset distance:{center_distance}°")
    plt.plot(count,np.log(m_est1), '.', label=f'({cl.ra},{cl.dec})')
    count +=1
#plt.legend(loc="upper left")
plt.show()
# Out:
# The log of the mass is :34.405324069137414, for the offset distance:0.00°
# The log of the mass is :30.08785621614845, for the offset distance:0.19°
# The log of the mass is :29.933606208922598, for the offset distance:0.21°
# The log of the mass is :31.255718942275134, for the offset distance:0.18°
# The log of the mass is :33.87696040346777, for the offset distance:0.14°

# %% [markdown]
# We can see that for cluster centers differing from (0,0), we have a negative effect on the lensing mass, which increases with the offset distance.
